# %% [markdown]
# # Import Dataset

# %%
# !pip install --upgrade keras
# Out:
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (3.4.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras) (1.25.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras) (13.7.1)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras) (3.9.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras) (0.12.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras) (0.2.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras) (24.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)

# %%
import os
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.feature_selection import RFE
from imblearn.over_sampling import SMOTE
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score
from keras.callbacks import EarlyStopping

# %%
### 1. Link notebook with google drive and access data from your personal Gdrive
from google.colab import drive
# Mount Google Drive
drive.mount('/content/gdrive')

### 2.Set the data path for dataset and model location (ex: model_loc = "/content/gdrive/My Drive/Dataset/")
dataset_dir = "/content/gdrive/My Drive/ColabNotebooks/"
model_loc = "/content/gdrive/My Drive/ColabNotebooks/"

print(os.listdir(dataset_dir))
mrna_data = pd.read_csv(dataset_dir+'BRCA_mRNA.csv', index_col=0)
miRNA_data = pd.read_csv(dataset_dir+'BRCA_miRNA.csv', index_col=0)
DNA_Methylation_data = pd.read_csv(dataset_dir+'BRCA_DNA_Methylation.csv', index_col=0)
copy_number_variation_data = pd.read_csv(dataset_dir+'BRCA_Copy Number Variation.csv', index_col=0)
brca_Label = pd.read_csv(dataset_dir+'BRCA_label.csv')
multi_omics_data = pd.read_csv(dataset_dir+'BRCA_Multi_Omics.csv', index_col=0)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# ['sample_submission.csv', 'test.csv', 'train.csv', 'test_labels.csv', 'Entrez_inclassexe.ipynb', 'Entrez_inclassexe2.ipynb', 'Task2_PhangChengYi_GohYitian.ipynb', 'Task1_PhangChengYi_GohYitian.ipynb', 'In Group Activity 1.ipynb', 'PSM1_v1.ipynb', 'penguin_size.ipynb', 'penguin_lter.ipynb', 'PSM1_v2.ipynb', 'PSM1_v4.ipynb', 'heart.csv', 'PSM2_v3_arranged.ipynb', 'PSM2_v2_preprocessed_keyword.ipynb', 'PSM2_v1.ipynb', 'PSM1_v3.ipynb', 'BRCA_Copy Number Variation.csv', 'BioModelling_Project_BRCA_copy_number.ipynb', '[1_April_2024]_Heart_Disease_NN_PhangChengYi.ipynb', 'BRCA_label.csv', 'BRCA_mRNA.csv', 'BRCA_DNA_Methylation.csv', 'BRCA_miRNA.csv', 'BioModel_Project', 'BRCA_SingleOmic_VAE_WithoutSmote_Dataset.ipynb', 'BRCA_Multi_Omics.csv']

# %% [markdown]
# #Data Preprocessing & EDA

# %% [markdown]
# ## BRCA_Copy Number Variation

# %%
copy_number_variation_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19568 entries, A1BG to pk
# Columns: 671 entries, TCGA.3C.AAAU.01 to TCGA.Z7.A8R6.01
# dtypes: float64(671)
# memory usage: 100.3+ MB

# %%
copy_number_variation_data.head(10)
# Out:
#          TCGA.3C.AAAU.01  TCGA.3C.AALI.01  TCGA.3C.AALJ.01  TCGA.3C.AALK.01  \
# A1BG            0.495252         1.028904         0.003059        -0.258705
# A1CF           -0.938762        -1.575977         0.405308         0.096910
# A2M             0.750838         0.010864         0.103201        -0.169130
# A2ML1           0.748593         0.005894         0.098571        -0.174763
# A3GALT2         1.093743        -1.575680        -0.706498         0.199712
# A4GALT         -0.876388        -0.967673        -1.643561         0.570857
# A4GNT           1.109460         1.481901        -0.661117        -0.422884
# AAAS           -1.966983        -0.040373        -1.342185        -0.156210
# AACS           -1.676420        -0.027748         1.469986        -0.017618
# AADAC           1.090124         1.213108        -0.571499        -0.402285
#
#          TCGA.5L.AAT0.01  TCGA.5T.A9QA.01  TCGA.A1.A0SB.01  TCGA.A1.A0SE.01  \
# A1B
CGA.A1.A0SF.01  TCGA.A1.A0SG.01  ...  TCGA.UL.AAZ6.01  \
# A1BG             0.112737        -0.397480  ...        -1.828641
# A1BG.AS1         0.627872         0.426477  ...        -2.123590
# A2M              0.476992         0.147622  ...        -1.493460
# A2M.AS1         -0.092982        -0.666693  ...         0.851988
# A2ML1           -0.408042        -0.457548  ...         0.419145
# A2MP1           -0.264776        -0.343200  ...        -0.814826
# A4GALT           0.676890         1.261371  ...         0.436093
# AAAS             1.583352         0.208439  ...         1.841616
# AACS            -1.331414         0.918643  ...         1.194196
# AADAT           -1.010971        -0.671109  ...         0.511056
#
#           TCGA.UU.A93S.01  TCGA.V7.A7HQ.01  TCGA.W8.A86G.01  TCGA.WT.AB41.01  \
# A1BG             0.756934         1.095019         2.453552        -1.526821
# A1BG.AS1        -0.556860        -1.271019         1.915429        -2.519037
# A2M             -1.848483        -0.608446         0.584722        -0.267116
# A2M.AS1         -2.180389        -1.614497         0.398519        -0.632821
# A2ML1           -0.483924        -0.379297        -0.406793        -0.470376
# A2MP1           -0.889906        -0.577070        -0.209513         1.692166
# A4GALT          -2.023100         1.798225        -0.706899         2.508851
# AAAS            -2.215116         1.540387         1.881914         1.241782
# AACS             1.802331         0.876724        -1.193957        -0.788798
# AADAT           -1.219445        -0.981982        -0.682073        -0.389474
#
#           TCGA.WT.AB44.01  TCGA.XX.A899.01  TCGA.XX.A89A.01  TCGA.Z7.A8R5.01  \
# A1BG             0.108732        -0.219390        -0.112740        -0.920878
# A1BG.AS1        -0.643504         0.082909         0.284536        -0.372892
# A2M             -1.271778         0.780906         0.292935         1.883640
# A2M.AS1         -0.768806         0.200613         0.351478         0.015328
# A2ML1           -0.429807        -0.491028         0.421906        -0.456669
# A2MP1           -0.517498         1.236668         0.277833         2.279637
# A4GALT          -0.148959         0.397136         0.658981         0.319417
# AAAS             1.136479        -0.030975         0.359229         0.667426
# AACS            -1.740086         0.730476        -0.336013        -0.298045
# AADAT           -0.562701        -0.449559        -0.483281        -0.376687
#
#           TCGA.Z7.A8R6.01
# A1BG             0.079873
# A1BG.AS1         0.539919
# A2M             -0.469512
# A2M.AS1         -1.309134
# A2ML1           -0.394471
# A2MP1           -0.730764
# A4GALT           1.304757
# AAAS             0.433323
# AACS            -0.811775
# AADAT           -0.699855
#
# [10 rows x 671 columns]

# %%
# Check if there any null values in the BRCA_mRNA dataset
mrna_data.isnull().any().any()
# Out:
# False

# %% [markdown]
# ## BRCA_label

# %%
brca_Label.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 671 entries, 0 to 670
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Label   671 non-null    object
# dtypes: object(1)
# memory usage: 5.4+ KB

# %%
# BRCA_Copy Number Variation dataset
brca_Label.head(10)
# Out:
#     Label
# 0    LumA
# 1    Her2
# 2    LumB
# 3    LumA
# 4    LumA
# 5    LumB
# 6  Normal
# 7    LumA
# 8    LumA
# 9    LumA

# %%
# check is there any null values in the BRCA_Copy Number Variation dataset
brca_Label.isnull().any().any()
# Out:
# False

# %%
brca_Label.shape
# Out:
# (671, 1)

# %%
label_value_counts = brca_Label['Label'].value_counts()

print(label_value_counts)
# Out:
# Label
# LumA      353
# LumB      132
# Basal     113
# Her2       42
# Normal     31
# Name: count, dtype: int64

# %%
#replace label with numerical data
brca_Label['Label'].replace('Normal', 0 , inplace=True)
brca_Label['Label'].replace('LumA', 1 , inplace=True)
brca_Label['Label'].replace('LumB', 2 , inplace=True)
brca_Label['Label'].replace('Basal', 3 , inplace=True)
brca_Label['Label'].replace('Her2', 4 , inplace=True)

# %%
label_value_counts = brca_Label['Label'].value_counts()

print(label_value_counts)
# Out:
# Label
# 1    353
# 2    132
# 3    113
# 4     42
# 0     31
# Name: count, dtype: int64

# %% [markdown]
# ## BRCA_Multi_Omics

# %%
multi_omics_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 
CGA.WT.AB44.01  TCGA.XX.A899.01  TCGA.XX.A89A.01  TCGA.Z7.A8R5.01  \
# A1BG           -0.835261        -0.148311         0.557439        -0.234602
# A1CF            0.483323         0.061306         0.627836         0.070730
# A2M             0.266599        -0.089133         0.344469         0.226601
# A2ML1           0.262571        -0.094471         0.340728         0.222425
# A3GALT2        -2.569588         0.046241        -1.244865        -0.252418
# A4GALT         -1.733704         0.592537        -0.629158         0.087808
# A4GNT          -0.412105        -0.391623        -0.897733        -1.021162
# AAAS            0.359954        -0.094390         0.600030         0.488395
# AACS            0.516238         0.009733         0.666163         0.491419
# AADAC          -0.364133        -0.347077        -0.768542        -0.882100
#
#          TCGA.Z7.A8R6.01
# A1BG           -0.838154
# A1CF           -0.463861
# A2M            -0.590817
# A2ML1          -0.598003
# A3GALT2        -0.264599
# A4GALT          0.082483
# A4GNT          -0.788319
# AAAS           -0.545733
# AACS           -0.372678
# AADAC          -0.628054
#
# [10 rows x 671 columns]

# %%
# Check if there any null values in the BRCA_mRNA dataset
multi_omics_data.isnull().any().any()
# Out:
# False

# %% [markdown]
# There is no missing values in all five dataset

# %% [markdown]
# # Data Preparation

# %% [markdown]
# Trasnpose the row and column

# %% [markdown]
# ## BRCA_Copy Number Variation

# %%
# Before transpose
copy_number_variation_data.shape
# Out:
# (19568, 671)

# %%
# Transpose copy_number_variation_data
copy_number_variation_data = copy_number_variation_data.transpose()

# %%
# After transpose
copy_number_variation_data.head(10)
# Out:
#                      A1BG      A1CF       A2M     A2ML1   A3GALT2    A4GALT  \
# TCGA.3C.AAAU.01  0.495252 -0.938762  0.750838  0.748593  1.093743 -0.876388
# TCGA.3C.AALI.01  1.028904 -1.575977  0.010864  0.005894 -1.575680 -0.967673
# TCGA.3C.AALJ.01  0.003059  0.405308  0.103201  0.098571 -0.706498 -1.643561
# TCGA.3C.AALK.01 -0.258705  0.096910 -0.169130 -0.174763  0.199712  0.570857
# TCGA.5L.AAT0.01 -0.083232  0.060782 -2.090765 -2.103474  0.376570  0.631333
# TCGA.5T.A9QA.01 -0.486242  2.050968 -0.216362 -0.222169 -2.334753  2.749902
# TCGA.A1.A0SB.01 -0.111192  0.154506 -0.062751 -0.067992  0.400443  0.620683
# TCGA.A1.A0SE.01 -0.102997  0.018894 -0.056368 -0.061585  0.225047  0.497449
# TCGA.A1.A0SF.01  0.687116  1.131535  0.857217  0.855364  1.226264  0.387146
# TCGA.A1.A0SG.01 -0.213873  0.145081 -0.016369 -0.021439  0.390699 -0.143066
#
#                     A4GNT      AAAS      AACS     AADAC  ...     ZWINT  \
# TCGA.3C.AAAU.01  1.109460 -1.966983 -1.676420  1.090124  ... -0.837399
# TCGA.3C.AALI.01  1.481901 -0.040373 -0.027748  1.213108  ... -1.537275
# TCGA.3C.AALJ.01 -0.661117 -1.342185  1.469986 -0.571499  ...  4.165544
# TCGA.3C.AALK.01 -0.422884 -0.156210 -0.017618 -0.402285  ...  0.080744
# TCGA.5L.AAT0.01 -0.350660 -0.101592  0.100904 -0.312965  ...  0.045801
# TCGA.5T.A9QA.01 -0.173333 -0.175416  0.011759 -0.110984  ...  1.970711
# TCGA.A1.A0SB.01 -0.273585  0.005842  0.084190 -0.226338  ...  0.136450
# TCGA.A1.A0SE.01 -0.151234  0.145686 -1.943348 -0.146892  ...  0.005287
# TCGA.A1.A0SF.01 -0.508045  1.277645 -1.716941 -0.444027  ...  1.072825
# TCGA.A1.A0SG.01 -0.384077 -0.019366  0.046708 -0.340793  ...  0.127335
#
#                      ZXDA      ZXDB      ZXDC    ZYG11A    ZYG11B       ZYX  \
# TCGA.3C.AAAU.01  2.020624  1.972719  1.053381  1.254989  1.267331  0.963246
# TCGA.3C.AALI.01  4.002085  3.897638  1.589442 -1.781406 -1.793233  1.446230
# TCGA.3C.AALJ.01 -0.319977 -0.301093 -0.477515 -0.867769 -0.872324  0.039191
# TCGA.3C.AALK.01 -0.316675 -0.297884 -0.267586  0.055935  0.058733 -0.257130
# TCGA.5L.AAT0.01 -0.307593 -0.289062 -0.200167  0.238663  0.242915 -0.185487
# TCGA.5T.A9QA.01 -0.399235 -0.392526 -0.141518 -2.457950 -2.475162 -1.970238
# TCGA.A1.A0SB.01 -0.179623 -0.164744 -0.084514  0.258798  0.263210 -0.112381
# TCGA.A1.A0SE.01 -0.121831 -0.108601  0.039909  0.082111  0.085117 -0.106533
# TCGA.A1.A0SF.01 -0.210171 -0.194420 -0.356381  1.164884  1.176508  0.704939
# TCGA.A1.A0SG.01 -0.254754 -0.237731 -0.196879  0.203426  0.207398 -0.262491
#
#                     ZZEF1      ZZZ3        pk
# TCGA.3C.AAAU.01 -0.580418  1.715811 -0.864183
# TCGA.3C.AALI.01 -0.790000 -1.268621  0.345052
# TCGA.3C.AALJ.01 -1.421040 -0.811368 -1.357237
# TCGA.3C.AALK.01 -1.377441  0.098802  0.042601
# TCGA.5L.AAT0.01 -0.999581  0.204322  0.078553
# TCGA.5T.A9QA.01  1.646581 -1.930651 -6.994250
# TCGA.A1.A0SB.01  0.848410  0.307432  0.189832
# TCGA.A1.A0SE.01 -0.727278  0.230822  0.289698
# TCGA.A1.A0SF.01 -0.501251 -1.278740 -0.088652
# TCGA.A1.A0SG.01  0.866003  0.290087  0.104803
#
# [10 rows x 19568 columns]

# %%
copy_number_variation_data.shape
# Out:
# (671, 19568)

# %%
# Ensure the number of rows in data match with label
if copy_number_variation_data.shape[0] == brca_Label.shape[0]:
    # Add the new column to the transposed DataFrame
    copy_number_variation_data['Label'] = brca_Label['Label'].values
else:
    raise ValueError("The number of rows in must match the number of columns in the transposed df1.")

# %%
copy_number_variation_data.shape
# Out:
# (671, 19569)

# %%
# Check if there any null values in the BRCA_mRNA dataset
copy_number_variation_data.isnull().any().any()
# Out:
# False

# %%
copy_number_variation_data.head(10)
# Out:
#                      A1BG      A1CF       A2M     A2ML1   A3GALT2    A4GALT  \
# TCGA.3C.AAAU.01  0.495252 -0.938762  0.750838  0.748593  1.093743 -0.876388
# TCGA.3C.AALI.01  1.028904 -1.575977  0.010864  0.005894 -1.575680 -0.967673
# TCGA.3C.AALJ.01  0.003059  0.405308  0.103201  0.098571 -0.706498 -1.643561
# TCGA.3C.AALK.01 -0.258705  0.096910 -0.169130 -0.174763  0.199712  0.570857
# TCGA.5L.AAT0.01 -0.083232  0.060782 -2.090765 -2.103474  0.376570  0.631333
# TCGA.5T.A9QA.01 -0.486242  2.050968 -0.216362 -0.222169 -2.334753  2.749902
# TCGA.A1.A0SB.01 -0.111192  0.154506 -0.062751 -0.067992  0.400443  0.620683
# TCGA.A1.A0SE.01 -0.102997  0.018894 -0.056368 -0.061585  0.225047  0.497449
# TCGA.A1.A0SF.01  0.687116  1.131535  0.857217  0.855364  1.226264  0.387146
# TCGA.A1.A0SG.01 -0.213873  0.145081 -0.016369 -0.021439  0.390699 -0.143066
#
#                     A4GNT      AAAS      AACS     AADAC  ...      ZXDA  \
# TCGA.3C.AAAU.01  1.109460 -1.966983 -1.676420  1.090124  ...  2.020624
# TCGA.3C.AALI.01  1.481901 -0.040373 -0.027748  1.213108  ...  4.002085
# TCGA.3C.AALJ.01 -0.661117 -1.342185  1.469986 -0.571499  ... -0.319977
# TCGA.3C.AALK.01 -0.422884 -0.156210 -0.017618 -0.402285  ... -0.316675
# TCGA.5L.AAT0.01 -0.350660 -0.101592  0.100904 -0.312965  ... -0.307593
# TCGA.5T.A9QA.01 -0.173333 -0.175416  0.011759 -0.110984  ... -0.399235
# TCGA.A1.A0SB.01 -0.273585  0.005842  0.084190 -0.226338  ... -0.179623
# TCGA.A1.A0SE.01 -0.151234  0.145686 -1.943348 -0.146892  ... -0.121831
# TCGA.A1.A0SF.01 -0.508045  1.277645 -1.716941 -0.444027  ... -0.210171
# TCGA.A1.A0SG.01 -0.384077 -0.019366  0.046708 -0.340793  ... -0.254754
#
#                      ZXDB      ZXDC    ZYG11A    ZYG11B       ZYX     ZZEF1  \
# TCGA.3C.AAAU.01  1.972719  1.053381  1.254989  1.267331  0.963246 -0.580418
# TCGA.3C.AALI.01  3.897638  1.589442 -1.781406 -1.793233  1.446230 -0.790000
# TCGA.3C.AALJ.01 -0.301093 -0.477515 -0.867769 -0.872324  0.039191 -1.421040
# TCGA.3C.AALK.01 -0.297884 -0.267586  0.055935  0.058733 -0.257130 -1.377441
# TCGA.5L.AAT0.01 -0.289062 -0.200167  0.238663  0.242915 -0.185487 -0.999581
# TCGA.5T.A9QA.01 -0.392526 -0.141518 -2.457950 -2.475162 -1.970238  1.646581
# TCGA.A1.A0SB.01 -0.164744 -0.084514  0.258798  0.263210 -0.112381  0.848410
# TCGA.A1.A0SE.01 -0.108601  0.039909  0.082111  0.085117 -0.106533 -0.727278
# TCGA.A1.A0SF.01 -0.194420 -0.356381  1.164884  1.176508  0.704939 -0.501251
# TCGA.A1.A0SG.01 -0.237731 -0.196879  0.203426  0.207398 -0.262491  0.866003
#
#                      ZZZ3        pk  Label
# TCGA.3C.AAAU.01  1.715811 -0.864183      1
# TCGA.3C.AALI.01 -1.268621  0.345052      4
# TCGA.3C.AALJ.01 -0.811368 -1.357237      2
# TCGA.3C.AALK.01  0.098802  0.042601      1
# TCGA.5L.AAT0.01  0.204322  0.078553      1
# TCGA.5T.A9QA.01 -1.930651 -6.994250      2
# TCGA.A1.A0SB.01  0.307432  0.189832      0
# TCGA.A1.A0SE.01  0.230822  0.289698      1
# TCGA.A1.A0SF.01 -1.278740 -0.088652      1
# TCGA.A1.A0SG.01  0.290087  0.104803      1
#
# [10 rows x 19569 columns]

# %%
print(copy_number_variation_data["Label"].value_counts()[0])
print(copy_number_variation_data["Label"].value_counts()[1])
print(copy_number_variation_data["Label"].value_counts()[2])
print(copy_number_variation_data["Label"].value_counts()[3])
print(copy_number_variation_data["Label"].value_counts()[4])
# Out:
# 31
# 353
# 132
# 113
# 42

# %% [markdown]
# ## BRCA_miRNA

# %%
# Before transpose
miRNA_data.shape
# Out:
# (368, 671)

# %%
# Transpose mrna_data
miRNA_data = miRNA_data.transpose()

# %%
# After transpose
miRNA_data.head(10)
# Out:
#                  hsa.let.7a.1  hsa.let.7a.2  hsa.let.7a.3  hsa.let.7b  \
# TCGA.3C.AAAU.01      0.068317      0.068932      0.073899    0.524562
# TCGA.3C.AALI.01     -0.301684     -0.318009     -0.301310    0.419859
# TCGA.3C.AALJ.01     -0.150810     -0.122747     -0.126333   -0.958939
# TCGA.3C.AALK.01      0.107831      0.097594      0.095545    0.615389
# TCGA.5L.AAT0.01      0.395211      0.412879      0.418441    0.500594
# TCGA.5T.A9QA.01      1.135212      1.140183      1.143605    1.159087
# TCGA.3C.AALJ.01      1.088164    0.523204  ...     1.952380    -1.226285
# TCGA.3C.AALK.01     -0.686623   -1.015715  ...     0.119549    -0.340371
# TCGA.5L.AAT0.01     -0.233746   -0.818574  ...    -0.248950    -1.439120
# TCGA.5T.A9QA.01     -0.152147    1.243074  ...    -0.531098    -0.001485
# TCGA.A1.A0SB.01      0.798862    2.111705  ...    -1.000344    -0.912012
# TCGA.A1.A0SE.01      0.184119   -0.511843  ...    -1.280723    -0.332270
# TCGA.A1.A0SF.01      0.041877   -1.315689  ...    -1.139447    -0.259122
# TCGA.A1.A0SG.01      0.851887    0.162780  ...     1.512383    -1.105097
#
#                  hsa.mir.940  hsa.mir.942  hsa.mir.95  hsa.mir.96  hsa.mir.98  \
# TCGA.3C.AAAU.01     1.768897     0.226659    0.943346    1.552613   -0.143572
# TCGA.3C.AALI.01    -0.453994     0.804807   -0.828843    0.599794    1.103662
# TCGA.3C.AALJ.01    -0.281690    -0.314543   -0.487207    1.261482    1.940594
# TCGA.3C.AALK.01    -0.586990    -0.364370   -0.539524    0.856983   -0.831098
# TCGA.5L.AAT0.01    -0.707823    -0.109361   -0.490655    1.188748   -0.885905
# TCGA.5T.A9QA.01    -0.042380     2.139282    1.716711    0.375870   -0.922881
# TCGA.A1.A0SB.01    -0.327511     0.306851   -0.311971    0.297224    0.390134
# TCGA.A1.A0SE.01    -0.426424    -0.629303   -0.207033    0.066368   -0.330246
# TCGA.A1.A0SF.01    -0.505870    -0.260053   -0.411471    0.268172   -0.481707
# TCGA.A1.A0SG.01     0.315259    -0.420010    1.331634    0.155349    0.490018
#
#                  hsa.mir.99a  hsa.mir.99b  Label
# TCGA.3C.AAAU.01    -1.251868     1.603022      1
# TCGA.3C.AALI.01    -0.627587    -1.506825      4
# TCGA.3C.AALJ.01    -0.848552     0.787948      2
# TCGA.3C.AALK.01     0.936474     0.030739      1
# TCGA.5L.AAT0.01     0.449284    -0.645458      1
# TCGA.5T.A9QA.01    -1.316179     0.931785      2
# TCGA.A1.A0SB.01     2.106744     0.319827      0
# TCGA.A1.A0SE.01     1.078635     0.089918      1
# TCGA.A1.A0SF.01     1.255710    -0.443763      1
# TCGA.A1.A0SG.01    -0.062945     1.220345      1
#
# [10 rows x 369 columns]

# %%
print(miRNA_data["Label"].value_counts()[0])
print(miRNA_data["Label"].value_counts()[1])
print(miRNA_data["Label"].value_counts()[2])
print(miRNA_data["Label"].value_counts()[3])
print(miRNA_data["Label"].value_counts()[4])
# Out:
# 31
# 353
# 132
# 113
# 42

# %% [markdown]
# ## BRCA_DNA_Methylation

# %%
# Before transpose
DNA_Methylation_data.shape
# Out:
# (19049, 671)

# %%
# Transpose mrna_data
DNA_Methylation_data = DNA_Methylation_data.transpose()

# %%
# After transpose
DNA_Methylation_data.head(10)
# Out:
#                      A1BG      A1CF       A2M     A2ML1   A3GALT2    A4GALT  \
# TCGA.3C.AAAU.
-0.086925 -0.473521 -0.112660 -0.967701 -0.585443 -0.625655
# TCGA.A1.A0SG.01 -0.688724 -0.388183 -0.283091 -0.634965 -0.713563  0.094450
#
#                      ZZZ3        pk  Label
# TCGA.3C.AAAU.01  0.378339  0.032275      1
# TCGA.3C.AALI.01  0.271888 -0.147645      4
# TCGA.3C.AALJ.01 -0.170242  0.748945      2
# TCGA.3C.AALK.01  0.484366  0.173110      1
# TCGA.5L.AAT0.01  0.029261 -0.424061      1
# TCGA.5T.A9QA.01  0.970602  2.038508      2
# TCGA.A1.A0SB.01 -0.468274 -0.932571      0
# TCGA.A1.A0SE.01 -0.221699  0.062171      1
# TCGA.A1.A0SF.01 -0.738370 -0.914940      1
# TCGA.A1.A0SG.01 -0.381204  0.623692      1
#
# [10 rows x 19050 columns]

# %%
print(DNA_Methylation_data["Label"].value_counts()[0])
print(DNA_Methylation_data["Label"].value_counts()[1])
print(DNA_Methylation_data["Label"].value_counts()[2])
print(DNA_Methylation_data["Label"].value_counts()[3])
print(DNA_Methylation_data["Label"].value_counts()[4])
# Out:
# 31
# 353
# 132
# 113
# 42

# %% [markdown]
# ## BRCA_mRNA

# %%
# Before transpose
mrna_data.shape
# Out:
# (18206, 671)

# %%
# Transpose mrna_data
mrna_data = mrna_data.transpose()

# %%
# After transpose
mrna_data.head(10)
# Out:
#                      A1BG  A1BG.AS1       A2M   A2M.AS1     A2ML1     A2MP1  \
# TCGA.3C.AAAU.01  1.389927  0.436758 -0.876187  1.607818 -0.415138 -0.374641
# TCGA.3C.AALI.01  1.522872  1.815091 -0.508085  0.863019 -0.406608 -0.361230
# TCGA.3C.AALJ.01  1.788271  0.580557 -0.258138 -0.491954 -0.455969  0.855983
# TCGA.3C.AALK.01 -0.288543 -0.250194 -0.030804 -0.579638 -0.464938 -0.313092
# TCGA.5L.AAT0.01 -0.462680 -0.091285  0.289970  0.572883 -0.438571 -0.090844
# TCGA.5T.A9QA.01 -0.451169 -0.688598 -1.641876 -0.836306 -0.479607 -1.014920
# TCGA.A1.A0SB.01 -0.805973 -1.037605  1.534552  0.099614 -0.444955  1.384198
# TCGA.A1.A0SE.01 -0.472368  0.658661  0.436717 -0.059346 -0.539629 -0.508012
# TCGA.A1.A0SF.01  0.112737  0.627872  0.476992 -0.092982 -0.408042 -0.264776
# TCGA.A1.A0SG.01 -0.397480  0.426477  0.147622 -0.666693 -0.457548 -0.343200
#
#                    A4GALT      AAAS      AACS     AADAT  ...    ZWILCH  \
# TCGA.3C.AAAU.01 -1.727152 -0.562530  0.225676 -1.337786  ...  0.382250
# TCGA.3C.AALI.01 -0.964244  0.525889 -0.590749 -0.724950  ...  2.927253
# TCGA.3C.AALJ.01  0.750127 -0.401461  1.077314  0.101880  ... -0.381820
# TCGA.3C.AALK.01  0.480557 -0.426938 -0.739098 -0.091341  ... -0.029094
# TCGA.5L.AAT0.01  0.179004  0.685542 -0.623465 -0.421059  ... -0.232629
# TCGA.5T.A9QA.01  0.420826  0.697997  0.669477  1.067540  ...  0.845089
# TCGA.A1.A0SB.01  0.260066  0.127438  1.339599  1.377738  ...  0.051136
# TCGA.A1.A0SE.01  0.058950 -0.117362 -0.443098 -0.566328  ...  0.091780
# TCGA.A1.A0SF.01  0.676890  1.583352 -1.331414 -1.010971  ... -1.173102
# TCGA.A1.A0SG.01  1.261371  0.208439  0.918643 -0.671109  ... -0.699790
#
#                     ZWINT      ZXDA      ZXDB      ZXDC    ZYG11A    ZYG11B  \
# TCGA.3C.AAAU.01  0.445598  2.359316  2.242234  1.190506  1.753777  2.013674
# TCGA.3C.AALI.01  0.455835  0.513900  0.179770  1.588651  1.298863 -0.140439
# TCGA.3C.AALJ.01  1.900756 -0.505798  0.658038 -1.008467  2.105007 -0.334864
# TCGA.3C.AALK.01 -0.210541 -0.185209 -0.066780 -0.759323  0.916528 -0.278901
# TCGA.5L.AAT0.01 -0.709315  0.770811  1.161026  0.369677 -1.152811  0.075213
# TCGA.5T.A9QA.01  1.473857 -0.869225 -0.460787 -0.008572 -1.553161 -1.397447
# TCGA.A1.A0SB.01 -1.227280  0.955570 -0.083160  1.287459 -1.086313  1.450555
# TCGA.A1.A0SE.01  0.231947  0.830896  0.605248 -0.282021 -0.380918  0.230984
# TCGA.A1.A0SF.01 -0.059546  0.746254  0.158860 -0.112952  0.077010  0.050613
# TCGA.A1.A0SG.01 -0.359577 -0.703121 -0.338345  0.205879 -1.682207 -0.605257
#
#                       ZYX     ZZEF1      ZZZ3
# TCGA.3C.AAAU.01 -0.424991  1.214399  1.667340
# TCGA.3C.AALI.01  0.635518  0.302547 -1.162286
# TCGA.3C.AALJ.01  0.573943 -0.379244 -0.547104
# TCGA.3C.AALK.01  0.515520 -0.939663  0.057166
# TCGA.5L.AAT0.01 -0.100236 -0.485591  1.268702
# TCGA.5T.A9QA.01 -0.472842  0.190737 -0.622851
# TCGA.A1.A0SB.01  1.176967  1.560267  0.954347
# TCGA.A1.A0SE.01 -0.169919 -0.492343  0.581995
# TCGA.A1.A0SF.01  0.889745 -0.513877 -1.422932
# TCGA.A1.A0SG.01 -0.606344  1.306838 -1.189883
#
# [10 rows x 18206 columns]

# %%
mrna_data.shape
# Out:
# (671, 18206)

# %%
brca_Label.shape
# Out:
# (671, 1)

# %%
# Ensure the number of rows in data match with label
if mrna_data.shape[0] == brca_Label.shape[0]:
    # Add the new column to the transposed DataFrame
    mrna_data['Label'] = brca_Label['Label'].values
else:
    raise ValueError("The number of rows in must match the number of columns in the transposed df1.")

# %%
mrna_data.shape
# Out:
# (671, 18207)

# %%
# Check if there any null values in the BRCA_mRNA dataset
mrna_data.isnull().any().any()
# Out:
# False

# %%
mrna_data.head(10)
# Out:
#                      A1BG  A1BG.AS1       A2M   A2M.AS1     A2ML1     A2MP1  \
# TCGA.3C.AAAU.01  1.389927  0.436758 -0.876187  1.607818 -0.415138 -0.374641
# TCGA.3C.AALI.01  1.522872  1.815091 -0.508085  0.863019 -0.406608 -0.361230
# TCGA.3C.AALJ.01  1.788271  0.580557 -0.258138 -0.491954 -0.455969  0.855983
# TCGA.3C.AALK.01 -0.288543 -0.250194 -0.030804 -0.579638 -0.464938 -0.313092
# TCGA.5L.AAT0.01 -0.462680 -0.091285  0.289970  0.572883 -0.438571 -0.090844
data["Label"].value_counts()[4])
# Out:
# 31
# 353
# 132
# 113
# 42

# %% [markdown]
# ## BRCA_Multi_Omics

# %%
# Before transpose
multi_omics_data.shape
# Out:
# (57191, 671)

# %%
# Transpose mrna_data
multi_omics_data = multi_omics_data.transpose()

# %%
# After transpose
multi_omics_data.head(10)
# Out:
#                      A1BG      A1CF       A2M     A2ML1   A3GALT2    A4GALT  \
# TCGA.3C.AAAU.01  0.495252 -0.938762  0.750838  0.748593  1.093743 -0.876388
# TCGA.3C.AALI.01  1.028904 -1.575977  0.010864  0.005894 -1.575680 -0.967673
# TCGA.3C.AALJ.01  0.003059  0.405308  0.103201  0.098571 -0.706498 -1.643561
# TCGA.3C.AALK.01 -0.258705  0.096910 -0.169130 -0.174763  0.199712  0.570857
# TCGA.5L.AAT0.01 -0.083232  0.060782 -2.090765 -2.103474  0.376570  0.631333
# TCGA.5T.A9QA.01 -0.486242  2.050968 -0.216362 -0.222169 -2.334753  2.749902
# TCGA.A1.A0SB.01 -0.111192  0.154506 -0.062751 -0.067992  0.400443  0.620683
# TCGA.A1.A0SE.01 -0.102997  0.018894 -0.056368 -0.061585  0.225047  0.497449
# TCGA.A1.A0SF.01  0.687116  1.131535  0.857217  0.855364  1.226264  0.387146
# TCGA.A1.A0SG.01 -0.213873  0.145081 -0.016369 -0.021439  0.390699 -0.143066
#
#                     A4GNT      AAAS      AACS     AADAC  ...     ZWINT  \
# TCGA.3C.AAAU.01  1.109460 -1.966983 -1.676420  1.090124  ...  0.835761
# TCGA.3C.AALI.01  1.481901 -0.040373 -0.027748  1.213108  ...  0.664052
# TCGA.3C.AALJ.01 -0.661117 -1.342185  1.469986 -0.571499  ... -0.092097
# TCGA.3C.AALK.01 -0.422884 -0.156210 -0.017618 -0.402285  ...  0.277971
# TCGA.5L.AAT0.01 -0.350660 -0.101592  0.100904 -0.312965  ... -0.008991
# TCGA.5T.A9QA.01 -0.173333 -0.175416  0.011759 -0.110984  ...  0.351988
# TCGA.A1.A0SB.01 -0.273585  0.005842  0.084190 -0.226338  ... -0.268241
# TCGA.A1.A0SE.01 -0.151234  0.145686 -1.943348 -0.146892  ... -0.279765
# TCGA.A1.A0SF.01 -0.508045  1.277645 -1.716941 -0.444027  ... -0.642373
# TCGA.A1.A0SG.01 -0.384077 -0.019366  0.046708 -0.340793  ... -0.883780
#
#                      ZXDA      ZXDB      ZXDC    ZYG11A    ZYG11B       ZYX  \
# TCGA.3C.AAAU.01 -2.172061 -0.184735  0.821827 -0.842599  1.079773  0.780058
# TCGA.3C.AALI.01 -0.897618 -1.043726  0.746737 -0.188174  1.107008  0.404568
# TCGA.3C.AALJ.01 -0.403899  0.163509  0.991162 -0.337345  1.143368 -0.583163
# TCGA.3C.AALK.01  0.752473  0.722295  0.352692 -0.606283  1.327138  0.047150
# TCGA.5L.AAT0.01  0.693802  0.211610  0.025049 -0.391619  0.825476  0.272223
# TCGA.5T.A9QA.01  1.575007  1.176298  0.677674  5.591173  1.014806  1.304881
# TCGA.A1.A0SB.01  0.144638  0.958181 -0.756234 -1.033358 -0.726589 -0.084193
# TCGA.A1.A0SE.01  0.158648 -0.079927 -0.148292 -0.781399  0.116715 -0.078364
# TCGA.A1.A0SF.01 -0.263347 -0.086925 -0.473521 -0.112660 -0.967701 -0.585443
# TCGA.A1.A0SG.01  0.150851 -0.688724 -0.388183 -0.283091 -0.634965 -0.713563
#
#                     ZZEF1      ZZZ3        pk
# TCGA.3C.AAAU.01  0.747015  0.378339  0.032275
# TCGA.3C.AALI.01  0.107306  0.271888 -0.147645
# TCGA.3C.AALJ.01  0.034379 -0.170242  0.748945
# TCGA.3C.AALK.01  0.014622  0.484366  0.173110
# TCGA.5L.AAT0.01  0.298979  0.029261 -0.424061
# TCGA.5T.A9QA.01  1.151613  0.970602  2.038508
# TCGA.A1.A0SB.01 -0.621557 -0.468274 -0.932571
# TCGA.A1.A0SE.01 -0.887355 -0.221699  0.062171
# TCGA.A1.A0SF.01 -0.625655 -0.738370 -0.914940
# TCGA.A1.A0SG.01  0.094450 -0.381204  0.623692
#
# [10 rows x 57191 columns]

# %%
multi_omics_data.shape
# Out:
# (671, 57191)

# %%
brca_Label.shape
# Out:
# (671, 1)

# %%
# Ensure the number of rows in data match with label
if multi_omics_data.shape[0] == brca_Label.shape[0]:
    # Add the new column to the transposed DataFrame
    multi_omics_data['Label'] = brca_Label['Label'].values
else:
    raise ValueError("The number of rows in must match the number of columns in the transposed df1.")

# %%
multi_omics_data.shape
# Out:
# (671, 57192)

# %%
# Check if there any null values in the BRCA_mRNA dataset
multi_omics_data.isnull().any().any()
# Out:
# False

# %%
multi_omics_data.head(10)
# Out:
#                      A1BG      A1CF       A2M     A2ML1   A3GALT2    A4GALT  \
# TCGA.5T.A9QA.01  0.970602  2.038508      2
# TCGA.A1.A0SB.01 -0.468274 -0.932571      0
# TCGA.A1.A0SE.01 -0.221699  0.062171      1
# TCGA.A1.A0SF.01 -0.738370 -0.914940      1
# TCGA.A1.A0SG.01 -0.381204  0.623692      1
#
# [10 rows x 57192 columns]

# %%
print(multi_omics_data["Label"].value_counts()[0])
print(multi_omics_data["Label"].value_counts()[1])
print(multi_omics_data["Label"].value_counts()[2])
print(multi_omics_data["Label"].value_counts()[3])
print(multi_omics_data["Label"].value_counts()[4])
# Out:
# 31
# 353
# 132
# 113
# 42

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ## BRCA_Copy Number Variation

# %% [markdown]
# ###Training of SVM

# %%
train_data, test_data = train_test_split(copy_number_variation_data,test_size=0.30,random_state=1)
target="Label"
X_train = train_data.select_dtypes(include=["number"]).copy()
y_train_copy_number_variation = train_data[target]
X_test = test_data.select_dtypes(include=["number"]).copy()
y_test_copy_number_variation = test_data[target]

# %%
print("X train :", X_train.shape)
print("X test :", X_test.shape)
print("Y train :", y_train_copy_number_variation.shape)
print("Y test :", y_test_copy_number_variation.shape)
# Out:
# X train : (469, 19569)
# X test : (202, 19569)
# Y train : (469,)
# Y test : (202,)

# %%
# Define the SVM model
model = SVC(kernel="linear")

# Define RFE with the SVM model, choosing a number of features to select
rfe = RFE(estimator=model, n_features_to_select=19000, step=0.05)

# Fit RFE on the training data
rfe.fit(X_train, y_train_copy_number_variation)
# Out:
# RFE(estimator=SVC(kernel='linear'), n_features_to_select=19000)

# %%
# Transform the training and test sets to include only the selected features
X_train_rfe_copy_number_variation = rfe.transform(X_train)
X_test_rfe_copy_number_variation = rfe.transform(X_test)

# %%
print(X_test_rfe_copy_number_variation.shape)
print(X_train_rfe_copy_number_variation.shape)
# Out:
# (202, 19000)
# (469, 19000)

# %% [markdown]
# ### Result

# %%
# Convert the transformed arrays back to DataFrames
# Get the selected feature names
selected_features_copy_number_variation = X_train.columns[rfe.support_]

X_train_rfe_copy_number_variation= pd.DataFrame(X_train_rfe_copy_number_variation, columns=selected_features_copy_number_variation, index=X_train.index)
X_test_rfe_copy_number_variation = pd.DataFrame(X_test_rfe_copy_number_variation, columns=selected_features_copy_number_variation, index=X_test.index)

# %%
# Save the dataframes
X_train_rfe_copy_number_variation.to_pickle('X_train_rfe_copy_number_variation.pkl')
X_test_rfe_copy_number_variation.to_pickle('X_test_rfe_copy_number_variation.pkl')

# %%
from google.colab import drive
# Mount Google Drive
drive.mount('/content/gdrive')

X_train_rfe_copy_number_variation.to_pickle('/content/gdrive/My Drive/ColabNotebooks/BioModel_Project/X_train_rfe_copy_number_variation.pkl')
X_test_rfe_copy_number_variation.to_pickle('/content/gdrive/My Drive/ColabNotebooks/BioModel_Project/X_test_rfe_copy_number_variation.pkl')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# ## BRCA_miRNA

# %% [markdown]
# ###Training of SVM

# %%
train_data, test_data = train_test_split(miRNA_data,test_size=0.30,random_state=1)
target="Label"
X_train = train_data.select_dtypes(include=["number"]).copy()
y_train_miRNA = train_data[target]
X_test = test_data.select_dtypes(include=["number"]).copy()
y_test_miRNA = test_data[target]

# %%
print("X train :", X_train.shape)
print("X test :", X_test.shape)
print("Y train :", y_train_miRNA.shape)
print("Y test :", y_test_miRNA.shape)
# Out:
# X train : (469, 369)
# X test : (202, 369)
# Y train : (469,)
# Y test : (202,)

# %%
# Define the SVM model
model = SVC(kernel="linear")

# Define RFE with the SVM model, choosing a number of features to select
rfe = RFE(estimator=model, n_features_to_select=300, step=0.05)

# Fit RFE on the training data
rfe.fit(X_train, y_train_miRNA)
# Out:
# RFE(estimator=SVC(kernel='linear'), n_features_to_select=18000)

# %%
# Transform the training and test sets to include only the selected features
x_train_rfe_miRNA = rfe.transform(X_train)
x_test_rfe_miRNA = rfe.transform(X_test)

# %%
print(x_test_rfe_miRNA.shape)
print(x_train_rfe_miRNA.shape)
# Out:
# (202, 300)
# (469, 300)

# %% [markdown]
# ### Result

# %%
# Convert the transformed arrays back to DataFrames
# Get the selected feature names
selected_features_miRNA = X_train.columns[rfe.support_]

X_train_rfe_miRNA= pd.DataFrame(x_train_rfe_miRNA, columns=selected_features_miRNA, index=X_train.index)
X_test_rfe_miRNA = pd.DataFrame(x_test_rfe_miRNA, columns=selected_features_miRNA, index=X_test.index)

# %%
# Save the dataframes
X_train_rfe_miRNA.to_pickle('X_train_rfe_miRNA.pkl')
X_test_rfe_miRNA.to_pickle('X_test_rfe_miRNA.pkl')

# %%
from google.colab import drive
# Mount Google Drive
drive.mount('/content/gdrive')

X_train_rfe_miRNA.to_pickle('/content/gdrive/My Drive/ColabNotebooks/BioModel_Project/X_train_rfe_miRNA.pkl')
X_test_rfe_miRNA.to_pickle('/content/gdrive/My Drive/ColabNotebooks/BioModel_Project/X_test_rfe_miRNA.pkl')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# ## BRCA_DNA_Methylation

# %% [markdown]
# ###Training of SVM

# %%
train_data, test_data = train_test_split(DNA_Methylation_data,test_size=0.30,random_state=1)
target="Label"
X_train = train_data.select_dtypes(include=["number"]).copy()
y_train_dna = train_data[target]
X_test = test_data.select_dtypes(include=["number"]).copy()
y_test_dna = test_data[target]

# %%
print("X train :", X_train.shape)
print("X test :", X_test.shape)
print("Y train :", y_train_dna.shape)
print("Y test :", y_test_dna.shape)
# Out:
# X train : (469, 19050)
# X test : (202, 19050)
# Y train : (469,)
# Y test : (202,)

# %%
# Define the SVM model
model = SVC(kernel="linear")

# Define RFE with the SVM model, choosing a number of features to select
rfe = RFE(estimator=model, n_features_to_select=19000, step=0.05)

# Fit RFE on the training data
rfe.fit(X_train, y_train_dna)
# Out:
# RFE(estimator=SVC(kernel='linear'), n_features_to_select=19000)

# %%
# Transform the training and test sets to include only the selected features
x_train_rfe_dna = rfe.transform(X_train)
x_test_rfe_dna= rfe.transform(X_test)

# %%
print(x_test_rfe_dna.shape)
print(x_train_rfe_dna.shape)
# Out:
# (202, 19000)
# (469, 19000)

# %% [markdown]
# ### Result

# %%
# Convert the transformed arrays back to DataFrames
# Get the selected feature names
selected_features_dna = X_train.columns[rfe.support_]

X_train_rfe_dna = pd.DataFrame(x_train_rfe_dna, columns=selected_features_dna, index=X_train.index)
X_test_rfe_dna = pd.DataFrame(x_test_rfe_dna, columns=selected_features_dna, index=X_test.index)

# %%
# Save the dataframes
X_train_rfe_dna.to_pickle('X_train_rfe_dna.pkl')
X_test_rfe_dna.to_pickle('X_test_rfe_dna.pkl')

# %%
from google.colab import drive
# Mount Google Drive
drive.mount('/content/gdrive')

X_train_rfe_dna.to_pickle('/content/gdrive/My Drive/ColabNotebooks/BioModel_Project/X_train_rfe_dna.pkl')
X_test_rfe_dna.to_pickle('/content/gdrive/My Drive/ColabNotebooks/BioModel_Project/X_test_rfe_dna.pkl')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# ## BRCA_mRNA

# %% [markdown]
# ###Training of SVM

# %%
train_data, test_data = train_test_split(mrna_data,test_size=0.30,random_state=1)
target="Label"
X_train = train_data.select_dtypes(include=["number"]).copy()
y_train_mrna = train_data[target]
X_test = test_data.select_dtypes(include=["number"]).copy()
y_test_mrna = test_data[target]

# %%
print("X train :", X_train.shape)
print("X test :", X_test.shape)
print("Y train :", y_train_mrna.shape)
print("Y test :", y_test_mrna.shape)
# Out:
# X train : (469, 18207)
# X test : (202, 18207)
# Y train : (469,)
# Y test : (202,)

# %%
y_train_mrna
# Out:
# TCGA.B6.A1KF.01    3
# TCGA.B6.A1KN.01    2
# TCGA.D8.A1X6.01    2
# TCGA.AO.A129.01    3
# TCGA.A2.A3XZ.01    4
#                   ..
# TCGA.AO.A03L.01    1
# TCGA.PE.A5DD.01    1
# TCGA.A7.A0D9.01    1
# TCGA.B6.A0RE.01    3
# TCGA.A2.A0YC.01    1
# Name: Label, Length: 469, dtype: int64

# %%
# Define the SVM model
model = SVC(kernel="linear")

# Define RFE with the SVM model, choosing a number of features to select
rfe = RFE(estimator=model, n_features_to_select=18000, step=0.05)

# Fit RFE on the training data
rfe.fit(X_train, y_train_mrna)
# Out:
# RFE(estimator=SVC(kernel='linear'), n_features_to_select=18000)

# %%
# Transform the training and test sets to include only the selected features
x_train_rfe_mrna = rfe.transform(X_train)
x_test_rfe_mrna = rfe.transform(X_test)

# %%
print(x_test_rfe_mrna.shape)
print(x_train_rfe_mrna.shape)
# Out:
# (202, 18000)
# (469, 18000)

# %% [markdown]
# ### Result

# %%
# Convert the transformed arrays back to DataFrames
# Get the selected feature names
selected_features_mrna = X_train.columns[rfe.support_]

X_train_rfe_mrna = pd.DataFrame(x_train_rfe_mrna, columns=selected_features_mrna, index=X_train.index)
X_test_rfe_mrna = pd.DataFrame(x_test_rfe_mrna, columns=selected_features_mrna, index=X_test.index)

# %%
# Save the dataframes
X_train_rfe_mrna.to_pickle('X_train_rfe_mrna.pkl')
X_test_rfe_mrna.to_pickle('X_test_rfe_mrna.pkl')

# %%
from google.colab import drive
# Mount Google Drive
drive.mount('/content/gdrive')

X_train_rfe_mrna.to_pickle('/content/gdrive/My Drive/ColabNotebooks/BioModel_Project/X_train_rfe_mrna.pkl')
X_test_rfe_mrna.to_pickle('/content/gdrive/My Drive/ColabNotebooks/BioModel_Project/X_test_rfe_mrna.pkl')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## BRCA_Multi_Omics

# %% [markdown]
# ###Training of SVM

# %%
train_data, test_data = train_test_split(multi_omics_data,test_size=0.30,random_state=1)
target="Label"
X_train = train_data.select_dtypes(include=["number"]).copy()
y_train_multi = train_data[target]
X_test = test_data.select_dtypes(include=["number"]).copy()
y_test_multi = test_data[target]

# %%
print("X train :", X_train.shape)
print("X test :", X_test.shape)
print("Y train :", y_train_multi.shape)
print("Y test :", y_test_multi.shape)
# Out:
# X train : (469, 57192)
# X test : (202, 57192)
# Y train : (469,)
# Y test : (202,)

# %%
y_train_multi
# Out:
# TCGA.B6.A1KF.01    3
# TCGA.B6.A1KN.01    2
# TCGA.D8.A1X6.01    2
# TCGA.AO.A129.01    3
# TCGA.A2.A3XZ.01    4
#                   ..
# TCGA.AO.A03L.01    1
# TCGA.PE.A5DD.01    1
# TCGA.A7.A0D9.01    1
# TCGA.B6.A0RE.01    3
# TCGA.A2.A0YC.01    1
# Name: Label, Length: 469, dtype: int64

# %%
# Define the SVM model
model = SVC(kernel="linear")

# Define RFE with the SVM model, choosing a number of features to select
rfe = RFE(estimator=model, n_features_to_select=57000, step=0.05)

# Fit RFE on the training data
rfe.fit(X_train, y_train_multi)
# Out:
# RFE(estimator=SVC(kernel='linear'), n_features_to_select=18000)

# %%
# Transform the training and test sets to include only the selected features
x_train_rfe_multi = rfe.transform(X_train)
x_test_rfe_multi = rfe.transform(X_test)

# %%
print(x_test_rfe_multi.shape)
print(x_train_rfe_multi.shape)
# Out:
# (202, 18000)
# (469, 18000)

# %% [markdown]
# # Without SMOTE
#
# - vae: epoch 15, batch size 128
#
# Results: All omics have same accuracy

# %% [markdown]
# ## BRCA_Copy Number Variation

# %%
X_train_rfe_copy_number_variation = pd.read_pickle('/content/gdrive/My Drive/ColabNotebooks/BioModel_Project/X_train_rfe_copy_number_variation.pkl')
X_test_rfe_copy_number_variation = pd.read_pickle('/content/gdrive/My Drive/ColabNotebooks/BioModel_Project/X_test_rfe_copy_number_variation.pkl')

# %%
X_train_rfe_copy_number_variation.shape
# Out:
# (469, 19000)

# %%
X_test_rfe_copy_number_variation.shape
# Out:
# (202, 19000)

# %% [markdown]
# ### Train the VAE

# %%
# Assume X_train_rfe_copy_number_variation and X_test_rfe_copy_number_variation are your DataFrames
X_train_rfe_copy_number_variation = X_train_rfe_copy_number_variation.to_numpy()
X_test_rfe_copy_number_variation = X_test_rfe_copy_number_variation.to_numpy()

# Normalize the data
scaler = MinMaxScaler()

# Fit the scaler on the training data and transform both training and test data
X_train_rfe_cnv_scaled = scaler.fit_transform(X_train_rfe_copy_number_variation)
X_test_rfe_cnv_scaled = scaler.transform(X_test_rfe_copy_number_variation)

# Define the correct shape
height = 100
width = 190
channels = 1

# Reshape the data
X_train_rfe_copy_number_variation_reshaped = X_train_rfe_cnv_scaled.reshape((469, height, width, channels))
X_test_rfe_copy_number_variation_reshaped = X_test_rfe_cnv_scaled.reshape((202, height, width, channels))


# Define the encoder
class Encoder(tf.keras.Model):
    def __init__(self, latent_dim):
        super(Encoder, self).__init__()
        self.conv1 = layers.Conv2D(16, kernel_size=3, strides=2, padding='same', activation='relu')
        self.conv2 = layers.Conv2D(32, kernel_size=3, strides=2, padding='same', activation='relu')
        self.conv3 = layers.Conv2D(64, kernel_size=3, strides=2, padding='same', activation='relu')
        self.flatten = layers.Flatten()
        self.dense_mean = layers.Dense(latent_dim)
        self.dense_log_var = layers.Dense(latent_dim)
        self.sampling = Sampling()

    def call(self, inputs):
        x = self.conv1(inputs)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.flatten(x)
        z_mean = self.dense_mean(x)
        z_log_var = self.dense_log_var(x)
        z = self.sampling((z_mean, z_log_var))
        return z_mean, z_log_var, z

class Sampling(tf.keras.layers.Layer):
    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# Define the decoder
class Decoder(tf.keras.Model):
    def __init__(self, original_shape):
        super(Decoder, self).__init__()
        self.dense = layers.Dense(100 * 190 * 64, activation='relu')
        self.reshape = layers.Reshape((100, 190, 64))
        # Adjust strides to 1 to avoid doubling the size
        self.deconv1 = layers.Conv2DTranspose(32, kernel_size=3, strides=1, padding='same', activation='relu')
        self.deconv2 = layers.Conv2DTranspose(16, kernel_size=3, strides=1, padding='same', activation='relu')
        self.deconv3 = layers.Conv2DTranspose(1, kernel_size=3, strides=1, padding='same', activation='sigmoid')
        # Remove cropping layer as it's no longer needed
        # self.cropping = layers.Cropping2D(cropping=((0, 0), (1, 1)))

    def call(self, inputs):
        x = self.dense(inputs)
        x = self.reshape(x)
        x = self.deconv1(x)
        x = self.deconv2(x)
        x = self.deconv3(x)
        # Return the output without cropping
        return x # self.cropping(x)

# Define the VAE
class VAE(tf.keras.Model):
    def __init__(self, encoder, decoder):
        super(VAE, self).__init__()
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = tf.keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = tf.keras.metrics.Mean(name="reconstruction_loss")
        self.kl_loss_tracker = tf.keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [self.total_loss_tracker, self.reconstruction_loss_tracker, self.kl_loss_tracker]

    def call(self, inputs):
        z_mean, z_log_var, z = self.encoder(inputs)
        return self.decoder(z)

    def train_step(self, data):
        if isinstance(data, tuple):
            data = data[0]
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            reconstruction_loss = tf.reduce_mean(
                tf.reduce_sum(
                    tf.keras.losses.binary_crossentropy(data, reconstruction),
                    axis=(1, 2)
                )
            )
            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
            total_loss = reconstruction_loss + kl_loss
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }

    def test_step(self, data):
        if isinstance(data, tuple):
            data = data[0]
        z_mean, z_log_var, z = self.encoder(data)
        reconstruction = self.decoder(z)
        reconstruction_loss = tf.reduce_mean(
            tf.reduce_sum(
                tf.keras.losses.binary_crossentropy(data, reconstruction),
                axis=(1, 2)
            )
        )
        return {"reconstruction_loss": reconstruction_loss}

# Initialize the encoder, decoder, and VAE
latent_dim = 64
encoder = Encoder(latent_dim)
decoder = Decoder((100, 190, 1))
vae = VAE(encoder, decoder)

# Compile the VAE
vae.compile(optimizer=tf.keras.optimizers.Adam())

# Train the VAE
vae.fit(X_train_rfe_copy_number_variation_reshaped, X_train_rfe_copy_number_variation_reshaped, epochs=15, batch_size=32, validation_data=(X_test_rfe_copy_number_variation_reshaped, X_test_rfe_copy_number_variation_reshaped))
# Out:
# Epoch 1/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - kl_loss: 13.5241 - loss: 13001.2949 - reconstruction_loss: 12987.7705 - val_reconstruction_loss: 12634.3994
# Epoch 2/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - kl_loss: 14.6579 - loss: 12680.5654 - reconstruction_loss: 12665.9072 - val_reconstruction_loss: 12612.1660
# Epoch 3/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - kl_loss: 14.6640 - loss: 12665.2578 - reconstruction_loss: 12650.5938 - val_reconstruction_loss: 12610.1348
# Epoch 4/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - kl_loss: 15.4490 - loss: 12655.7090 - reconstruction_loss: 12640.2598 - val_reconstruction_loss: 12586.4561
# Epoch 5/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - kl_loss: 19.2987 - loss: 12616.1777 - reconstruction_loss: 12596.8779 - val_reconstruction_loss: 12540.9854
# Epoch 6/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - kl_loss: 23.5453 - loss: 12577.2715 - reconstruction_loss: 12553.7266 - val_reconstruction_loss: 12536.2393
# Epoch 7/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - kl_loss: 27.3248 - loss: 12559.4434 - reconstruction_loss: 12532.1191 - val_reconstruction_loss: 12517.4053
# Epoch 8/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - kl_loss: 33.7431 - loss: 12533.3428 - reconstruction_loss: 12499.5986 - val_reconstruction_loss: 12480.5869
# Epoch 9/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - kl_loss: 37.9583 - loss: 12490.6162 - reconstruction_loss: 12452.6582 - val_reconstruction_loss: 12469.7158
# Epoch 10/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - kl_loss: 42.5583 - loss: 12465.6582 - reconstruction_loss: 12423.1006 - val_reconstruction_loss: 12457.6201
# Epoch 11/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - kl_loss: 45.0006 - loss: 12438.9355 - reconstruction_loss: 12393.9355 - val_reconstruction_loss: 12445.0068
# Epoch 12/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - kl_loss: 49.4364 - loss: 12404.4678 - reconstruction_loss: 12355.0322 - val_reconstruction_loss: 12433.0967
# Epoch 13/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - kl_loss: 54.1968 - loss: 12372.2373 - reconstruction_loss: 12318.0400 - val_reconstruction_loss: 12419.3193
# Epoch 14/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - kl_loss: 59.1604 - loss: 12335.2520 - reconstruction_loss: 12276.0908 - val_reconstruction_loss: 12416.4453
# Epoch 15/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - kl_loss: 58.7354 - loss: 12328.2227 - reconstruction_loss: 12269.4873 - val_reconstruction_loss: 12417.5566

# %%
X_train_rfe_copy_number_variation_reshaped.shape
# Out:
# (469, 100, 190, 1)

# %%
X_test_rfe_copy_number_variation_reshaped.shape
# Out:
# (202, 100, 190, 1)

# %% [markdown]
# ### Evaluate test set

# %%
# Encode the data using the trained VAE encoder
X_train_encoded = encoder.predict(X_train_rfe_copy_number_variation_reshaped)
X_test_encoded = encoder.predict(X_test_rfe_copy_number_variation_reshaped)
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step

# %%
# Ensure the labels are the same length as the encoded data
assert X_train_rfe_copy_number_variation_reshaped.shape[0] == y_train_dna.shape[0], "Mismatch in training data and labels"
assert X_test_rfe_copy_number_variation_reshaped.shape[0] == y_test_dna.shape[0], "Mismatch in testing data and labels"

# %%
# Define a classifier (example: simple MLP classifier)
num_classes = len(np.unique(y_train_copy_number_variation))  # Number of classes in the target

classifier = Sequential([
    Dense(64, activation='relu', input_dim=latent_dim),
    Dropout(0.5),
    Dense(32, activation='relu'),
    Dropout(0.5),
    Dense(num_classes, activation='softmax')  # Softmax for multiclass classification
])

# Compile and train the classifier
classifier.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Define early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10)

classifier.fit(X_train_encoded, y_train_copy_number_variation, epochs=250, batch_size=32, validation_data=(X_test_encoded, y_test_copy_number_variation), callbacks=[early_stopping])

# Predict probabilities
y_pred_prob = classifier.predict(X_test_encoded)

# Convert probabilities to class labels
y_pred = np.argmax(y_pred_prob, axis=1)

# Evaluate the classifier
accuracy = accuracy_score(y_test_copy_number_variation, y_pred)
print(f"Accuracy: {accuracy}")
# Out:
# Epoch 1/250
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 7s 246ms/step - accuracy: 0.2226 - loss: 2.1142 - val_accuracy: 0.4703 - val_loss: 1.3161
# Epoch 2/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.3348 - loss: 1.5647 - val_accuracy: 0.5693 - val_loss: 1.1668
# Epoch 3/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4148 - loss: 1.4200 - val_accuracy: 0.5891 - val_loss: 1.1091
# Epoch 4/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5105 - loss: 1.3006 - val_accuracy: 0.6386 - val_loss: 1.0690
# Epoch 5/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4675 - loss: 1.3362 - val_accuracy: 0.6436 - val_loss: 1.0258
# Epoch 6/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5076 - loss: 1.2663 - val_accuracy: 0.6485 - val_loss: 0.9952
# Epoch 7/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5865 - loss: 1.1167 - val_accuracy: 0.6634 - val_loss: 0.9706
# Epoch 8/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5705 - loss: 1.1133 - val_accuracy: 0.6683 - val_loss: 0.9405
# Epoch 9/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6241 - loss: 1.0579 - val_accuracy: 0.6733 - val_loss: 0.9187
# Epoch 10/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5726 - loss: 1.0431 - val_accuracy: 0.6733 - val_loss: 0.8991
# Epoch 11/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6255 - loss: 0.9815 - val_accuracy: 0.6733 - val_loss: 0.8787
# Epoch 12/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6602 - loss: 0.9595 - val_accuracy: 0.6782 - val_loss: 0.8630
# Epoch 13/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6576 - loss: 0.9718 - val_accuracy: 0.6782 - val_loss: 0.8505
# Epoch 14/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6628 - loss: 0.8921 - val_accuracy: 0.6832 - val_loss: 0.8416
# Epoch 15/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6754 - loss: 0.8683 - val_accuracy: 0.6931 - val_loss: 0.8361
# Epoch 16/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6265 - loss: 0.9365 - val_accuracy: 0.6980 - val_loss: 0.8281
# Epoch 17/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6777 - loss: 0.8418 - val_accuracy: 0.6931 - val_loss: 0.8229
# Epoch 18/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7053 - loss: 0.7953 - val_accuracy: 0.6980 - val_loss: 0.8180
# Epoch 19/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6852 - loss: 0.7774 - val_accuracy: 0.6931 - val_loss: 0.8166
# Epoch 20/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6537 - loss: 0.8459 - val_accuracy: 0.6881 - val_loss: 0.8157
# Epoch 21/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7037 - loss: 0.8163 - val_accuracy: 0.6980 - val_loss: 0.8119
# Epoch 22/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6700 - loss: 0.8041 - val_accuracy: 0.6881 - val_loss: 0.8110
# Epoch 23/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6978 - loss: 0.7868 - val_accuracy: 0.6832 - val_loss: 0.8117
# Epoch 24/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7196 - loss: 0.7599 - val_accuracy: 0.6832 - val_loss: 0.8126
# Epoch 25/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6848 - loss: 0.7532 - val_accuracy: 0.6931 - val_loss: 0.8108
# Epoch 26/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6955 - loss: 0.7634 - val_accuracy: 0.6832 - val_loss: 0.8100
# Epoch 27/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7173 - loss: 0.7137 - val_accuracy: 0.6931 - val_loss: 0.8121
# Epoch 28/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6842 - loss: 0.7388 - val_accuracy: 0.6881 - val_loss: 0.8127
# Epoch 29/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7582 - loss: 0.6561 - val_accuracy: 0.6931 - val_loss: 0.8132
# Epoch 30/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7326 - loss: 0.7185 - val_accuracy: 0.6980 - val_loss: 0.8125
# Epoch 31/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7067 - loss: 0.7175 - val_accuracy: 0.7030 - val_loss: 0.8141
# Epoch 32/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7267 - loss: 0.7016 - val_accuracy: 0.6980 - val_loss: 0.8198
# Epoch 33/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7156 - loss: 0.7698 - val_accuracy: 0.7030 - val_loss: 0.8182
# Epoch 34/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7453 - loss: 0.6584 - val_accuracy: 0.7129 - val_loss: 0.8209
# Epoch 35/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7703 - loss: 0.6577 - val_accuracy: 0.7079 - val_loss: 0.8236
# Epoch 36/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7326 - loss: 0.7376 - val_accuracy: 0.7030 - val_loss: 0.8281
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Accuracy: 0.7029702970297029

# %% [markdown]
# ## BRCA_miRNA

# %%
X_train_rfe_miRNA = pd.read_pickle('/content/gdrive/My Drive/ColabNotebooks/BioModel_Project/X_train_rfe_miRNA.pkl')
X_test_rfe_miRNA = pd.read_pickle('/content/gdrive/My Drive/ColabNotebooks/BioModel_Project/X_test_rfe_miRNA.pkl')

# %%
X_train_rfe_miRNA.shape
# Out:
# (469, 300)

# %%
X_test_rfe_miRNA.shape
# Out:
# (202, 300)

# %% [markdown]
# ### Train the VAE

# %%
# Assume X_train_rfe_miRNA and X_test_rfe_miRNA are your DataFrames
X_train_rfe_miRNA = X_train_rfe_miRNA.to_numpy()
X_test_rfe_miRNA = X_test_rfe_miRNA.to_numpy()

# Normalize the data
scaler = MinMaxScaler()

# Fit the scaler on the training data and transform both training and test data
X_train_rfe_miRNA_scaled = scaler.fit_transform(X_train_rfe_miRNA)
X_test_rfe_miRNA_scaled = scaler.transform(X_test_rfe_miRNA)

# Define the correct shape
height = 10
width = 30
channels = 1

# Reshape the data
X_train_rfe_miRNA_reshaped = X_train_rfe_miRNA_scaled.reshape((469, height, width, channels))
X_test_rfe_miRNA_reshaped = X_test_rfe_miRNA_scaled.reshape((202, height, width, channels))


# Define the encoder
class Encoder(tf.keras.Model):
    def __init__(self, latent_dim):
        super(Encoder, self).__init__()
        self.conv1 = layers.Conv2D(16, kernel_size=3, strides=2, padding='same', activation='relu')
        self.conv2 = layers.Conv2D(32, kernel_size=3, strides=2, padding='same', activation='relu')
        self.conv3 = layers.Conv2D(64, kernel_size=3, strides=2, padding='same', activation='relu')
        self.flatten = layers.Flatten()
        self.dense_mean = layers.Dense(latent_dim)
        self.dense_log_var = layers.Dense(latent_dim)
        self.sampling = Sampling()

    def call(self, inputs):
        x = self.conv1(inputs)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.flatten(x)
        z_mean = self.dense_mean(x)
        z_log_var = self.dense_log_var(x)
        z = self.sampling((z_mean, z_log_var))
        return z_mean, z_log_var, z

class Sampling(tf.keras.layers.Layer):
    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# Define the decoder
class Decoder(tf.keras.Model):
    def __init__(self, original_shape):
        super(Decoder, self).__init__()
        self.dense = layers.Dense(10 * 30 * 64, activation='relu')
        self.reshape = layers.Reshape((10, 30, 64))
        # Adjust strides to 1 to avoid doubling the size
        self.deconv1 = layers.Conv2DTranspose(32, kernel_size=3, strides=1, padding='same', activation='relu')
        self.deconv2 = layers.Conv2DTranspose(16, kernel_size=3, strides=1, padding='same', activation='relu')
        self.deconv3 = layers.Conv2DTranspose(1, kernel_size=3, strides=1, padding='same', activation='sigmoid')
        # Remove cropping layer as it's no longer needed
        # self.cropping = layers.Cropping2D(cropping=((0, 0), (1, 1)))

    def call(self, inputs):
        x = self.dense(inputs)
        x = self.reshape(x)
        x = self.deconv1(x)
        x = self.deconv2(x)
        x = self.deconv3(x)
        # Return the output without cropping
        return x # self.cropping(x)

# Define the VAE
class VAE(tf.keras.Model):
    def __init__(self, encoder, decoder):
        super(VAE, self).__init__()
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = tf.keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = tf.keras.metrics.Mean(name="reconstruction_loss")
        self.kl_loss_tracker = tf.keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [self.total_loss_tracker, self.reconstruction_loss_tracker, self.kl_loss_tracker]

    def call(self, inputs):
        z_mean, z_log_var, z = self.encoder(inputs)
        return self.decoder(z)

    def train_step(self, data):
        if isinstance(data, tuple):
            data = data[0]
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            reconstruction_loss = tf.reduce_mean(
                tf.reduce_sum(
                    tf.keras.losses.binary_crossentropy(data, reconstruction),
                    axis=(1, 2)
                )
            )
            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
            total_loss = reconstruction_loss + kl_loss
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }

    def test_step(self, data):
        if isinstance(data, tuple):
            data = data[0]
        z_mean, z_log_var, z = self.encoder(data)
        reconstruction = self.decoder(z)
        reconstruction_loss = tf.reduce_mean(
            tf.reduce_sum(
                tf.keras.losses.binary_crossentropy(data, reconstruction),
                axis=(1, 2)
            )
        )
        return {"reconstruction_loss": reconstruction_loss}

# Initialize the encoder, decoder, and VAE
latent_dim = 64
encoder = Encoder(latent_dim)
decoder = Decoder((10, 30, 1))
vae = VAE(encoder, decoder)

# Compile the VAE
vae.compile(optimizer=tf.keras.optimizers.Adam())

# Train the VAE
vae.fit(X_train_rfe_miRNA_reshaped, X_train_rfe_miRNA_reshaped, epochs=15, batch_size=32, validation_data=(X_test_rfe_miRNA_reshaped, X_test_rfe_miRNA_reshaped))
# Out:
# Epoch 1/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 18s 397ms/step - kl_loss: 0.0113 - loss: 206.6243 - reconstruction_loss: 206.6130 - val_reconstruction_loss: 203.3167
# Epoch 2/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_loss: 0.0143 - loss: 203.8381 - reconstruction_loss: 203.8238 - val_reconstruction_loss: 201.4429
# Epoch 3/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - kl_loss: 0.0509 - loss: 202.4896 - reconstruction_loss: 202.4387 - val_reconstruction_loss: 201.3434
# Epoch 4/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - kl_loss: 0.1124 - loss: 201.6328 - reconstruction_loss: 201.5204 - val_reconstruction_loss: 200.0423
# Epoch 5/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - kl_loss: 0.4008 - loss: 201.0681 - reconstruction_loss: 200.6673 - val_reconstruction_loss: 199.0435
# Epoch 6/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - kl_loss: 0.5990 - loss: 200.4010 - reconstruction_loss: 199.8020 - val_reconstruction_loss: 198.6400
# Epoch 7/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - kl_loss: 0.7051 - loss: 199.9520 - reconstruction_loss: 199.2468 - val_reconstruction_loss: 197.7252
# Epoch 8/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - kl_loss: 0.7346 - loss: 200.1151 - reconstruction_loss: 199.3805 - val_reconstruction_loss: 197.3951
# Epoch 9/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - kl_loss: 0.8876 - loss: 199.6465 - reconstruction_loss: 198.7589 - val_reconstruction_loss: 197.2155
# Epoch 10/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - kl_loss: 0.8613 - loss: 199.7320 - reconstruction_loss: 198.8707 - val_reconstruction_loss: 197.2369
# Epoch 11/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - kl_loss: 1.0104 - loss: 199.4478 - reconstruction_loss: 198.4374 - val_reconstruction_loss: 196.9118
# Epoch 12/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - kl_loss: 1.1023 - loss: 199.3399 - reconstruction_loss: 198.2376 - val_reconstruction_loss: 199.4666
# Epoch 13/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - kl_loss: 1.0078 - loss: 199.5893 - reconstruction_loss: 198.5815 - val_reconstruction_loss: 197.3160
# Epoch 14/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - kl_loss: 1.0811 - loss: 199.4416 - reconstruction_loss: 198.3606 - val_reconstruction_loss: 197.0651
# Epoch 15/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - kl_loss: 1.1186 - loss: 199.7155 - reconstruction_loss: 198.5969 - val_reconstruction_loss: 196.8032

# %%
X_train_rfe_miRNA_reshaped.shape
# Out:
# (469, 10, 30, 1)

# %%
X_test_rfe_miRNA_reshaped.shape
# Out:
# (202, 10, 30, 1)

# %% [markdown]
# ### Evaluate test set

# %%
# Encode the data using the trained VAE encoder
X_train_encoded = encoder.predict(X_train_rfe_miRNA_reshaped)
X_test_encoded = encoder.predict(X_test_rfe_miRNA_reshaped)
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step

# %%
# Ensure the labels are the same length as the encoded data
assert X_train_rfe_miRNA_reshaped.shape[0] == y_train_miRNA.shape[0], "Mismatch in training data and labels"
assert X_test_rfe_miRNA_reshaped.shape[0] == y_test_miRNA.shape[0], "Mismatch in testing data and labels"

# %%
# Define a classifier (example: simple MLP classifier)
num_classes = len(np.unique(y_train_miRNA))  # Number of classes in the target

classifier = Sequential([
    Dense(64, activation='relu', input_dim=latent_dim),
    Dropout(0.5),
    Dense(32, activation='relu'),
    Dropout(0.5),
    Dense(num_classes, activation='softmax')  # Softmax for multiclass classification
])

# Compile and train the classifier
classifier.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Define early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10)

classifier.fit(X_train_encoded, y_train_miRNA, epochs=250, batch_size=32, validation_data=(X_test_encoded, y_test_miRNA), callbacks=[early_stopping])

# Predict probabilities
y_pred_prob = classifier.predict(X_test_encoded)

# Convert probabilities to class labels
y_pred = np.argmax(y_pred_prob, axis=1)

# Evaluate the classifier
accuracy = accuracy_score(y_test_miRNA, y_pred)
print(f"Accuracy: {accuracy}")
# Out:
# Epoch 1/250
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 8s 290ms/step - accuracy: 0.2268 - loss: 1.6286 - val_accuracy: 0.5891 - val_loss: 1.4579
# Epoch 2/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.5276 - loss: 1.4270 - val_accuracy: 0.6238 - val_loss: 1.2901
# Epoch 3/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6195 - loss: 1.2596 - val_accuracy: 0.6287 - val_loss: 1.1468
# Epoch 4/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6276 - loss: 1.1509 - val_accuracy: 0.6337 - val_loss: 1.0717
# Epoch 5/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6410 - loss: 1.0777 - val_accuracy: 0.6337 - val_loss: 1.0487
# Epoch 6/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6372 - loss: 1.0297 - val_accuracy: 0.6386 - val_loss: 1.0433
# Epoch 7/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6917 - loss: 0.9538 - val_accuracy: 0.6386 - val_loss: 1.0337
# Epoch 8/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6879 - loss: 0.9363 - val_accuracy: 0.6485 - val_loss: 1.0206
# Epoch 9/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7029 - loss: 0.9533 - val_accuracy: 0.6485 - val_loss: 1.0026
# Epoch 10/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6638 - loss: 0.9193 - val_accuracy: 0.6485 - val_loss: 0.9911
# Epoch 11/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.
250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7119 - loss: 0.6980 - val_accuracy: 0.6980 - val_loss: 0.8276
# Epoch 44/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7373 - loss: 0.7176 - val_accuracy: 0.7178 - val_loss: 0.8112
# Epoch 45/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7474 - loss: 0.7371 - val_accuracy: 0.7079 - val_loss: 0.8267
# Epoch 46/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7399 - loss: 0.6998 - val_accuracy: 0.7079 - val_loss: 0.8116
# Epoch 47/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7874 - loss: 0.6510 - val_accuracy: 0.7079 - val_loss: 0.8120
# Epoch 48/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7108 - loss: 0.6956 - val_accuracy: 0.7030 - val_loss: 0.8029
# Epoch 49/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7636 - loss: 0.7037 - val_accuracy: 0.7178 - val_loss: 0.7976
# Epoch 50/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7148 - loss: 0.6902 - val_accuracy: 0.7178 - val_loss: 0.7987
# Epoch 51/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7195 - loss: 0.7188 - val_accuracy: 0.7178 - val_loss: 0.8207
# Epoch 52/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7769 - loss: 0.6865 - val_accuracy: 0.7178 - val_loss: 0.8009
# Epoch 53/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7215 - loss: 0.6799 - val_accuracy: 0.7228 - val_loss: 0.8049
# Epoch 54/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6984 - loss: 0.7407 - val_accuracy: 0.7129 - val_loss: 0.7986
# Epoch 55/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7414 - loss: 0.6967 - val_accuracy: 0.7178 - val_loss: 0.8005
# Epoch 56/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7724 - loss: 0.6236 - val_accuracy: 0.7178 - val_loss: 0.8177
# Epoch 57/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7438 - loss: 0.6647 - val_accuracy: 0.7228 - val_loss: 0.7998
# Epoch 58/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7402 - loss: 0.7076 - val_accuracy: 0.7129 - val_loss: 0.8076
# Epoch 59/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7895 - loss: 0.5663 - val_accuracy: 0.7079 - val_loss: 0.8247
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Accuracy: 0.7079207920792079

# %% [markdown]
# ## BRCA_DNA_Methylation

# %%
X_train_rfe_dna = pd.read_pickle('/content/gdrive/My Drive/ColabNotebooks/BioModel_Project/X_train_rfe_dna.pkl')
X_test_rfe_dna = pd.read_pickle('/content/gdrive/My Drive/ColabNotebooks/BioModel_Project/X_test_rfe_dna.pkl')

# %%
X_train_rfe_dna.shape
# Out:
# (469, 19000)

# %%
X_test_rfe_dna.shape
# Out:
# (202, 19000)

# %% [markdown]
# ### Train the VAE

# %%
# Assume X_train_rfe_dna and X_test_rfe_dna are your DataFrames
X_train_rfe_dna = X_train_rfe_dna.to_numpy()
X_test_rfe_dna = X_test_rfe_dna.to_numpy()

# Normalize the data
scaler = MinMaxScaler()

# Fit the scaler on the training data and transform both training and test data
X_train_rfe_dna_scaled = scaler.fit_transform(X_train_rfe_dna)
X_test_rfe_dna_scaled = scaler.transform(X_test_rfe_dna)

# Define the correct shape
height = 100
width = 190
channels = 1

# Reshape the data
X_train_rfe_dna_reshaped = X_train_rfe_dna_scaled.reshape((469, height, width, channels))
X_test_rfe_dna_reshaped = X_test_rfe_dna_scaled.reshape((202, height, width, channels))


# Define the encoder
class Encoder(tf.keras.Model):
    def __init__(self, latent_dim):
        super(Encoder, self).__init__()
        self.conv1 = layers.Conv2D(16, kernel_size=3, strides=2, padding='same', activation='relu')
        self.conv2 = layers.Conv2D(32, kernel_size=3, strides=2, padding='same', activation='relu')
        self.conv3 = layers.Conv2D(64, kernel_size=3, strides=2, padding='same', activation='relu')
        self.flatten = layers.Flatten()
        self.dense_mean = layers.Dense(latent_dim)
        self.dense_log_var = layers.Dense(latent_dim)
        self.sampling = Sampling()

    def call(self, inputs):
        x = self.conv1(inputs)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.flatten(x)
        z_mean = self.dense_mean(x)
        z_log_var = self.dense_log_var(x)
        z = self.sampling((z_mean, z_log_var))
        return z_mean, z_log_var, z

class Sampling(tf.keras.layers.Layer):
    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# Define the decoder
class Decoder(tf.keras.Model):
    def __init__(self, original_shape):
        super(Decoder, self).__init__()
        self.dense = layers.Dense(100 * 190 * 64, activation='relu')
        self.reshape = layers.Reshape((100, 190, 64))
        # Adjust strides to 1 to avoid doubling the size
        self.deconv1 = layers.Conv2DTranspose(32, kernel_size=3, strides=1, padding='same', activation='relu')
        self.deconv2 = layers.Conv2DTranspose(16, kernel_size=3, strides=1, padding='same', activation='relu')
        self.deconv3 = layers.Conv2DTranspose(1, kernel_size=3, strides=1, padding='same', activation='sigmoid')
        # Remove cropping layer as it's no longer needed
        # self.cropping = layers.Cropping2D(cropping=((0, 0), (1, 1)))

    def call(self, inputs):
        x = self.dense(inputs)
        x = self.reshape(x)
        x = self.deconv1(x)
        x = self.deconv2(x)
        x = self.deconv3(x)
        # Return the output without cropping
        return x # self.cropping(x)

# Define the VAE
class VAE(tf.keras.Model):
    def __init__(self, encoder, decoder):
        super(VAE, self).__init__()
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = tf.keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = tf.keras.metrics.Mean(name="reconstruction_loss")
        self.kl_loss_tracker = tf.keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [self.total_loss_tracker, self.reconstruction_loss_tracker, self.kl_loss_tracker]

    def call(self, inputs):
        z_mean, z_log_var, z = self.encoder(inputs)
        return self.decoder(z)

    def train_step(self, data):
        if isinstance(data, tuple):
            data = data[0]
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            reconstruction_loss = tf.reduce_mean(
                tf.reduce_sum(
                    tf.keras.losses.binary_crossentropy(data, reconstruction),
                    axis=(1, 2)
                )
            )
            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
            total_loss = reconstruction_loss + kl_loss
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }

    def test_step(self, data):
        if isinstance(data, tuple):
            data = data[0]
        z_mean, z_log_var, z = self.encoder(data)
        reconstruction = self.decoder(z)
        reconstruction_loss = tf.reduce_mean(
            tf.reduce_sum(
                tf.keras.losses.binary_crossentropy(data, reconstruction),
                axis=(1, 2)
            )
        )
        return {"reconstruction_loss": reconstruction_loss}

# Initialize the encoder, decoder, and VAE
latent_dim = 64
encoder = Encoder(latent_dim)
decoder = Decoder((100, 190, 1))
vae = VAE(encoder, decoder)

# Compile the VAE
vae.compile(optimizer=tf.keras.optimizers.Adam())

# Train the VAE
vae.fit(X_train_rfe_dna_reshaped, X_train_rfe_dna_reshaped, epochs=15, batch_size=32, validation_data=(X_test_rfe_dna_reshaped, X_test_rfe_dna_reshaped))
# Out:
# Epoch 1/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 12s 401ms/step - kl_loss: 59.0088 - loss: 11871.9932 - reconstruction_loss: 11812.9824 - val_reconstruction_loss: 9648.4053
# Epoch 2/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - kl_loss: 62.9302 - loss: 9631.1396 - reconstruction_loss: 9568.2100 - val_reconstruction_loss: 9528.8125
# Epoch 3/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - kl_loss: 38.9777 - loss: 9502.8105 - reconstruction_loss: 9463.8330 - val_reconstruction_loss: 9517.4844
# Epoch 4/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - kl_loss: 35.8791 - loss: 9465.4951 - reconstruction_loss: 9429.6152 - val_reconstruction_loss: 9451.5469
# Epoch 5/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - kl_loss: 42.3927 - loss: 9451.0117 - reconstruction_loss: 9408.6191 - val_reconstruction_loss: 9395.1338
# Epoch 6/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - kl_loss: 45.9883 - loss: 9376.4385 - reconstruction_loss: 9330.4502 - val_reconstruction_loss: 9347.0928
# Epoch 7/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - kl_loss: 45.7825 - loss: 9263.1055 - reconstruction_loss: 9217.3213 - val_reconstruction_loss: 9216.2832
# Epoch 8/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - kl_loss: 52.9462 - loss: 9192.3115 - reconstruction_loss: 9139.3652 - val_reconstruction_loss: 9202.2334
# Epoch 9/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - kl_loss: 50.4617 - loss: 9184.8633 - reconstruction_loss: 9134.4014 - val_reconstruction_loss: 9141.3916
# Epoch 10/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - kl_loss: 54.9379 - loss: 9125.9072 - reconstruction_loss: 9070.9697 - val_reconstruction_loss: 9123.1797
# Epoch 11/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - kl_loss: 54.9664 - loss: 9128.5361 - reconstruction_loss: 9073.5684 - val_reconstruction_loss: 9134.5869
# Epoch 12/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - kl_loss: 54.0036 - loss: 9083.1660 - reconstruction_loss: 9029.1621 - val_reconstruction_loss: 9093.8896
# Epoch 13/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - kl_loss: 59.1279 - loss: 9024.8936 - reconstruction_loss: 8965.7656 - val_reconstruction_loss: 9099.3750
# Epoch 14/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - kl_loss: 58.2667 - loss: 9034.6113 - reconstruction_loss: 8976.3438 - val_reconstruction_loss: 9086.7373
# Epoch 15/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - kl_loss: 58.4475 - loss: 9063.6484 - reconstruction_loss: 9005.2002 - val_reconstruction_loss: 9076.7920

# %%
X_train_rfe_dna_reshaped.shape
# Out:
# (469, 100, 190, 1)

# %%
X_test_rfe_dna_reshaped.shape
# Out:
# (202, 100, 190, 1)

# %% [markdown]
# ### Evaluate test set

# %%
# Encode the data using the trained VAE encoder
X_train_encoded = encoder.predict(X_train_rfe_dna_reshaped)
X_test_encoded = encoder.predict(X_test_rfe_dna_reshaped)
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step

# %%
# Ensure the labels are the same length as the encoded data
assert X_train_rfe_dna_reshaped.shape[0] == y_train_dna.shape[0], "Mismatch in training data and labels"
assert X_test_rfe_dna_reshaped.shape[0] == y_test_dna.shape[0], "Mismatch in testing data and labels"

# %%
# Define a classifier (example: simple MLP classifier)
num_classes = len(np.unique(y_train_dna))  # Number of classes in the target

classifier = Sequential([
    Dense(64, activation='relu', input_dim=latent_dim),
    Dropout(0.5),
    Dense(32, activation='relu'),
    Dropout(0.5),
    Dense(num_classes, activation='softmax')  # Softmax for multiclass classification
])

# Compile and train the classifier
classifier.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Define early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10)

classifier.fit(X_train_encoded, y_train_dna, epochs=250, batch_size=32, validation_data=(X_test_encoded, y_test_dna), callbacks=[early_stopping])

# Predict probabilities
y_pred_prob = classifier.predict(X_test_encoded)

# Convert probabilities to class labels
y_pred = np.argmax(y_pred_prob, axis=1)

# Evaluate the classifier
accuracy = accuracy_score(y_test_dna, y_pred)
print(f"Accuracy: {accuracy}")
# Out:
# Epoch 1/250
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 9s 344ms/step - accuracy: 0.2017 - loss: 2.2180 - val_accuracy: 0.5743 - val_loss: 1.3174
# Epoch 2/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3715 - loss: 1.5357 - val_accuracy: 0.5842 - val_loss: 1.2047
# Epoch 3/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4734 - loss: 1.3874 - val_accuracy: 0.6485 - val_loss: 1.1102
# Epoch 4/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5326 - loss: 1.2471 - val_accuracy: 0.6584 - val_loss: 1.0229
# Epoch 5/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5504 - loss: 1.1704 - val_accuracy: 0.6733 - val_loss: 0.9750
# Epoch 6/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6280 - loss: 0.9990 - val_accuracy: 0.6832 - val_loss: 0.9275
# Epoch 7/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5887 - loss: 1.0689 - val_accuracy: 0.6832 - val_loss: 0.8948
# Epoch 8/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6278 - loss: 1.0679 - val_accuracy: 0.6881 - val_loss: 0.8645
# Epoch 9/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6410 - loss: 1.0571 - val_accuracy: 0.6980 - val_loss: 0.8474
# Epoch 10/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6532 - loss: 0.9331 - val_accuracy: 0.6782 - val_loss: 0.8348
# Epoch 11/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6661 - loss: 0.8935 - val_accuracy: 0.6881 - val_loss: 0.8116
# Epoch 12/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6722 - loss: 0.8780 - val_accuracy: 0.6832 - val_loss: 0.7893
# Epoch 13/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6750 - loss: 0.8973 - val_accuracy: 0.6832 - val_loss: 0.7813
# Epoch 14/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6767 - loss: 0.8955 - val_accuracy: 0.6931 - val_loss: 0.7757
# Epoch 15/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6836 - loss: 0.8295 - val_accuracy: 0.6980 - val_loss: 0.7552
# Epoch 16/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6557 - loss: 0.8573 - val_accuracy: 0.6980 - val_loss: 0.7567
# Epoch 17/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6936 - loss: 0.8252 - val_accuracy: 0.6832 - val_loss: 0.7409
# Epoch 18/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7145 - loss: 0.7642 - val_accuracy: 0.6931 - val_loss: 0.7299
# Epoch 19/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.
250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7464 - loss: 0.6200 - val_accuracy: 0.7376 - val_loss: 0.6296
# Epoch 84/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7314 - loss: 0.6786 - val_accuracy: 0.7376 - val_loss: 0.6197
# Epoch 85/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7178 - loss: 0.6198 - val_accuracy: 0.7327 - val_loss: 0.6287
# Epoch 86/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7512 - loss: 0.5941 - val_accuracy: 0.7327 - val_loss: 0.6198
# Epoch 87/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7933 - loss: 0.5566 - val_accuracy: 0.7228 - val_loss: 0.6276
# Epoch 88/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7289 - loss: 0.6482 - val_accuracy: 0.7277 - val_loss: 0.6170
# Epoch 89/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8143 - loss: 0.5678 - val_accuracy: 0.7228 - val_loss: 0.6287
# Epoch 90/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7121 - loss: 0.6166 - val_accuracy: 0.7327 - val_loss: 0.6232
# Epoch 91/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7460 - loss: 0.6024 - val_accuracy: 0.7178 - val_loss: 0.6175
# Epoch 92/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7522 - loss: 0.6085 - val_accuracy: 0.7327 - val_loss: 0.6188
# Epoch 93/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7705 - loss: 0.6278 - val_accuracy: 0.7376 - val_loss: 0.6177
# Epoch 94/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7524 - loss: 0.6195 - val_accuracy: 0.7475 - val_loss: 0.6189
# Epoch 95/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7451 - loss: 0.6506 - val_accuracy: 0.7327 - val_loss: 0.6181
# Epoch 96/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7629 - loss: 0.5873 - val_accuracy: 0.7327 - val_loss: 0.6298
# Epoch 97/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7410 - loss: 0.6267 - val_accuracy: 0.7228 - val_loss: 0.6371
# Epoch 98/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7623 - loss: 0.5627 - val_accuracy: 0.7030 - val_loss: 0.6277
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Accuracy: 0.7029702970297029

# %% [markdown]
# ## BRCA_mRNA

# %%
X_train_rfe_mrna = pd.read_pickle('/content/gdrive/My Drive/ColabNotebooks/BioModel_Project/X_train_rfe_mrna.pkl')
X_test_rfe_mrna = pd.read_pickle('/content/gdrive/My Drive/ColabNotebooks/BioModel_Project/X_test_rfe_mrna.pkl')

# %%
X_train_rfe_mrna.shape
# Out:
# (469, 18000)

# %%
X_test_rfe_mrna.shape
# Out:
# (202, 18000)

# %% [markdown]
# ### Train the VAE

# %%
# Assume X_train_rfe_mrna and X_test_rfe_mrna are your DataFrames
X_train_rfe_mrna = X_train_rfe_mrna.to_numpy()
X_test_rfe_mrna = X_test_rfe_mrna.to_numpy()

# Normalize the data
scaler = MinMaxScaler()

# Fit the scaler on the training data and transform both training and test data
X_train_rfe_mrna_scaled = scaler.fit_transform(X_train_rfe_mrna)
X_test_rfe_mrna_scaled = scaler.transform(X_test_rfe_mrna)

# Define the correct shape
height = 100
width = 180
channels = 1

# Reshape the data
X_train_rfe_mrna_reshaped = X_train_rfe_mrna_scaled.reshape((469, height, width, channels))
X_test_rfe_mrna_reshaped = X_test_rfe_mrna_scaled.reshape((202, height, width, channels))


# Define the encoder
class Encoder(tf.keras.Model):
    def __init__(self, latent_dim):
        super(Encoder, self).__init__()
        self.conv1 = layers.Conv2D(16, kernel_size=3, strides=2, padding='same', activation='relu')
        self.conv2 = layers.Conv2D(32, kernel_size=3, strides=2, padding='same', activation='relu')
        self.conv3 = layers.Conv2D(64, kernel_size=3, strides=2, padding='same', activation='relu')
        self.flatten = layers.Flatten()
        self.dense_mean = layers.Dense(latent_dim)
        self.dense_log_var = layers.Dense(latent_dim)
        self.sampling = Sampling()

    def call(self, inputs):
        x = self.conv1(inputs)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.flatten(x)
        z_mean = self.dense_mean(x)
        z_log_var = self.dense_log_var(x)
        z = self.sampling((z_mean, z_log_var))
        return z_mean, z_log_var, z

class Sampling(tf.keras.layers.Layer):
    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# Define the decoder
class Decoder(tf.keras.Model):
    def __init__(self, original_shape):
        super(Decoder, self).__init__()
        self.dense = layers.Dense(100 * 180 * 64, activation='relu')
        self.reshape = layers.Reshape((100, 180, 64))
        # Adjust strides to 1 to avoid doubling the size
        self.deconv1 = layers.Conv2DTranspose(32, kernel_size=3, strides=1, padding='same', activation='relu')
        self.deconv2 = layers.Conv2DTranspose(16, kernel_size=3, strides=1, padding='same', activation='relu')
        self.deconv3 = layers.Conv2DTranspose(1, kernel_size=3, strides=1, padding='same', activation='sigmoid')
        # Remove cropping layer as it's no longer needed
        # self.cropping = layers.Cropping2D(cropping=((0, 0), (1, 1)))

    def call(self, inputs):
        x = self.dense(inputs)
        x = self.reshape(x)
        x = self.deconv1(x)
        x = self.deconv2(x)
        x = self.deconv3(x)
        # Return the output without cropping
        return x # self.cropping(x)

# Define the VAE
class VAE(tf.keras.Model):
    def __init__(self, encoder, decoder):
        super(VAE, self).__init__()
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = tf.keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = tf.keras.metrics.Mean(name="reconstruction_loss")
        self.kl_loss_tracker = tf.keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [self.total_loss_tracker, self.reconstruction_loss_tracker, self.kl_loss_tracker]

    def call(self, inputs):
        z_mean, z_log_var, z = self.encoder(inputs)
        return self.decoder(z)

    def train_step(self, data):
        if isinstance(data, tuple):
            data = data[0]
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            reconstruction_loss = tf.reduce_mean(
                tf.reduce_sum(
                    tf.keras.losses.binary_crossentropy(data, reconstruction),
                    axis=(1, 2)
                )
            )
            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
            total_loss = reconstruction_loss + kl_loss
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }

    def test_step(self, data):
        if isinstance(data, tuple):
            data = data[0]
        z_mean, z_log_var, z = self.encoder(data)
        reconstruction = self.decoder(z)
        reconstruction_loss = tf.reduce_mean(
            tf.reduce_sum(
                tf.keras.losses.binary_crossentropy(data, reconstruction),
                axis=(1, 2)
            )
        )
        return {"reconstruction_loss": reconstruction_loss}

# Initialize the encoder, decoder, and VAE
latent_dim = 64
encoder = Encoder(latent_dim)
decoder = Decoder((100, 180, 1))
vae = VAE(encoder, decoder)

# Compile the VAE
vae.compile(optimizer=tf.keras.optimizers.Adam())

# Train the VAE
vae.fit(X_train_rfe_mrna_reshaped, X_train_rfe_mrna_reshaped, epochs=15, batch_size=32, validation_data=(X_test_rfe_mrna_reshaped, X_test_rfe_mrna_reshaped))
# Out:
# Epoch 1/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - kl_loss: 21.7831 - loss: 11975.3613 - reconstruction_loss: 11953.5771 - val_reconstruction_loss: 11184.4834
# Epoch 2/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - kl_loss: 26.4979 - loss: 11221.6436 - reconstruction_loss: 11195.1455 - val_reconstruction_loss: 11155.1621
# Epoch 3/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - kl_loss: 19.8427 - loss: 11185.0605 - reconstruction_loss: 11165.2188 - val_reconstruction_loss: 11105.6338
# Epoch 4/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - kl_loss: 24.2363 - loss: 11111.1553 - reconstruction_loss: 11086.9199 - val_reconstruction_loss: 10946.8438
# Epoch 5/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - kl_loss: 36.8266 - loss: 11018.0762 - reconstruction_loss: 10981.2500 - val_reconstruction_loss: 10871.3262
# Epoch 6/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - kl_loss: 38.2926 - loss: 10954.3496 - reconstruction_loss: 10916.0557 - val_reconstruction_loss: 10830.4561
# Epoch 7/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - kl_loss: 38.4119 - loss: 10926.5488 - reconstruction_loss: 10888.1377 - val_reconstruction_loss: 10819.5127
# Epoch 8/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - kl_loss: 40.9270 - loss: 10897.9297 - reconstruction_loss: 10857.0020 - val_reconstruction_loss: 10805.2090
# Epoch 9/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - kl_loss: 43.2098 - loss: 10867.6982 - reconstruction_loss: 10824.4883 - val_reconstruction_loss: 10781.9814
# Epoch 10/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - kl_loss: 46.8266 - loss: 10821.9375 - reconstruction_loss: 10775.1113 - val_reconstruction_loss: 10773.0596
# Epoch 11/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step - kl_loss: 49.4607 - loss: 10800.2539 - reconstruction_loss: 10750.7930 - val_reconstruction_loss: 10766.8242
# Epoch 12/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - kl_loss: 52.2230 - loss: 10777.0029 - reconstruction_loss: 10724.7793 - val_reconstruction_loss: 10773.4424
# Epoch 13/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - kl_loss: 52.3264 - loss: 10769.9043 - reconstruction_loss: 10717.5781 - val_reconstruction_loss: 10764.4990
# Epoch 14/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - kl_loss: 55.3732 - loss: 10726.5576 - reconstruction_loss: 10671.1846 - val_reconstruction_loss: 10748.3613
# Epoch 15/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - kl_loss: 59.6367 - loss: 10718.5098 - reconstruction_loss: 10658.8730 - val_reconstruction_loss: 10740.9346

# %%
X_train_rfe_mrna_reshaped.shape
# Out:
# (469, 100, 180, 1)

# %%
X_test_rfe_mrna_reshaped.shape
# Out:
# (202, 100, 180, 1)

# %% [markdown]
# ### Evaluate test set

# %%
# Encode the data using the trained VAE encoder
X_train_encoded = encoder.predict(X_train_rfe_mrna_reshaped)
X_test_encoded = encoder.predict(X_test_rfe_mrna_reshaped)
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 99ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step

# %%
# Ensure the labels are the same length as the encoded data
assert X_train_rfe_mrna_reshaped.shape[0] == y_train_mrna.shape[0], "Mismatch in training data and labels"
assert X_test_rfe_mrna_reshaped.shape[0] == y_test_mrna.shape[0], "Mismatch in testing data and labels"

# %%
# Define a classifier (example: simple MLP classifier)
num_classes = len(np.unique(y_train_mrna))  # Number of classes in the target

classifier = Sequential([
    Dense(64, activation='relu', input_dim=latent_dim),
    Dropout(0.5),
    Dense(32, activation='relu'),
    Dropout(0.5),
    Dense(num_classes, activation='softmax')  # Softmax for multiclass classification
])

# Compile and train the classifier
classifier.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Define early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10)

classifier.fit(X_train_encoded, y_train_mrna, epochs=250, batch_size=32, validation_data=(X_test_encoded, y_test_mrna), callbacks=[early_stopping])

# Predict probabilities
y_pred_prob = classifier.predict(X_test_encoded)

# Convert probabilities to class labels
y_pred = np.argmax(y_pred_prob, axis=1)

# Evaluate the classifier
accuracy = accuracy_score(y_test_mrna, y_pred)
print(f"Accuracy: {accuracy}")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 17s 414ms/step - accuracy: 0.1858 - loss: 1.9776 - val_accuracy: 0.6238 - val_loss: 1.3409
# Epoch 2/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.3871 - loss: 1.4432 - val_accuracy: 0.6683 - val_loss: 1.1466
# Epoch 3/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5009 - loss: 1.3114 - val_accuracy: 0.6683 - val_loss: 1.0185
# Epoch 4/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5529 - loss: 1.1656 - val_accuracy: 0.6733 - val_loss: 0.9318
# Epoch 5/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6117 - loss: 1.0042 - val_accuracy: 0.6782 - val_loss: 0.8585
# Epoch 6/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6623 - loss: 0.9670 - val_accuracy: 0.6782 - val_loss: 0.7999
# Epoch 7/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6316 - loss: 0.9280 - val_accuracy: 0.6980 - val_loss: 0.7612
# Epoch 8/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6634 - loss: 0.8795 - val_accuracy: 0.7129 - val_loss: 0.7284
# Epoch 9/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6667 - loss: 0.8695 - val_accuracy: 0.7426 - val_loss: 0.6978
# Epoch 10/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6907 - loss: 0.8500 - val_accuracy: 0.7426 - val_loss: 0.6744
# Epoch 11/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6930 - loss: 0.8312 - val_accuracy: 0.7426 - val_loss: 0.6547
# Epoch 12/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7582 - loss: 0.6614 - val_accuracy: 0.7475 - val_loss: 0.6402
# Epoch 13/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7082 - loss: 0.8083 - val_accuracy: 0.7525 - val_loss: 0.6257
# Epoch 14/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7341 - loss: 0.7056 - val_accuracy: 0.7673 - val_loss: 0.6113
# Epoch 15/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6885 - loss: 0.7786 - val_accuracy: 0.7723 - val_loss: 0.6055
# Epoch 16/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7557 - loss: 0.6788 - val_accuracy: 0.7822 - val_loss: 0.5913
# Epoch 17/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7737 - loss: 0.6288 - val_accuracy: 0.7921 - val_loss: 0.5796
# Epoch 18/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7457 - loss: 0.6361 - val_accuracy: 0.7921 - val_loss: 0.5657
# Epoch 19/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7824 - loss: 0.6118 - val_accuracy: 0.7970 - val_loss: 0.5559
# Epoch 20/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.
250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8683 - loss: 0.3657 - val_accuracy: 0.7921 - val_loss: 0.4893
# Epoch 53/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8518 - loss: 0.4110 - val_accuracy: 0.8020 - val_loss: 0.4821
# Epoch 54/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8364 - loss: 0.4044 - val_accuracy: 0.8020 - val_loss: 0.4721
# Epoch 55/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8818 - loss: 0.3234 - val_accuracy: 0.8218 - val_loss: 0.4762
# Epoch 56/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8579 - loss: 0.3674 - val_accuracy: 0.8168 - val_loss: 0.4733
# Epoch 57/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8251 - loss: 0.3925 - val_accuracy: 0.8317 - val_loss: 0.4759
# Epoch 58/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8784 - loss: 0.3829 - val_accuracy: 0.8416 - val_loss: 0.4734
# Epoch 59/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8485 - loss: 0.3665 - val_accuracy: 0.8119 - val_loss: 0.4685
# Epoch 60/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8320 - loss: 0.3994 - val_accuracy: 0.7921 - val_loss: 0.4663
# Epoch 61/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8302 - loss: 0.4060 - val_accuracy: 0.8119 - val_loss: 0.4647
# Epoch 62/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8716 - loss: 0.3452 - val_accuracy: 0.8119 - val_loss: 0.4698
# Epoch 63/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8538 - loss: 0.3940 - val_accuracy: 0.8119 - val_loss: 0.4880
# Epoch 64/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8771 - loss: 0.3284 - val_accuracy: 0.8119 - val_loss: 0.4811
# Epoch 65/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8742 - loss: 0.3300 - val_accuracy: 0.8267 - val_loss: 0.4799
# Epoch 66/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8550 - loss: 0.4018 - val_accuracy: 0.8119 - val_loss: 0.4753
# Epoch 67/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8708 - loss: 0.3512 - val_accuracy: 0.8168 - val_loss: 0.4757
# Epoch 68/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8611 - loss: 0.3196 - val_accuracy: 0.8168 - val_loss: 0.4744
# Epoch 69/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8696 - loss: 0.3565 - val_accuracy: 0.8020 - val_loss: 0.4786
# Epoch 70/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8688 - loss: 0.3443 - val_accuracy: 0.8218 - val_loss: 0.4844
# Epoch 71/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8510 - loss: 0.3521 - val_accuracy: 0.8168 - val_loss: 0.4927
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Accuracy: 0.8168316831683168

# %% [markdown]
# ## BRCA_Multi_Omics

# %%
X_train_rfe_multi = pd.read_pickle('/content/gdrive/My Drive/ColabNotebooks/BioModel_Project/X_train_rfe_multi_omics.pkl')
X_test_rfe_multi = pd.read_pickle('/content/gdrive/My Drive/ColabNotebooks/BioModel_Project/X_test_rfe_multi_omics.pkl')

# %%
X_train_rfe_multi.shape
# Out:
# (469, 57000)

# %%
X_test_rfe_multi.shape
# Out:
# (202, 57000)

# %% [markdown]
# ### Train the VAE

# %%
# Assume X_train_rfe_multi and X_test_rfe_multi are your DataFrames
X_train_rfe_multi = X_train_rfe_multi.to_numpy()
X_test_rfe_multi = X_test_rfe_multi.to_numpy()

# Normalize the data
scaler = MinMaxScaler()

# Fit the scaler on the training data and transform both training and test data
X_train_rfe_multi_scaled = scaler.fit_transform(X_train_rfe_multi)
X_test_rfe_multi_scaled = scaler.transform(X_test_rfe_multi)

# Define the correct shape
height = 190
width = 300
channels = 1

# Reshape the data
X_train_rfe_multi_reshaped = X_train_rfe_multi_scaled.reshape((469, height, width, channels))
X_test_rfe_multi_reshaped = X_test_rfe_multi_scaled.reshape((202, height, width, channels))


# Define the encoder
class Encoder(tf.keras.Model):
    def __init__(self, latent_dim):
        super(Encoder, self).__init__()
        self.conv1 = layers.Conv2D(16, kernel_size=3, strides=2, padding='same', activation='relu')
        self.conv2 = layers.Conv2D(32, kernel_size=3, strides=2, padding='same', activation='relu')
        self.conv3 = layers.Conv2D(64, kernel_size=3, strides=2, padding='same', activation='relu')
        self.flatten = layers.Flatten()
        self.dense_mean = layers.Dense(latent_dim)
        self.dense_log_var = layers.Dense(latent_dim)
        self.sampling = Sampling()

    def call(self, inputs):
        x = self.conv1(inputs)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.flatten(x)
        z_mean = self.dense_mean(x)
        z_log_var = self.dense_log_var(x)
        z = self.sampling((z_mean, z_log_var))
        return z_mean, z_log_var, z

class Sampling(tf.keras.layers.Layer):
    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# Define the decoder
class Decoder(tf.keras.Model):
    def __init__(self, original_shape):
        super(Decoder, self).__init__()
        self.dense = layers.Dense(190 * 300 * 64, activation='relu')
        self.reshape = layers.Reshape((190, 300, 64))
        # Adjust strides to 1 to avoid doubling the size
        self.deconv1 = layers.Conv2DTranspose(64, kernel_size=3, strides=1, padding='same', activation='relu')
        self.deconv2 = layers.Conv2DTranspose(32, kernel_size=3, strides=1, padding='same', activation='relu')
        self.deconv3 = layers.Conv2DTranspose(16, kernel_size=3, strides=1, padding='same', activation='relu')
        self.deconv4 = layers.Conv2DTranspose(1, kernel_size=3, strides=1, padding='same', activation='sigmoid')
        # Remove cropping layer as it's no longer needed
        # self.cropping = layers.Cropping2D(cropping=((0, 0), (1, 1)))

    def call(self, inputs):
        x = self.dense(inputs)
        x = self.reshape(x)
        x = self.deconv1(x)
        x = self.deconv2(x)
        x = self.deconv3(x)
        x = self.deconv4(x)
        return x

# Define the VAE
class VAE(tf.keras.Model):
    def __init__(self, encoder, decoder):
        super(VAE, self).__init__()
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = tf.keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = tf.keras.metrics.Mean(name="reconstruction_loss")
        self.kl_loss_tracker = tf.keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [self.total_loss_tracker, self.reconstruction_loss_tracker, self.kl_loss_tracker]

    def call(self, inputs):
        z_mean, z_log_var, z = self.encoder(inputs)
        return self.decoder(z)

    def train_step(self, data):
        if isinstance(data, tuple):
            data = data[0]
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            reconstruction_loss = tf.reduce_mean(
                tf.reduce_sum(
                    tf.keras.losses.binary_crossentropy(data, reconstruction),
                    axis=(1, 2)
                )
            )
            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
            total_loss = reconstruction_loss + kl_loss
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }

    def test_step(self, data):
        if isinstance(data, tuple):
            data = data[0]
        z_mean, z_log_var, z = self.encoder(data)
        reconstruction = self.decoder(z)
        reconstruction_loss = tf.reduce_mean(
            tf.reduce_sum(
                tf.keras.losses.binary_crossentropy(data, reconstruction),
                axis=(1, 2)
            )
        )
        return {"reconstruction_loss": reconstruction_loss}

# Initialize the encoder, decoder, and VAE
latent_dim = 64
encoder = Encoder(latent_dim)
decoder = Decoder((190, 300, 1))
vae = VAE(encoder, decoder)

# Compile the VAE
vae.compile(optimizer=tf.keras.optimizers.Adam())

# Train the VAE
vae.fit(X_train_rfe_multi_reshaped, X_train_rfe_multi_reshaped, epochs=15, batch_size=32, validation_data=(X_test_rfe_multi_reshaped, X_test_rfe_multi_reshaped))
# Out:
# Epoch 1/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 88s 3s/step - kl_loss: 53.4181 - loss: 38262.1641 - reconstruction_loss: 38208.7500 - val_reconstruction_loss: 34532.0859
# Epoch 2/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 351ms/step - kl_loss: 116.3868 - loss: 34600.1758 - reconstruction_loss: 34483.7891 - val_reconstruction_loss: 34102.0898
# Epoch 3/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 10s 346ms/step - kl_loss: 75.5962 - loss: 34169.4805 - reconstruction_loss: 34093.8867 - val_reconstruction_loss: 34063.2500
# Epoch 4/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 10s 344ms/step - kl_loss: 47.0882 - loss: 34072.7891 - reconstruction_loss: 34025.7031 - val_reconstruction_loss: 33958.1641
# Epoch 5/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 10s 344ms/step - kl_loss: 46.8187 - loss: 34016.6523 - reconstruction_loss: 33969.8398 - val_reconstruction_loss: 33850.1875
# Epoch 6/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 10s 349ms/step - kl_loss: 57.8276 - loss: 33846.8438 - reconstruction_loss: 33789.0195 - val_reconstruction_loss: 33695.0273
# Epoch 7/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 10s 356ms/step - kl_loss: 57.4990 - loss: 33642.0898 - reconstruction_loss: 33584.5898 - val_reconstruction_loss: 33537.8242
# Epoch 8/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 10s 351ms/step - kl_loss: 65.2452 - loss: 33524.3164 - reconstruction_loss: 33459.0703 - val_reconstruction_loss: 33459.3867
# Epoch 9/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 10s 363ms/step - kl_loss: 69.4687 - loss: 33389.5742 - reconstruction_loss: 33320.1055 - val_reconstruction_loss: 33310.8125
# Epoch 10/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 10s 353ms/step - kl_loss: 72.5815 - loss: 33350.7422 - reconstruction_loss: 33278.1641 - val_reconstruction_loss: 33206.5625
# Epoch 11/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 10s 355ms/step - kl_loss: 72.8524 - loss: 33279.8828 - reconstruction_loss: 33207.0312 - val_reconstruction_loss: 33150.4531
# Epoch 12/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 10s 359ms/step - kl_loss: 79.2832 - loss: 33158.4023 - reconstruction_loss: 33079.1211 - val_reconstruction_loss: 33133.5195
# Epoch 13/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 10s 349ms/step - kl_loss: 82.1110 - loss: 33068.7969 - reconstruction_loss: 32986.6836 - val_reconstruction_loss: 33102.9375
# Epoch 14/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 10s 350ms/step - kl_loss: 84.4121 - loss: 33099.5391 - reconstruction_loss: 33015.1211 - val_reconstruction_loss: 33073.0742
# Epoch 15/15
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 10s 352ms/step - kl_loss: 89.5571 - loss: 32883.3477 - reconstruction_loss: 32793.7891 - val_reconstruction_loss: 33101.5469

# %%
X_train_rfe_multi_reshaped.shape
# Out:
# (469, 190, 300, 1)

# %%
X_test_rfe_multi_reshaped.shape
# Out:
# (202, 190, 300, 1)

# %% [markdown]
# ### Evaluate test set

# %%
# Encode the data using the trained VAE encoder
X_train_encoded = encoder.predict(X_train_rfe_multi_reshaped)
X_test_encoded = encoder.predict(X_test_rfe_multi_reshaped)
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step

# %%
# Ensure the labels are the same length as the encoded data
assert X_train_rfe_multi_reshaped.shape[0] == y_train_multi.shape[0], "Mismatch in training data and labels"
assert X_test_rfe_multi_reshaped.shape[0] == y_test_multi.shape[0], "Mismatch in testing data and labels"

# %%
# Define a classifier (example: simple MLP classifier)
num_classes = len(np.unique(y_train_multi))  # Number of classes in the target

classifier = Sequential([
    Dense(64, activation='relu', input_dim=latent_dim),
    Dropout(0.5),
    Dense(32, activation='relu'),
    Dropout(0.5),
    Dense(num_classes, activation='softmax')  # Softmax for multiclass classification
])

# Compile and train the classifier
classifier.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Define early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10)

classifier.fit(X_train_encoded, y_train_multi, epochs=250, batch_size=32, validation_data=(X_test_encoded, y_test_multi), callbacks=[early_stopping])

# Predict probabilities
y_pred_prob = classifier.predict(X_test_encoded)

# Convert probabilities to class labels
y_pred = np.argmax(y_pred_prob, axis=1)

# Evaluate the classifier
accuracy = accuracy_score(y_test_multi, y_pred)
print(f"Accuracy: {accuracy}")
# Out:
# Epoch 1/250
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 10s 344ms/step - accuracy: 0.2487 - loss: 2.2412 - val_accuracy: 0.5495 - val_loss: 1.3488
# Epoch 2/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.4386 - loss: 1.5673 - val_accuracy: 0.6040 - val_loss: 1.1664
# Epoch 3/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4945 - loss: 1.3838 - val_accuracy: 0.6733 - val_loss: 1.0636
# Epoch 4/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5164 - loss: 1.2157 - val_accuracy: 0.6733 - val_loss: 0.9604
# Epoch 5/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5887 - loss: 1.1171 - val_accuracy: 0.7228 - val_loss: 0.8964
# Epoch 6/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6219 - loss: 1.0981 - val_accuracy: 0.7228 - val_loss: 0.8320
# Epoch 7/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6113 - loss: 0.9749 - val_accuracy: 0.7327 - val_loss: 0.7881
# Epoch 8/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6870 - loss: 0.9061 - val_accuracy: 0.7277 - val_loss: 0.7483
# Epoch 9/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6982 - loss: 0.8782 - val_accuracy: 0.7228 - val_loss: 0.7167
# Epoch 10/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7126 - loss: 0.8852 - val_accuracy: 0.7327 - val_loss: 0.6953
# Epoch 11/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6660 - loss: 0.9519 - val_accuracy: 0.7277 - val_loss: 0.6688
# Epoch 12/250
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.