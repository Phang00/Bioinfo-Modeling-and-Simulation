# %% [markdown]
# # Import Dataset

# %%
import os
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.feature_selection import RFE
from imblearn.over_sampling import SMOTE
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# %%
### 1. Link notebook with google drive and access data from your personal Gdrive
from google.colab import drive
# Mount Google Drive
drive.mount('/content/gdrive')

### 2.Set the data path for dataset and model location (ex: model_loc = "/content/gdrive/My Drive/Dataset/")
dataset_dir = "/content/gdrive/My Drive/BIOINFORMATICSII/Project/"
model_loc = "/content/gdrive/My Drive/BIOINFORMATICSII/Project/"

print(os.listdir(dataset_dir))
mrna_data = pd.read_csv(dataset_dir+'BRCA_mRNA.csv', index_col=0)
miRNA_data = pd.read_csv(dataset_dir+'BRCA_miRNA.csv', index_col=0)
DNA_Methylation_data = pd.read_csv(dataset_dir+'BRCA_DNA_Methylation.csv', index_col=0)
copy_number_variation_data = pd.read_csv(dataset_dir+'BRCA_Copy Number Variation.csv', index_col=0)
multi_omics_data = pd.read_csv(dataset_dir+'BRCA_Multi_Omics.csv', index_col=0)
brca_Label = pd.read_csv(dataset_dir+'BRCA_label.csv')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# ['BRCA_mRNA.csv', 'BRCA_DNA_Methylation.csv', 'BRCA_miRNA.csv', 'BRCA_Copy Number Variation.csv', 'BRCA_label.csv', 'X_test_rfe_mrna.pkl', 'X_test_rfe_miRNA.pkl', 'X_train_rfe_mrna.pkl', 'X_train_rfe_miRNA.pkl', 'X_train_rfe_dna.pkl', 'X_test_rfe_dna.pkl', 'X_test_rfe_copy_number_variation.pkl', 'X_train_rfe_copy_number_variation.pkl', 'BRCA_Multi_Omics.csv', 'X_test_rfe_multi_omics.pkl', 'X_train_rfe_multi_omics.pkl']

# %% [markdown]
# ###Concatenate Method

# %%
mrna_data.shape
# Out:
# (18206, 671)

# %%
miRNA_data.shape
# Out:
# (368, 671)

# %%
DNA_Methylation_data.shape
# Out:
# (19049, 671)

# %%
copy_number_variation_data.shape
# Out:
# (19568, 671)

# %%
# Concatenate the datasets along the columns
multi = pd.concat([mrna_data, miRNA_data, DNA_Methylation_data, copy_number_variation_data], axis=0)

# %%
multi.shape
# Out:
# (57191, 671)

# %%
# Save the concatenated dataframe to a new CSV file
multi_omics_data.to_csv(dataset_dir + 'BRCA_Multi_Omics.csv')

print('Concatenation complete. The file BRCA_Multi_Omics.csv has been saved.')

# %% [markdown]
# #Data Preprocessing & EDA

# %% [markdown]
# ## BRCA_Copy Number Variation

# %%
copy_number_variation_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19568 entries, A1BG to pk
# Columns: 671 entries, TCGA.3C.AAAU.01 to TCGA.Z7.A8R6.01
# dtypes: float64(671)
# memory usage: 100.3+ MB

# %%
copy_number_variation_data.head(10)
# Out:
#          TCGA.3C.AAAU.01  TCGA.3C.AALI.01  TCGA.3C.AALJ.01  TCGA.3C.AALK.01  \
# A1BG            0.495252         1.028904         0.003059        -0.258705
# A1CF           -0.938762        -1.575977         0.405308         0.096910
# A2M             0.750838         0.010864         0.103201        -0.169130
# A2ML1           0.748593         0.005894         0.098571        -0.174763
# A3GALT2         1.093743        -1.575680        -0.706498         0.199712
# A4GALT         -0.876388        -0.967673        -1.643561         0.570857
# A4GNT           1.109460         1.481901        -0.661117        -0.422884
# AAAS           -1.966983        -0.040373        -1.342185        -0.156210
# AACS           -1.676420        -0.027748         1.469986        -0.017618
# AADAC           1.090124         1.213108        -0.571499        -0.402285
#
#          TCGA.5L.AAT0.01  TCGA.5T.A9QA.01  TCGA.A1.A0SB.01  TCGA.A1.A0SE.01  \
# A1B
CGA.A1.A0SF.01  TCGA.A1.A0SG.01  ...  TCGA.UL.AAZ6.01  \
# A1BG             0.112737        -0.397480  ...        -1.828641
# A1BG.AS1         0.627872         0.426477  ...        -2.123590
# A2M              0.476992         0.147622  ...        -1.493460
# A2M.AS1         -0.092982        -0.666693  ...         0.851988
# A2ML1           -0.408042        -0.457548  ...         0.419145
# A2MP1           -0.264776        -0.343200  ...        -0.814826
# A4GALT           0.676890         1.261371  ...         0.436093
# AAAS             1.583352         0.208439  ...         1.841616
# AACS            -1.331414         0.918643  ...         1.194196
# AADAT           -1.010971        -0.671109  ...         0.511056
#
#           TCGA.UU.A93S.01  TCGA.V7.A7HQ.01  TCGA.W8.A86G.01  TCGA.WT.AB41.01  \
# A1BG             0.756934         1.095019         2.453552        -1.526821
# A1BG.AS1        -0.556860        -1.271019         1.915429        -2.519037
# A2M             -1.848483        -0.608446         0.584722        -0.267116
# A2M.AS1         -2.180389        -1.614497         0.398519        -0.632821
# A2ML1           -0.483924        -0.379297        -0.406793        -0.470376
# A2MP1           -0.889906        -0.577070        -0.209513         1.692166
# A4GALT          -2.023100         1.798225        -0.706899         2.508851
# AAAS            -2.215116         1.540387         1.881914         1.241782
# AACS             1.802331         0.876724        -1.193957        -0.788798
# AADAT           -1.219445        -0.981982        -0.682073        -0.389474
#
#           TCGA.WT.AB44.01  TCGA.XX.A899.01  TCGA.XX.A89A.01  TCGA.Z7.A8R5.01  \
# A1BG             0.108732        -0.219390        -0.112740        -0.920878
# A1BG.AS1        -0.643504         0.082909         0.284536        -0.372892
# A2M             -1.271778         0.780906         0.292935         1.883640
# A2M.AS1         -0.768806         0.200613         0.351478         0.015328
# A2ML1           -0.429807        -0.491028         0.421906        -0.456669
# A2MP1           -0.517498         1.236668         0.277833         2.279637
# A4GALT          -0.148959         0.397136         0.658981         0.319417
# AAAS             1.136479        -0.030975         0.359229         0.667426
# AACS            -1.740086         0.730476        -0.336013        -0.298045
# AADAT           -0.562701        -0.449559        -0.483281        -0.376687
#
#           TCGA.Z7.A8R6.01
# A1BG             0.079873
# A1BG.AS1         0.539919
# A2M             -0.469512
# A2M.AS1         -1.309134
# A2ML1           -0.394471
# A2MP1           -0.730764
# A4GALT           1.304757
# AAAS             0.433323
# AACS            -0.811775
# AADAT           -0.699855
#
# [10 rows x 671 columns]

# %%
# Check if there any null values in the BRCA_mRNA dataset
mrna_data.isnull().any().any()
# Out:
# False

# %% [markdown]
# ## BRCA_label

# %%
brca_Label.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 671 entries, 0 to 670
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Label   671 non-null    object
# dtypes: object(1)
# memory usage: 5.4+ KB

# %%
# BRCA_Copy Number Variation dataset
brca_Label.head(10)
# Out:
#     Label
# 0    LumA
# 1    Her2
# 2    LumB
# 3    LumA
# 4    LumA
# 5    LumB
# 6  Normal
# 7    LumA
# 8    LumA
# 9    LumA

# %%
# check is there any null values in the BRCA_Copy Number Variation dataset
brca_Label.isnull().any().any()
# Out:
# False

# %%
brca_Label.shape
# Out:
# (671, 1)

# %%
label_value_counts = brca_Label['Label'].value_counts()

print(label_value_counts)
# Out:
# Label
# LumA      353
# LumB      132
# Basal     113
# Her2       42
# Normal     31
# Name: count, dtype: int64

# %%
#replace label with numerical data
brca_Label['Label'].replace('Normal', 0 , inplace=True)
brca_Label['Label'].replace('LumA', 1 , inplace=True)
brca_Label['Label'].replace('LumB', 2 , inplace=True)
brca_Label['Label'].replace('Basal', 3 , inplace=True)
brca_Label['Label'].replace('Her2', 4 , inplace=True)

# %%
label_value_counts = brca_Label['Label'].value_counts()

print(label_value_counts)
# Out:
# Label
# 1    353
# 2    132
# 3    113
# 4     42
# 0     31
# Name: count, dtype: int64

# %% [markdown]
# There is no missing values in all dataset

# %% [markdown]
# ## BRCA_Multi_Omics

# %%
multi_omics_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 
#
#          TCGA.Z7.A8R6.01
# A1BG           -0.838154
# A1CF           -0.463861
# A2M            -0.590817
# A2ML1          -0.598003
# A3GALT2        -0.264599
# A4GALT          0.082483
# A4GNT          -0.788319
# AAAS           -0.545733
# AACS           -0.372678
# AADAC          -0.628054
#
# [10 rows x 671 columns]

# %%
# Check if there any null values in the BRCA_mRNA dataset
multi_omics_data.isnull().any().any()
# Out:
# False

# %% [markdown]
# # Data Preparation

# %% [markdown]
# Trasnpose the row and column

# %% [markdown]
# ## BRCA_Copy Number Variation

# %%
# Before transpose
copy_number_variation_data.shape
# Out:
# (19568, 671)

# %%
# Transpose mrna_data
copy_number_variation_data = copy_number_variation_data.transpose()

# %%
# After transpose
copy_number_variation_data.head(10)
# Out:
#                      A1BG      A1CF       A2M     A2ML1   A3GALT2    A4GALT  \
# TCGA.3C.AAAU.01  0.495252 -0.938762  0.750838  0.748593  1.093743 -0.876388
# TCGA.3C.AALI.01  1.028904 -1.575977  0.010864  0.005894 -1.575680 -0.967673
# TCGA.3C.AALJ.01  0.003059  0.405308  0.103201  0.098571 -0.706498 -1.643561
# TCGA.3C.AALK.01 -0.258705  0.096910 -0.169130 -0.174763  0.199712  0.570857
# TCGA.5L.AAT0.01 -0.083232  0.060782 -2.090765 -2.103474  0.376570  0.631333
# TCGA.5T.A9QA.01 -0.486242  2.050968 -0.216362 -0.222169 -2.334753  2.749902
# TCGA.A1.A0SB.01 -0.111192  0.154506 -0.062751 -0.067992  0.400443  0.620683
# TCGA.A1.A0SE.01 -0.102997  0.018894 -0.056368 -0.061585  0.225047  0.497449
# TCGA.A1.A0SF.01  0.687116  1.131535  0.857217  0.855364  1.226264  0.387146
# TCGA.A1.A0SG.01 -0.213873  0.145081 -0.016369 -0.021439  0.390699 -0.143066
#
#                     A4GNT      AAAS      AACS     AADAC  ...     ZWINT  \
# TCGA.3C.AAAU.01  1.109460 -1.966983 -1.676420  1.090124  ... -0.837399
# TCGA.3C.AALI.01  1.481901 -0.040373 -0.027748  1.213108  ... -1.537275
# TCGA.3C.AALJ.01 -0.661117 -1.342185  1.469986 -0.571499  ...  4.165544
# TCGA.3C.AALK.01 -0.422884 -0.156210 -0.017618 -0.402285  ...  0.080744
# TCGA.5L.AAT0.01 -0.350660 -0.101592  0.100904 -0.312965  ...  0.045801
# TCGA.5T.A9QA.01 -0.173333 -0.175416  0.011759 -0.110984  ...  1.970711
# TCGA.A1.A0SB.01 -0.273585  0.005842  0.084190 -0.226338  ...  0.136450
# TCGA.A1.A0SE.01 -0.151234  0.145686 -1.943348 -0.146892  ...  0.005287
# TCGA.A1.A0SF.01 -0.508045  1.277645 -1.716941 -0.444027  ...  1.072825
# TCGA.A1.A0SG.01 -0.384077 -0.019366  0.046708 -0.340793  ...  0.127335
#
#                      ZXDA      ZXDB      ZXDC    ZYG11A    ZYG11B       ZYX  \
# TCGA.3C.AAAU.01  2.020624  1.972719  1.053381  1.254989  1.267331  0.963246
# TCGA.3C.AALI.01  4.002085  3.897638  1.589442 -1.781406 -1.793233  1.446230
# TCGA.3C.AALJ.01 -0.319977 -0.301093 -0.477515 -0.867769 -0.872324  0.039191
# TCGA.3C.AALK.01 -0.316675 -0.297884 -0.267586  0.055935  0.058733 -0.257130
# TCGA.5L.AAT0.01 -0.307593 -0.289062 -0.200167  0.238663  0.242915 -0.185487
# TCGA.5T.A9QA.01 -0.399235 -0.392526 -0.141518 -2.457950 -2.475162 -1.970238
# TCGA.A1.A0SB.01 -0.179623 -0.164744 -0.084514  0.258798  0.263210 -0.112381
# TCGA.A1.A0SE.01 -0.121831 -0.108601  0.039909  0.082111  0.085117 -0.106533
# TCGA.A1.A0SF.01 -0.210171 -0.194420 -0.356381  1.164884  1.176508  0.704939
# TCGA.A1.A0SG.01 -0.254754 -0.237731 -0.196879  0.203426  0.207398 -0.262491
#
#                     ZZEF1      ZZZ3        pk
# TCGA.3C.AAAU.01 -0.580418  1.715811 -0.864183
# TCGA.3C.AALI.01 -0.790000 -1.268621  0.345052
# TCGA.3C.AALJ.01 -1.421040 -0.811368 -1.357237
# TCGA.3C.AALK.01 -1.377441  0.098802  0.042601
# TCGA.5L.AAT0.01 -0.999581  0.204322  0.078553
# TCGA.5T.A9QA.01  1.646581 -1.930651 -6.994250
# TCGA.A1.A0SB.01  0.848410  0.307432  0.189832
# TCGA.A1.A0SE.01 -0.727278  0.230822  0.289698
# TCGA.A1.A0SF.01 -0.501251 -1.278740 -0.088652
# TCGA.A1.A0SG.01  0.866003  0.290087  0.104803
#
# [10 rows x 19568 columns]

# %%
copy_number_variation_data.shape
# Out:
# (671, 19568)

# %%
# Ensure the number of rows in data match with label
if copy_number_variation_data.shape[0] == brca_Label.shape[0]:
    # Add the new column to the transposed DataFrame
    copy_number_variation_data['Label'] = brca_Label['Label'].values
else:
    raise ValueError("The number of rows in must match the number of columns in the transposed df1.")

# %%
copy_number_variation_data.shape
# Out:
# (671, 19569)

# %%
# Check if there any null values in the BRCA_mRNA dataset
copy_number_variation_data.isnull().any().any()
# Out:
# False

# %%
copy_number_variation_data.head(10)
# Out:
#                      A1BG      A1CF       A2M     A2ML1   A3GALT2    A4GALT  \
# TCGA.3C.AAAU.01  0.495252 -0.938762  0.750838  0.748593  1.093743 -0.876388
# TCGA.3C.AALI.01  1.028904 -1.575977  0.010864  0.005894 -1.575680 -0.967673
# TCGA.3C.AALJ.01  0.003059  0.405308  0.103201  0.098571 -0.706498 -1.643561
# TCGA.3C.AALK.01 -0.258705  0.096910 -0.169130 -0.174763  0.199712  0.570857
# TCGA.5L.AAT0.01 -0.083232  0.060782 -2.090765 -2.103474  0.376570  0.631333
# TCGA.5T.A9QA.01 -0.486242  2.050968 -0.216362 -0.222169 -2.334753  2.749902
# TCGA.A1.A0SB.01 -0.111192  0.154506 -0.062751 -0.067992  0.400443  0.620683
# TCGA.A1.A0SE.01 -0.102997  0.018894 -0.056368 -0.061585  0.225047  0.497449
# TCGA.A1.A0SF.01  0.687116  1.131535  0.857217  0.855364  1.226264  0.387146
# TCGA.A1.A0SG.01 -0.213873  0.145081 -0.016369 -0.021439  0.390699 -0.143066
#
#                     A4GNT      AAAS      AACS     AADAC  ...      ZXDA  \
# TCGA.3C.AAAU.01  1.109460 -1.966983 -1.676420  1.090124  ...  2.020624
# TCGA.3C.AALI.01  1.481901 -0.040373 -0.027748  1.213108  ...  4.002085
# TCGA.3C.AALJ.01 -0.661117 -1.342185  1.469986 -0.571499  ... -0.319977
# TCGA.3C.AALK.01 -0.422884 -0.156210 -0.017618 -0.402285  ... -0.316675
# TCGA.5L.AAT0.01 -0.350660 -0.101592  0.100904 -0.312965  ... -0.307593
# TCGA.5T.A9QA.01 -0.173333 -0.175416  0.011759 -0.110984  ... -0.399235
# TCGA.A1.A0SB.01 -0.273585  0.005842  0.084190 -0.226338  ... -0.179623
# TCGA.A1.A0SE.01 -0.151234  0.145686 -1.943348 -0.146892  ... -0.121831
# TCGA.A1.A0SF.01 -0.508045  1.277645 -1.716941 -0.444027  ... -0.210171
# TCGA.A1.A0SG.01 -0.384077 -0.019366  0.046708 -0.340793  ... -0.254754
#
#                      ZXDB      ZXDC    ZYG11A    ZYG11B       ZYX     ZZEF1  \
# TCGA.3C.AAAU.01  1.972719  1.053381  1.254989  1.267331  0.963246 -0.580418
# TCGA.3C.AALI.01  3.897638  1.589442 -1.781406 -1.793233  1.446230 -0.790000
# TCGA.3C.AALJ.01 -0.301093 -0.477515 -0.867769 -0.872324  0.039191 -1.421040
# TCGA.3C.AALK.01 -0.297884 -0.267586  0.055935  0.058733 -0.257130 -1.377441
# TCGA.5L.AAT0.01 -0.289062 -0.200167  0.238663  0.242915 -0.185487 -0.999581
# TCGA.5T.A9QA.01 -0.392526 -0.141518 -2.457950 -2.475162 -1.970238  1.646581
# TCGA.A1.A0SB.01 -0.164744 -0.084514  0.258798  0.263210 -0.112381  0.848410
# TCGA.A1.A0SE.01 -0.108601  0.039909  0.082111  0.085117 -0.106533 -0.727278
# TCGA.A1.A0SF.01 -0.194420 -0.356381  1.164884  1.176508  0.704939 -0.501251
# TCGA.A1.A0SG.01 -0.237731 -0.196879  0.203426  0.207398 -0.262491  0.866003
#
#                      ZZZ3        pk  Label
# TCGA.3C.AAAU.01  1.715811 -0.864183      1
# TCGA.3C.AALI.01 -1.268621  0.345052      4
# TCGA.3C.AALJ.01 -0.811368 -1.357237      2
# TCGA.3C.AALK.01  0.098802  0.042601      1
# TCGA.5L.AAT0.01  0.204322  0.078553      1
# TCGA.5T.A9QA.01 -1.930651 -6.994250      2
# TCGA.A1.A0SB.01  0.307432  0.189832      0
# TCGA.A1.A0SE.01  0.230822  0.289698      1
# TCGA.A1.A0SF.01 -1.278740 -0.088652      1
# TCGA.A1.A0SG.01  0.290087  0.104803      1
#
# [10 rows x 19569 columns]

# %%
print(copy_number_variation_data["Label"].value_counts()[0])
print(copy_number_variation_data["Label"].value_counts()[1])
print(copy_number_variation_data["Label"].value_counts()[2])
print(copy_number_variation_data["Label"].value_counts()[3])
print(copy_number_variation_data["Label"].value_counts()[4])
# Out:
# 31
# 353
# 132
# 113
# 42

# %% [markdown]
# ## BRCA_miRNA

# %%
# Before transpose
miRNA_data.shape
# Out:
# (368, 671)

# %%
# Transpose mrna_data
miRNA_data = miRNA_data.transpose()

# %%
# After transpose
miRNA_data.head(10)
# Out:
#                  hsa.let.7a.1  hsa.let.7a.2  hsa.let.7a.3  hsa.let.7b  \
# TCGA.3C.AAAU.01      0.068317      0.068932      0.073899    0.524562
# TCGA.3C.AALI.01     -0.301684     -0.318009     -0.301310    0.419859
# TCGA.3C.AALJ.01     -0.150810     -0.122747     -0.126333   -0.958939
# TCGA.3C.AALK.01      0.107831      0.097594      0.095545    0.615389
# TCGA.5L.AAT0.01      0.395211      0.412879      0.418441    0.500594
# TCGA.5T.A9QA.01      1.135212      1.140183      1.143605    1.159087
# TCGA.A1.A0SB.01      1.813887      1.790792      1.822272    2.113821
# TCGA.A1.A0SE.01      0.473642      0.442224      0.431312    0.812876
# TCGA.A1.A0SF.01     -0.470612     -0.461217     -0.470734   -0.129307
# TCGA.A1.A0SG.01      0.791968      0.841821      0.805374    0.867411
#
#                  hsa.let.7c  hsa.let.7d  hsa.let.7e  hsa.let.7f.1  \
# TCGA.A1.A0SB.01    0.297224    0.390134     2.106744     0.319827
# TCGA.A1.A0SE.01    0.066368   -0.330246     1.078635     0.089918
# TCGA.A1.A0SF.01    0.268172   -0.481707     1.255710    -0.443763
# TCGA.A1.A0SG.01    0.155349    0.490018    -0.062945     1.220345
#
# [10 rows x 368 columns]

# %%
miRNA_data.shape
# Out:
# (671, 368)

# %%
# Ensure the number of rows in data match with label
if miRNA_data.shape[0] == brca_Label.shape[0]:
    # Add the new column to the transposed DataFrame
    miRNA_data['Label'] = brca_Label['Label'].values
else:
    raise ValueError("The number of rows in must match the number of columns in the transposed df1.")

# %%
miRNA_data.shape
# Out:
# (671, 369)

# %%
# Check if there any null values in the BRCA_mRNA dataset
miRNA_data.isnull().any().any()
# Out:
# False

# %%
miRNA_data.head(10)
# Out:
#                  hsa.let.7a.1  hsa.let.7a.2  hsa.let.7a.3  hsa.let.7b  \
# TCGA.3C.AAAU.01      0.068317      0.068932      0.073899    0.524562
# TCGA.3C.AALI.01     -0.301684     -0.318009     -0.301310    0.419859
# TCGA.3C.AALJ.01     -0.150810     -0.122747     -0.126333   -0.958939
# TCGA.3C.AALK.01      0.107831      0.097594      0.095545    0.615389
# TCGA.5L.AAT0.01      0.395211      0.412879      0.418441    0.500594
# TCGA.5T.A9QA.01      1.135212      1.140183      1.143605    1.159087
# TCGA.A1.A0SB.01      1.813887      1.790792      1.822272    2.113821
# TCGA.A1.A0SE.01      0.473642      0.442224      0.431312    0.812876
# TCGA.A1.A0SF.01     -0.470612     -0.461217     -0.470734   -0.129307
# TCGA.A1.A0SG.01      0.791968      0.841821      0.805374    0.867411
#
#                  hsa.let.7c  hsa.let.7d  hsa.let.7e  hsa.let.7f.1  \
# TCGA.3C.AAAU.01   -1.656853   -0.038283    0.501125     -2.390084
# TCGA.3C.AALI.01   -0.715963    0.460975   -1.999304     -0.659788
# TCGA.3C.AALJ.01   -0.971038    0.866585    2.074809      1.080746
# TCGA.3C.AALK.01    0.711952   -0.454282    0.227441     -0.735552
# TCGA.5L.AAT0.01    0.426323   -1.545556   -0.952282     -0.280966
# TCGA.5T.A9QA.01   -1.058870    0.348033    1.610267     -0.141723
# TCGA.A1.A0SB.01    2.135373    1.844765   -0.469603      0.837358
# TCGA.A1.A0SE.01    1.031809   -0.453824   -0.611333      0.169462
# TCGA.A1.A0SF.01    0.864211   -1.070594   -0.571769     -0.000266
# TCGA.A1.A0SG.01    0.071249    0.499824    0.505744      0.859450
#
#                  hsa.let.7f.2  hsa.let.7g  ...  hsa.mir.937  hsa.mir.939  \
# TCGA.3C.AAAU.01     -2.406331   -0.760042  ...     0.108421     0.179279
# TCGA.3C.AALI.01     -0.651943   -1.050266  ...     0.569264     0.188875
# TCGA.3C.AALJ.01      1.088164    0.523204  ...     1.952380    -1.226285
# TCGA.3C.AALK.01     -0.686623   -1.015715  ...     0.119549    -0.340371
# TCGA.5L.AAT0.01     -0.233746   -0.818574  ...    -0.248950    -1.439120
# TCGA.5T.A9QA.01     -0.152147    1.243074  ...    -0.531098    -0.001485
# TCGA.A1.A0SB.01      0.798862    2.111705  ...    -1.000344    -0.912012
# TCGA.A1.A0SE.01      0.184119   -0.511843  ...    -1.280723    -0.332270
# TCGA.A1.A0SF.01      0.041877   -1.315689  ...    -1.139447    -0.259122
# TCGA.A1.A0SG.01      0.851887    0.162780  ...     1.512383    -1.105097
#
#                  hsa.mir.940  hsa.mir.942  hsa.mir.95  hsa.mir.96  hsa.mir.98  \
# TCGA.3C.AAAU.01     1.768897     0.226659    0.943346    1.552613   -0.143572
# TCGA.3C.AALI.01    -0.453994     0.804807   -0.828843    0.599794    1.103662
# TCGA.3C.AALJ.01    -0.281690    -0.314543   -0.487207    1.261482    1.940594
# TCGA.3C.AALK.01    -0.586990    -0.364370   -0.539524    0.856983   -0.831098
# TCGA.5L.AAT0.01    -0.707823    -0.109361   -0.490655    1.188748   -0.885905
# TCGA.5T.A9QA.01    -0.042380     2.139282    1.716711    0.375870   -0.922881
# TCGA.A1.A0SB.01    -0.327511     0.306851   -0.311971    0.297224    0.390134
# TCGA.A1.A0SE.01    -0.426424    -0.629303   -0.207033    0.066368   -0.330246
# TCGA.A1.A0SF.01    -0.505870    -0.260053   -0.411471    0.268172   -0.481707
# TCGA.A1.A0SG.01     0.315259    -0.420010    1.331634    0.155349    0.490018
#
#                  hsa.mir.99a  hsa.mir.99b  Label
# TCGA.3C.AAAU.01    -1.251868     1.603022      1
# TCGA.3C.AALI.01    -0.627587    -1.506825      4
# TCGA.3C.AALJ.01    -0.848552     0.787948      2
# TCGA.3C.AALK.01     0.936474     0.030739      1
# TCGA.5L.AAT0.01     0.449284    -0.645458      1
# TCGA.5T.A9QA.01    -1.316179     0.931785      2
# TCGA.A1.A0SB.01     2.106744     0.319827      0
# TCGA.A1.A0SE.01     1.078635     0.089918      1
# TCGA.A1.A0SF.01     1.255710    -0.443763      1
# TCGA.A1.A0SG.01    -0.062945     1.220345      1
#
# [10 rows x 369 columns]

# %%
print(miRNA_data["Label"].value_counts()[0])
print(miRNA_data["Label"].value_counts()[1])
print(miRNA_data["Label"].value_counts()[2])
print(miRNA_data["Label"].value_counts()[3])
print(miRNA_data["Label"].value_counts()[4])
# Out:
# 31
# 353
# 132
# 113
# 42

# %% [markdown]
# ## BRCA_DNA_Methylation

# %%
# Before transpose
DNA_Methylation_data.shape
# Out:
# (19049, 671)

# %%
# Transpose mrna_data
DNA_Methylation_data = DNA_Methylation_data.transpose()

# %%
# After transpose
DNA_Methylation_data.head(10)
# Out:
#                      A1BG      A1CF       A2M     A2ML1   A3GALT2    A4GALT  \
# TCGA.3C.AAAU.01 -1.211396 -1.801239 -0.696763  0.832338  0.857098 -0.695053
# TCGA.3C.AALI.01  0.974531 -1.091976 -1.597015  0.758754  0.450506  1.570301
# TCGA.3C.AALJ.01  0.633283 -0.258825 -0.873714  0.753608  0.821330 -0.369450
# TCGA.3C.AALK.01  0.354642  0.344929 -1.080573  0.548382  0.497375  1.342464
# TCGA.5L.AAT0.01 -1.939963 -0.018208 -0.788607  0.589277  0.400632  1.553188
# TCGA.5T.A9QA.01  1.328608 -1.007907 -0.583001  0.870132  1.183863 -0.876086
# TCGA.A1.A0SB.01  0.946010  1.246215 -0.654375 -1.878898 -3.316770 -1.168542
# TCGA.A1.A0SE.01  0.930281  0.360814  0.302439  0.160075  0.227579  1.418889
-0.688724 -0.388183 -0.283091 -0.634965 -0.713563  0.094450
#
#                      ZZZ3        pk  Label
# TCGA.3C.AAAU.01  0.378339  0.032275      1
# TCGA.3C.AALI.01  0.271888 -0.147645      4
# TCGA.3C.AALJ.01 -0.170242  0.748945      2
# TCGA.3C.AALK.01  0.484366  0.173110      1
# TCGA.5L.AAT0.01  0.029261 -0.424061      1
# TCGA.5T.A9QA.01  0.970602  2.038508      2
# TCGA.A1.A0SB.01 -0.468274 -0.932571      0
# TCGA.A1.A0SE.01 -0.221699  0.062171      1
# TCGA.A1.A0SF.01 -0.738370 -0.914940      1
# TCGA.A1.A0SG.01 -0.381204  0.623692      1
#
# [10 rows x 19050 columns]

# %%
print(DNA_Methylation_data["Label"].value_counts()[0])
print(DNA_Methylation_data["Label"].value_counts()[1])
print(DNA_Methylation_data["Label"].value_counts()[2])
print(DNA_Methylation_data["Label"].value_counts()[3])
print(DNA_Methylation_data["Label"].value_counts()[4])
# Out:
# 31
# 353
# 132
# 113
# 42

# %% [markdown]
# ## BRCA_mRNA

# %%
# Before transpose
mrna_data.shape
# Out:
# (18206, 671)

# %%
# Transpose mrna_data
mrna_data = mrna_data.transpose()

# %%
# After transpose
mrna_data.head(10)
# Out:
#                      A1BG  A1BG.AS1       A2M   A2M.AS1     A2ML1     A2MP1  \
# TCGA.3C.AAAU.01  1.389927  0.436758 -0.876187  1.607818 -0.415138 -0.374641
# TCGA.3C.AALI.01  1.522872  1.815091 -0.508085  0.863019 -0.406608 -0.361230
# TCGA.3C.AALJ.01  1.788271  0.580557 -0.258138 -0.491954 -0.455969  0.855983
# TCGA.3C.AALK.01 -0.288543 -0.250194 -0.030804 -0.579638 -0.464938 -0.313092
# TCGA.5L.AAT0.01 -0.462680 -0.091285  0.289970  0.572883 -0.438571 -0.090844
# TCGA.5T.A9QA.01 -0.451169 -0.688598 -1.641876 -0.836306 -0.479607 -1.014920
# TCGA.A1.A0SB.01 -0.805973 -1.037605  1.534552  0.099614 -0.444955  1.384198
# TCGA.A1.A0SE.01 -0.472368  0.658661  0.436717 -0.059346 -0.539629 -0.508012
# TCGA.A1.A0SF.01  0.112737  0.627872  0.476992 -0.092982 -0.408042 -0.264776
# TCGA.A1.A0SG.01 -0.397480  0.426477  0.147622 -0.666693 -0.457548 -0.343200
#
#                    A4GALT      AAAS      AACS     AADAT  ...    ZWILCH  \
# TCGA.3C.AAAU.01 -1.727152 -0.562530  0.225676 -1.337786  ...  0.382250
# TCGA.3C.AALI.01 -0.964244  0.525889 -0.590749 -0.724950  ...  2.927253
# TCGA.3C.AALJ.01  0.750127 -0.401461  1.077314  0.101880  ... -0.381820
# TCGA.3C.AALK.01  0.480557 -0.426938 -0.739098 -0.091341  ... -0.029094
# TCGA.5L.AAT0.01  0.179004  0.685542 -0.623465 -0.421059  ... -0.232629
# TCGA.5T.A9QA.01  0.420826  0.697997  0.669477  1.067540  ...  0.845089
# TCGA.A1.A0SB.01  0.260066  0.127438  1.339599  1.377738  ...  0.051136
# TCGA.A1.A0SE.01  0.058950 -0.117362 -0.443098 -0.566328  ...  0.091780
# TCGA.A1.A0SF.01  0.676890  1.583352 -1.331414 -1.010971  ... -1.173102
# TCGA.A1.A0SG.01  1.261371  0.208439  0.918643 -0.671109  ... -0.699790
#
#                     ZWINT      ZXDA      ZXDB      ZXDC    ZYG11A    ZYG11B  \
# TCGA.3C.AAAU.01  0.445598  2.359316  2.242234  1.190506  1.753777  2.013674
# TCGA.3C.AALI.01  0.455835  0.513900  0.179770  1.588651  1.298863 -0.140439
# TCGA.3C.AALJ.01  1.900756 -0.505798  0.658038 -1.008467  2.105007 -0.334864
# TCGA.3C.AALK.01 -0.210541 -0.185209 -0.066780 -0.759323  0.916528 -0.278901
# TCGA.5L.AAT0.01 -0.709315  0.770811  1.161026  0.369677 -1.152811  0.075213
# TCGA.5T.A9QA.01  1.473857 -0.869225 -0.460787 -0.008572 -1.553161 -1.397447
# TCGA.A1.A0SB.01 -1.227280  0.955570 -0.083160  1.287459 -1.086313  1.450555
# TCGA.A1.A0SE.01  0.231947  0.830896  0.605248 -0.282021 -0.380918  0.230984
# TCGA.A1.A0SF.01 -0.059546  0.746254  0.158860 -0.112952  0.077010  0.050613
# TCGA.A1.A0SG.01 -0.359577 -0.703121 -0.338345  0.205879 -1.682207 -0.605257
#
#                       ZYX     ZZEF1      ZZZ3
# TCGA.3C.AAAU.01 -0.424991  1.214399  1.667340
# TCGA.3C.AALI.01  0.635518  0.302547 -1.162286
# TCGA.3C.AALJ.01  0.573943 -0.379244 -0.547104
# TCGA.3C.AALK.01  0.515520 -0.939663  0.057166
# TCGA.5L.AAT0.01 -0.100236 -0.485591  1.268702
# TCGA.5T.A9QA.01 -0.472842  0.190737 -0.622851
# TCGA.A1.A0SB.01  1.176967  1.560267  0.954347
# TCGA.A1.A0SE.01 -0.169919 -0.492343  0.581995
# TCGA.A1.A0SF.01  0.889745 -0.513877 -1.422932
# TCGA.A1.A0SG.01 -0.606344  1.306838 -1.189883
#
# [10 rows x 18206 columns]

# %%
mrna_data.shape
# Out:
# (671, 18206)

# %%
brca_Label.shape
# Out:
# (671, 1)

# %%
# Ensure the number of rows in data match with label
if mrna_data.shape[0] == brca_Label.shape[0]:
    # Add the new column to the transposed DataFrame
    mrna_data['Label'] = brca_Label['Label'].values
else:
    raise ValueError("The number of rows in must match the number of columns in the transposed df1.")

# %%
mrna_data.shape
# Out:
# (671, 18207)

# %%
# Check if there any null values in the BRCA_mRNA dataset
mrna_data.isnull().any().any()
# Out:
# False

# %%
mrna_data.head(10)
# Out:
#                      A1BG  A1BG.AS1       A2M   A2M.AS1     A2ML1     A2MP1  \
# TCGA.3C.AAAU.01  1.389927  0.436758 -0.876187  1.607818 -0.415138 -0.374641
# TCGA.3C.AALI.01  1.522872  1.815091 -0.508085  0.863019 -0.406608 -0.361230
# TCGA.3C.AALJ.01  1.788271  0.580557 -0.258138 -0.491954 -0.455969  0.855983
# TCGA.3C.AALK.01 -0.288543 -0.250194 -0.030804 -0.579638 -0.464938 -0.313092
# TCGA.5L.AAT0.01 -0.462680 -0.091285  0.289970  0.572883 -0.438571 -0.090844
# TCGA.5T.A9QA.01 -0.451169 -0.688598 -1.641876 -0.836306 -0.479607 -1.014920
# TCGA.A1.A0SB.01 -0.805973 -1.037605  1.534552  0.099614 -0.444955  1.384198
# TCGA.A1.A0SE.01 -0.472368  0.658661  0.436717 -0.059346 -0.539629 -0.508012
# TCGA.A1.A0SF.01  0.112737  0.627872  0.476992 -0.092982 -0.408042 -0.264776
# TCGA.A1.A0SG.01 -0.397480  0.426477  0.147622 -0.666693 -0.457548 -0.343200
#
#                    A4GALT      AAAS      AACS     AADAT  ...     ZWINT  \
# TCGA.3C.AAAU.01 -1.727152 -0.562530  0.225676 -1.337786  ...  0.445598
# TCGA.3C.AALI.01 -0.964244  0.525889 -0.590749 -0.724950  ...  0.455835
# TCGA.3C.AALJ.01  0.750127 -0.401461  1.077314  0.101880  ...  1.900756
# TCGA.3C.AALK.01  0.480557 -0.426938 -0.739098 -0.091341  ... -0.210541
# TCGA.5L.AAT0.01  0.179004  0.685542 -0.623465 -0.421059  ... -0.709315
# TCGA.5T.A9QA.01  0.420826  0.697997  0.669477  1.067540  ...  1.473857
# TCGA.A1.A0SB.01  0.260066  0.127438  1.339599  1.377738  ... -1.227280
# TCGA.A1.A0SE.01  0.058950 -0.117362 -0.443098 -0.566328  ...  0.231947
# TCGA.A1.A0SF.01  0.676890  1.583352 -1.331414 -1.010971  ... -0.059546
# TCGA.A1.A0SG.01  1.261371  0.208439  0.918643 -0.671109  ... -0.359577
#
#                      ZXDA      ZXDB      ZXDC    ZYG11A    ZYG11B       ZYX  \
# TCGA.3C.AAAU.01  2.359316  2.242234  1.190506  1.753777  2.013674 -0.424991
# TCGA.3C.AALI.01  0.513900  0.179770  1.588651  1.298863 -0.140439  0.635518
# TCGA.3C.AALJ.01 -0.505798  0.658038 -1.008467  2.105007 -0.334864  0.573943
# TCGA.3C.AALK.01 -0.185209 -0.066780 -0.759323  0.916528 -0.278901  0.515520
# TCGA.5L.AAT0.01  0.770811  1.161026  0.369677 -1.152811  0.075213 -0.100236
# TCGA.5T.A9QA.01 -0.869225 -0.460787 -0.008572 -1.553161 -1.397447 -0.472842
# TCGA.A1.A0SB.01  0.955570 -0.083160  1.287459 -1.086313  1.450555  1.176967
# TCGA.A1.A0SE.01  0.830896  0.605248 -0.282021 -0.380918  0.230984 -0.169919
# TCGA.A1.A0SF.01  0.746254  0.158860 -0.112952  0.077010  0.050613  0.889745
# TCGA.A1.A0SG.01 -0.703121 -0.338345  0.205879 -1.682207 -0.605257 -0.606344
#
#                     ZZEF1      ZZZ3  Label
# TCGA.3C.AAAU.01  1.214399  1.667340      1
# TCGA.3C.AALI.01  0.302547 -1.162286      4
# TCGA.3C.AALJ.01 -0.379244 -0.547104      2
# TCGA.3C.AALK.01 -0.939663  0.057166      1
# TCGA.5L.AAT0.01 -0.485591  1.268702      1
# TCGA.5T.A9QA.01  0.190737 -0.622851      2
# TCGA.A1.A0SB.01  1.560267  0.954347      0
# TCGA.A1.A0SE.01 -0.492343  0.581995      1
# TCGA.A1.A0SF.01 -0.513877 -1.422932      1
# TCGA.A1.A0SG.01  1.306838 -1.189883      1
#
# [10 rows x 18207 columns]

# %%
print(mrna_data["Label"].value_counts()[0])
print(mrna_data["Label"].value_counts()[1])
print(mrna_data["Label"].value_counts()[2])
print(mrna_data["Label"].value_counts()[3])
print(mrna_data["Label"].value_counts()[4])
# Out:
# 31
# 353
# 132
# 113
# 42

# %% [markdown]
# ## BRCA_Multi_Omics

# %%
# Before transpose
multi_omics_data.shape
# Out:
# (57191, 671)

# %%
# Transpose mrna_data
multi_omics_data = multi_omics_data.transpose()

# %%
# After transpose
multi_omics_data.head(10)
# Out:
#                      A1BG      A1CF       A2M     A2ML1   A3GALT2    A4GALT  \
# TCGA.3C.AAAU.01  0.495252 -0.938762  0.750838  0.748593  1.093743 -0.876388
# TCGA.3C.AALI.01  1.028904 -1.575977  0.010864  0.005894 -1.575680 -0.967673
# TCGA.3C.AALJ.01  0.003059  0.405308  0.103201  0.098571 -0.706498 -1.643561
# TCGA.3C.AALK.01 -0.258705  0.096910 -0.169130 -0.174763  0.199712  0.570857
# TCGA.5L.AAT0.01 -0.083232  0.060782 -2.090765 -2.103474  0.376570  0.631333
# TCGA.5T.A9QA.01 -0.486242  2.050968 -0.216362 -0.222169 -2.334753  2.749902
# TCGA.A1.A0SB.01 -0.111192  0.154506 -0.062751 -0.067992  0.400443  0.620683
# TCGA.A1.A0SE.01 -0.102997  0.018894 -0.056368 -0.061585  0.225047  0.497449
# TCGA.A1.A0SF.01  0.687116  1.131535  0.857217  0.855364  1.226264  0.387146
# TCGA.A1.A0SG.01 -0.213873  0.145081 -0.016369 -0.021439  0.390699 -0.143066
#
#                     A4GNT      AAAS      AACS     AADAC  ...     ZWINT  \
# TCGA.3C.AAAU.01  1.109460 -1.966983 -1.676420  1.090124  ...  0.835761
# TCGA.3C.AALI.01  1.481901 -0.040373 -0.027748  1.213108  ...  0.664052
# TCGA.3C.AALJ.01 -0.661117 -1.342185  1.469986 -0.571499  ... -0.092097
# TCGA.3C.AALK.01 -0.422884 -0.156210 -0.017618 -0.402285  ...  0.277971
# TCGA.5L.AAT0.01 -0.350660 -0.101592  0.100904 -0.312965  ... -0.008991
# TCGA.5T.A9QA.01 -0.173333 -0.175416  0.011759 -0.110984  ...  0.351988
# TCGA.A1.A0SB.01 -0.273585  0.005842  0.084190 -0.226338  ... -0.268241
# TCGA.A1.A0SE.01 -0.151234  0.145686 -1.943348 -0.146892  ... -0.279765
# TCGA.A1.A0SF.01 -0.508045  1.277645 -1.716941 -0.444027  ... -0.642373
# TCGA.A1.A0SG.01 -0.384077 -0.019366  0.046708 -0.340793  ... -0.883780
#
#                      ZXDA      ZXDB      ZXDC    ZYG11A    ZYG11B       ZYX  \
# TCGA.3C.AAAU.01 -2.172061 -0.184735  0.821827 -0.842599  1.079773  0.780058
# TCGA.3C.AALI.01 -0.897618 -1.043726  0.746737 -0.188174  1.107008  0.404568
# TCGA.3C.AALJ.01 -0.403899  0.163509  0.991162 -0.337345  1.143368 -0.583163
# TCGA.3C.AALK.01  0.752473  0.722295  0.352692 -0.606283  1.327138  0.047150
# TCGA.5L.AAT0.01  0.693802  0.211610  0.025049 -0.391619  0.825476  0.272223
# TCGA.5T.A9QA.01  1.575007  1.176298  0.677674  5.591173  1.014806  1.304881
# TCGA.A1.A0SB.01  0.144638  0.958181 -0.756234 -1.033358 -0.726589 -0.084193
# TCGA.A1.A0SE.01  0.158648 -0.079927 -0.148292 -0.781399  0.116715 -0.078364
# TCGA.A1.A0SF.01 -0.263347 -0.086925 -0.473521 -0.112660 -0.967701 -0.585443
# TCGA.A1.A0SG.01  0.150851 -0.688724 -0.388183 -0.283091 -0.634965 -0.713563
#
#                     ZZEF1      ZZZ3        pk
# TCGA.3C.AAAU.01  0.747015  0.378339  0.032275
# TCGA.3C.AALI.01  0.107306  0.271888 -0.147645
# TCGA.3C.AALJ.01  0.034379 -0.170242  0.748945
# TCGA.3C.AALK.01  0.014622  0.484366  0.173110
# TCGA.5L.AAT0.01  0.298979  0.029261 -0.424061
# TCGA.5T.A9QA.01  1.151613  0.970602  2.038508
# TCGA.A1.A0SB.01 -0.621557 -0.468274 -0.932571
# TCGA.A1.A0SE.01 -0.887355 -0.221699  0.062171
# TCGA.A1.A0SF.01 -0.625655 -0.738370 -0.914940
# TCGA.A1.A0SG.01  0.094450 -0.381204  0.623692
#
# [10 rows x 57191 columns]

# %%
multi_omics_data.shape
# Out:
# (671, 57191)

# %%
brca_Label.shape
# Out:
# (671, 1)

# %%
# Ensure the number of rows in data match with label
if multi_omics_data.shape[0] == brca_Label.shape[0]:
    # Add the new column to the transposed DataFrame
    multi_omics_data['Label'] = brca_Label['Label'].values
else:
    raise ValueError("The number of rows in must match the number of columns in the transposed df1.")

# %%
multi_omics_data.shape
# Out:
# (671, 57192)

# %%
# Check if there any null values in the BRCA_mRNA dataset
multi_omics_data.isnull().any().any()
# Out:
# False

# %%
multi_omics_data.head(10)
# Out:
#                      A1BG      A1CF       A2M     A2ML1   A3GALT2    A4GALT  \
# TCGA.3C.AAAU.01  0.495252 -0.938762  0.750838  0.748593  1.093743 -0.876388
# TCGA.3C.AALI.01  1.028904 -1.575977  0.010864  0.005894 -1.575680 -0.967673
# TCGA.3C.AALJ.01  0.003059  0.405308  0.103201  0.098571 -0.706498 -1.643561
# TCGA.3C.AALK.01 -0.258705  0.096910 -0.169130 -0.174763  0.199712  0.570857
# TCGA.5L.AAT0.01 -0.083232  0.060782 -2.090765 -2.103474  0.376570  0.631333
# TCGA.5T.A9QA.01 -0.486242  2.050968 -0.216362 -0.222169 -2.334753  2.749902
# TCGA.A1.A0SB.01 -0.111192  0.154506 -0.062751 -0.067992  0.400443  0.620683
# TCGA.A1.A0SE.01 -0.102997  0.018894 -0.056368 -0.061585  0.225047  0.497449
# TCGA.A1.A0SF.01  0.687116  1.131535  0.857217  0.855364  1.226264  0.387146
# TCGA.A1.A0SG.01 -0.213873  0.145081 -0.016369 -0.021439  0.390699 -0.143066
#
#                     A4GNT      AAAS      AACS     AADAC  ...      ZXDA  \
# TCGA.3C.AAAU.01  1.109460 -1.966983 -1.676420  1.090124  ... -2.172061
# TCGA.3C.AALI.01  1.481901 -0.040373 -0.027748  1.213108  ... -0.897618
# TCGA.3C.AALJ.01 -0.661117 -1.342185  1.469986 -0.571499  ... -0.403899
# TCGA.3C.AALK.01 -0.422884 -0.156210 -0.017618 -0.402285  ...  0.752473
# TCGA.5L.AAT0.01 -0.350660 -0.101592  0.100904 -0.312965  ...  0.693802
# TCGA.5T.A9QA.01 -0.173333 -0.175416  0.011759 -0.110984  ...  1.575007
# TCGA.A1.A0SB.01 -0.273585  0.005842  0.084190 -0.226338  ...  0.144638
# TCGA.A1.A0SE.01 -0.151234  0.145686 -1.943348 -0.146892  ...  0.158648
# TCGA.A1.A0SF.01 -0.508045  1.277645 -1.716941 -0.444027  ... -0.263347
# TCGA.A1.A0SG.01 -0.384077 -0.019366  0.046708 -0.340793  ...  0.150851
#
#                      ZXDB      ZXDC    ZYG11A    ZYG11B       ZYX     ZZEF1  \
# TCGA.3C.AAAU.01 -0.184735  0.821827 -0.842599  1.079773  0.780058  0.747015
# TCGA.3C.AALI.01 -1.043726  0.746737 -0.188174  1.107008  0.404568  0.107306
# TCGA.3C.AALJ.01  0.163509  0.991162 -0.337345  1.143368 -0.583163  0.034379
# TCGA.3C.AALK.01  0.722295  0.352692 -0.606283  1.327138  0.047150  0.014622
# TCGA.5L.AAT0.01  0.211610  0.025049 -0.391619  0.825476  0.272223  0.298979
# TCGA.5T.A9QA.01  1.176298  0.677674  5.591173  1.014806  1.304881  1.151613
# TCGA.A1.A0SB.01  0.958181 -0.756234 -1.033358 -0.726589 -0.084193 -0.621557
# TCGA.A1.A0SE.01 -0.079927 -0.148292 -0.781399  0.116715 -0.078364 -0.887355
# TCGA.A1.A0SF.01 -0.086925 -0.473521 -0.112660 -0.967701 -0.585443 -0.625655
# TCGA.A1.A0SG.01 -0.688724 -0.388183 -0.283091 -0.634965 -0.713563  0.094450
#
#                      ZZZ3        pk   Label
# TCGA.3C.AAAU.01  0.378339  0.032275    LumA
# TCGA.3C.AALI.01  0.271888 -0.147645    Her2
# TCGA.3C.AALJ.01 -0.170242  0.748945    LumB
# TCGA.3C.AALK.01  0.484366  0.173110    LumA
# TCGA.5L.AAT0.01  0.029261 -0.424061    LumA
# TCGA.5T.A9QA.01  0.970602  2.038508    LumB
# TCGA.A1.A0SB.01 -0.468274 -0.932571  Normal
# TCGA.A1.A0SE.01 -0.221699  0.062171    LumA
# TCGA.A1.A0SF.01 -0.738370 -0.914940    LumA
# TCGA.A1.A0SG.01 -0.381204  0.623692    LumA
#
# [10 rows x 57192 columns]

# %%
print(multi_omics_data["Label"].value_counts()[0])
print(multi_omics_data["Label"].value_counts()[1])
print(multi_omics_data["Label"].value_counts()[2])
print(multi_omics_data["Label"].value_counts()[3])
print(multi_omics_data["Label"].value_counts()[4])
# Out:
# 353
# 132
# 113
# 42
# 31

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ## BRCA_Copy Number Variation

# %% [markdown]
# ###Training of SVM

# %%
varNumber_train_data, varNumber_test_data = train_test_split(copy_number_variation_data,test_size=0.30,random_state=1)
target="Label"
varNumber_X_train = varNumber_train_data.select_dtypes(include=["number"]).copy()
varNumber_y_train = varNumber_train_data[target]
varNumber_X_test = varNumber_test_data.select_dtypes(include=["number"]).copy()
varNumber_y_test = varNumber_test_data[target]

# %%
print("X train :", varNumber_X_train.shape)
print("X test :", varNumber_X_test.shape)
print("Y train :", varNumber_y_train.shape)
print("Y test :", varNumber_y_test.shape)
# Out:
# X train : (469, 19569)
# X test : (202, 19569)
# Y train : (469,)
# Y test : (202,)

# %%
# Define the SVM model
model = SVC(kernel="linear")

# Define RFE with the SVM model, choosing a number of features to select
rfe = RFE(estimator=model, n_features_to_select=19000, step=0.05)

# Fit RFE on the training data
rfe.fit(varNumber_X_train, varNumber_y_train)
# Out:
# RFE(estimator=SVC(kernel='linear'), n_features_to_select=19000, step=0.05)

# %%
# Transform the training and test sets to include only the selected features
X_train_rfe_varNumber = rfe.transform(varNumber_X_train)
X_test_rfe_varNumber = rfe.transform(varNumber_X_test)

# %%
print(X_train_rfe_varNumber.shape)
print(X_test_rfe_varNumber.shape)
# Out:
# (469, 19000)
# (202, 19000)

# %% [markdown]
# ###Result

# %%
# Convert the transformed arrays back to DataFrames
# Get the selected feature names
selected_features_varNumber = varNumber_X_train.columns[rfe.support_]

X_train_rfe_varNumber= pd.DataFrame(X_train_rfe_varNumber, columns=selected_features_varNumber, index=varNumber_X_train.index)
X_test_rfe_varNumber = pd.DataFrame(X_test_rfe_varNumber, columns=selected_features_varNumber, index=varNumber_X_test.index)

# %%
# Save the dataframes
X_train_rfe_varNumber.to_pickle('X_train_rfe_copy_number_variation.pkl')
X_test_rfe_varNumber.to_pickle('X_test_rfe_copy_number_variation.pkl')

# %%
from google.colab import drive
# Mount Google Drive
drive.mount('/content/gdrive')

X_train_rfe_varNumber.to_pickle('/content/gdrive/My Drive/BIOINFORMATICSII/Project/X_train_rfe_copy_number_variation.pkl')
X_test_rfe_varNumber.to_pickle('/content/gdrive/My Drive/BIOINFORMATICSII/Project/X_test_rfe_copy_number_variation.pkl')

# %% [markdown]
# ## BRCA_miRNA

# %% [markdown]
# ###Training of SVM

# %%
miRNA_train_data, miRNA_test_data = train_test_split(miRNA_data,test_size=0.30,random_state=1)
target="Label"
miRNA_X_train = miRNA_train_data.select_dtypes(include=["number"]).copy()
miRNA_y_train = miRNA_train_data[target]
miRNA_X_test = miRNA_test_data.select_dtypes(include=["number"]).copy()
miRNA_y_test = miRNA_test_data[target]

# %%
print("X train :", miRNA_X_train.shape)
print("X test :", miRNA_X_test.shape)
print("Y train :", miRNA_y_train.shape)
print("Y test :", miRNA_y_test.shape)
# Out:
# X train : (469, 369)
# X test : (202, 369)
# Y train : (469,)
# Y test : (202,)

# %%
# Define the SVM model
model = SVC(kernel="linear")

# Define RFE with the SVM model, choosing a number of features to select
rfe = RFE(estimator=model, n_features_to_select=300, step=0.05)

# Fit RFE on the training data
rfe.fit(miRNA_X_train, miRNA_y_train)
# Out:
# RFE(estimator=SVC(kernel='linear'), n_features_to_select=300, step=0.05)

# %%
# Transform the training and test sets to include only the selected features
x_train_rfe_miRNA = rfe.transform(miRNA_X_train)
x_test_rfe_miRNA = rfe.transform(miRNA_X_test)

# %%
print(x_test_rfe_miRNA.shape)
print(x_train_rfe_miRNA.shape)
# Out:
# (202, 300)
# (469, 300)

# %% [markdown]
# ### Result

# %%
# Convert the transformed arrays back to DataFrames
# Get the selected feature names
selected_features_miRNA = miRNA_X_train.columns[rfe.support_]

X_train_rfe_miRNA= pd.DataFrame(x_train_rfe_miRNA, columns=selected_features_miRNA, index=miRNA_X_train.index)
X_test_rfe_miRNA = pd.DataFrame(x_test_rfe_miRNA, columns=selected_features_miRNA, index=miRNA_X_test.index)

# %%
# Save the dataframes
X_train_rfe_miRNA.to_pickle('X_train_rfe_miRNA.pkl')
X_test_rfe_miRNA.to_pickle('X_test_rfe_miRNA.pkl')

# %%
from google.colab import drive
# Mount Google Drive
drive.mount('/content/gdrive')

X_train_rfe_miRNA.to_pickle('/content/gdrive/My Drive/BIOINFORMATICSII/Project/X_train_rfe_miRNA.pkl')
X_test_rfe_miRNA.to_pickle('/content/gdrive/My Drive/BIOINFORMATICSII/Project/X_test_rfe_miRNA.pkl')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# ## BRCA_DNA_Methylation

# %% [markdown]
# ###Training of SVM

# %%
dna_train_data, dna_test_data = train_test_split(DNA_Methylation_data,test_size=0.30,random_state=1)
target="Label"
dna_X_train = dna_train_data.select_dtypes(include=["number"]).copy()
dna_y_train = dna_train_data[target]
dna_X_test = dna_test_data.select_dtypes(include=["number"]).copy()
dna_y_test = dna_test_data[target]

# %%
print("X train :", dna_X_train.shape)
print("X test :", dna_X_test.shape)
print("Y train :", dna_y_train.shape)
print("Y test :", dna_y_test.shape)
# Out:
# X train : (469, 19050)
# X test : (202, 19050)
# Y train : (469,)
# Y test : (202,)

# %%
# Define the SVM model
model = SVC(kernel="linear")

# Define RFE with the SVM model, choosing a number of features to select
rfe = RFE(estimator=model, n_features_to_select=19000, step=0.05)

# Fit RFE on the training data
rfe.fit(dna_X_train, dna_y_train)
# Out:
# RFE(estimator=SVC(kernel='linear'), n_features_to_select=19000, step=0.05)

# %%
# Transform the training and test sets to include only the selected features
x_train_rfe_dna = rfe.transform(dna_X_train)
x_test_rfe_dna= rfe.transform(dna_X_test)

# %%
print(x_test_rfe_dna.shape)
print(x_train_rfe_dna.shape)
# Out:
# (202, 19000)
# (469, 19000)

# %% [markdown]
# ### Result

# %%
# Convert the transformed arrays back to DataFrames
# Get the selected feature names
selected_features_dna = dna_X_train.columns[rfe.support_]

X_train_rfe_dna = pd.DataFrame(x_train_rfe_dna, columns=selected_features_dna, index=dna_X_train.index)
X_test_rfe_dna = pd.DataFrame(x_test_rfe_dna, columns=selected_features_dna, index=dna_X_test.index)

# %%
# Save the dataframes
X_train_rfe_dna.to_pickle('X_train_rfe_dna.pkl')
X_test_rfe_dna.to_pickle('X_test_rfe_dna.pkl')

# %%
from google.colab import drive
# Mount Google Drive
drive.mount('/content/gdrive')

X_train_rfe_dna.to_pickle('/content/gdrive/My Drive/BIOINFORMATICSII/Project/X_train_rfe_dna.pkl')
X_test_rfe_dna.to_pickle('/content/gdrive/My Drive/BIOINFORMATICSII/Project/X_test_rfe_dna.pkl')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# ## BRCA_mRNA

# %% [markdown]
# ###Training of SVM

# %%
mrna_train_data, mrna_test_data = train_test_split(mrna_data,test_size=0.30,random_state=1)
target="Label"
mrna_X_train = mrna_train_data.select_dtypes(include=["number"]).copy()
mrna_y_train = mrna_train_data[target]
mrna_X_test = mrna_test_data.select_dtypes(include=["number"]).copy()
mrna_y_test = mrna_test_data[target]

# %%
print("X train :", mrna_X_train.shape)
print("X test :", mrna_X_test.shape)
print("Y train :", mrna_y_train.shape)
print("Y test :", mrna_y_test.shape)
# Out:
# X train : (469, 18207)
# X test : (202, 18207)
# Y train : (469,)
# Y test : (202,)

# %%
# Define the SVM model
model = SVC(kernel="linear")

# Define RFE with the SVM model, choosing a number of features to select
rfe = RFE(estimator=model, n_features_to_select=18000, step=0.05)

# Fit RFE on the training data
rfe.fit(mrna_X_train, mrna_y_train)
# Out:
# RFE(estimator=SVC(kernel='linear'), n_features_to_select=18000, step=0.05)

# %%
# Transform the training and test sets to include only the selected features
x_train_rfe_mrna = rfe.transform(mrna_X_train)
x_test_rfe_mrna = rfe.transform(mrna_X_test)

# %%
print(x_test_rfe_mrna.shape)
print(x_train_rfe_mrna.shape)
# Out:
# (202, 18000)
# (469, 18000)

# %% [markdown]
# ### Result

# %%
# Convert the transformed arrays back to DataFrames
# Get the selected feature names
selected_features_mrna = mrna_X_train.columns[rfe.support_]

X_train_rfe_mrna = pd.DataFrame(x_train_rfe_mrna, columns=selected_features_mrna, index=mrna_X_train.index)
X_test_rfe_mrna = pd.DataFrame(x_test_rfe_mrna, columns=selected_features_mrna, index=mrna_X_test.index)

# %%
# Save the dataframes
X_train_rfe_mrna.to_pickle('X_train_rfe_mrna.pkl')
X_test_rfe_mrna.to_pickle('X_test_rfe_mrna.pkl')

# %%
from google.colab import drive
# Mount Google Drive
drive.mount('/content/gdrive')

X_train_rfe_mrna.to_pickle('/content/gdrive/My Drive/BIOINFORMATICSII/Project/X_train_rfe_mrna.pkl')
X_test_rfe_mrna.to_pickle('/content/gdrive/My Drive/BIOINFORMATICSII/Project/X_test_rfe_mrna.pkl')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## BRCA_Multi_Omics

# %% [markdown]
# ###Training of SVM

# %%
multiOmics_train_data, multiOmics_test_data = train_test_split(multi_omics_data,test_size=0.30,random_state=1)
target="Label"
multiOmics_X_train = multiOmics_train_data.select_dtypes(include=["number"]).copy()
multiOmics_y_train = multiOmics_train_data[target]
multiOmics_X_test = multiOmics_test_data.select_dtypes(include=["number"]).copy()
multiOmics_y_test = multiOmics_test_data[target]

# %%
print("X train :", multiOmics_X_train.shape)
print("X test :", multiOmics_X_test.shape)
print("Y train :", multiOmics_y_train.shape)
print("Y test :", multiOmics_y_test.shape)
# Out:
# X train : (469, 57191)
# X test : (202, 57191)
# Y train : (469,)
# Y test : (202,)

# %%
# Define the SVM model
model = SVC(kernel="linear")

# Define RFE with the SVM model, choosing a number of features to select
rfe = RFE(estimator=model, n_features_to_select=57000, step=0.05)

# Fit RFE on the training data
rfe.fit(multiOmics_X_train, multiOmics_y_train)
# Out:
# RFE(estimator=SVC(kernel='linear'), n_features_to_select=57000, step=0.05)

# %%
# Transform the training and test sets to include only the selected features
x_train_rfe_multiOmics = rfe.transform(multiOmics_X_train)
x_test_rfe_multiOmics = rfe.transform(multiOmics_X_test)

# %%
print(x_test_rfe_multiOmics.shape)
print(x_train_rfe_multiOmics.shape)
# Out:
# (202, 57000)
# (469, 57000)

# %% [markdown]
# ###Result

# %%
# Convert the transformed arrays back to DataFrames
# Get the selected feature names
selected_features_multiOmics = multiOmics_X_train.columns[rfe.support_]

x_train_rfe_multiOmics = pd.DataFrame(x_train_rfe_multiOmics, columns=selected_features_multiOmics, index=multiOmics_X_train.index)
x_test_rfe_multiOmics = pd.DataFrame(x_test_rfe_multiOmics, columns=selected_features_multiOmics, index=multiOmics_X_test.index)

# %%
# Save the dataframes
x_train_rfe_multiOmics.to_pickle('X_train_rfe_multi_omics.pkl')
x_test_rfe_multiOmics.to_pickle('X_test_rfe_multi_omics.pkl')

# %%
from google.colab import drive
# Mount Google Drive
drive.mount('/content/gdrive')

x_train_rfe_multiOmics.to_pickle('/content/gdrive/My Drive/BIOINFORMATICSII/Project/X_train_rfe_multi_omics.pkl')
x_test_rfe_multiOmics.to_pickle('/content/gdrive/My Drive/BIOINFORMATICSII/Project/X_test_rfe_multi_omics.pkl')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # With SMOTE

# %%
df1 = pd.read_pickle('/content/gdrive/My Drive/BIOINFORMATICSII/Project/X_train_rfe_mrna.pkl')
df2 = pd.read_pickle('/content/gdrive/My Drive/BIOINFORMATICSII/Project/X_test_rfe_mrna.pkl')

# %%
### 1. Link notebook with google drive and access data from your personal Gdrive
from google.colab import drive
# Mount Google Drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## BRCA_Copy Number Variation

# %%
X_train_rfe_varNumber = pd.read_pickle('/content/gdrive/My Drive/BIOINFORMATICSII/Project/X_train_rfe_copy_number_variation.pkl')
X_test_rfe_varNumber = pd.read_pickle('/content/gdrive/My Drive/BIOINFORMATICSII/Project/X_test_rfe_copy_number_variation.pkl')

# %%
X_test_rfe_varNumber.shape
# Out:
# (202, 19000)

# %%
X_train_rfe_varNumber.shape
# Out:
# (469, 19000)

# %%
varNumber_y_train.shape
# Out:
# (469,)

# %%
#before SMOTE
varNumber_y_train.value_counts()
# Out:
# Label
# 1    245
# 2     96
# 3     82
# 4     25
# 0     21
# Name: count, dtype: int64

# %%
oversample = SMOTE()
X_resampled_varNumber, y_resampled_varNumber = oversample.fit_resample(X_train_rfe_varNumber, varNumber_y_train)
y_resampled_varNumber = pd.DataFrame(y_resampled_varNumber, columns=['Label'])

# %%
# after SMOTE
print(y_resampled_varNumber["Label"].value_counts()[0])
print(y_resampled_varNumber["Label"].value_counts()[1])
print(y_resampled_varNumber["Label"].value_counts()[2])
print(y_resampled_varNumber["Label"].value_counts()[3])
print(y_resampled_varNumber["Label"].value_counts()[4])
# Out:
# 245
# 245
# 245
# 245
# 245

# %%
y_resampled_varNumber.shape
# Out:
# (1225, 1)

# %%
from keras.callbacks import EarlyStopping

# %%
# Define the architecture parameters
input_dim = X_resampled_varNumber.shape[1]   # Number of features
hidden1_dim = 64
hidden2_dim = 32
encoding_dim = 16  # Size of the encoded representations

# Define early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10)

# Build the SDAE model
input_layer = Input(shape=(input_dim,))
hidden1 = Dense(hidden1_dim, activation='relu')(input_layer)
encoded1 = Dense(hidden2_dim, activation='relu')(hidden1)
encoded2 = Dense(encoding_dim, activation='relu')(encoded1)
decoded1 = Dense(hidden2_dim, activation='relu')(encoded2)
decoded2 = Dense(hidden1_dim, activation='relu')(decoded1)
output_layer = Dense(input_dim, activation='linear')(decoded2)

sdae = Model(inputs=input_layer, outputs=output_layer)

# Compile the SDAE model
sdae.compile(optimizer='adam', loss='mean_squared_error')

# Train the SDAE
sdae.fit(X_resampled_varNumber, X_resampled_varNumber, epochs=250, batch_size=32, shuffle=True, validation_data=(X_test_rfe_varNumber, X_test_rfe_varNumber), callbacks=[early_stopping])

# Extract the encoder part for feature extraction
encoder = Model(inputs=input_layer, outputs=encoded2)

# Extract features using the encoder
X_train_encoded = encoder.predict(X_resampled_varNumber)
X_test_encoded = encoder.predict(X_test_rfe_varNumber)

# Define a classifier (example: simple MLP classifier)
num_classes = len(np.unique(y_resampled_varNumber))  # Number of classes in the target

classifier = Sequential([
    Dense(64, activation='relu', input_dim=encoding_dim),
    Dropout(0.5),
    Dense(32, activation='relu'),
    Dropout(0.5),
    Dense(num_classes, activation='softmax')  # Softmax for multiclass classification
])


# Compile and train the classifier
classifier.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
classifier.fit(X_train_encoded, y_resampled_varNumber, epochs=250, batch_size=32, validation_data=(X_test_encoded, varNumber_y_test), callbacks=[early_stopping])

# Predict probabilities
y_pred_prob = classifier.predict(X_test_encoded)

# Convert probabilities to class labels
y_pred = np.argmax(y_pred_prob, axis=1)

# Evaluate the classifier
accuracy = accuracy_score(varNumber_y_test, y_pred)
print(f"Accuracy: {accuracy}")
# Out:
# Epoch 1/250
# 39/39 [==============================] - 3s 49ms/step - loss: 0.6457 - val_loss: 0.8719
# Epoch 2/250
# 39/39 [==============================] - 2s 42ms/step - loss: 0.5710 - val_loss: 0.8441
# Epoch 3/250
# 39/39 [==============================] - 2s 55ms/step - loss: 0.5252 - val_loss: 0.8299
# Epoch 4/250
# 39/39 [==============================] - 2s 58ms/step - loss: 0.4916 - val_loss: 0.8195
# Epoch 5/250
# 39/39 [==============================] - 2s 48ms/step - loss: 0.4720 - val_loss: 0.8157
# Epoch 6/250
# 39/39 [==============================] - 3s 75ms/step - loss: 0.4517 - val_loss: 0.8145
# Epoch 7/250
# 39/39 [==============================] - 2s 58ms/step - loss: 0.4394 - val_loss: 0.8160
# Epoch 8/250
# 39/39 [==============================] - 2s 42ms/step - loss: 0.4167 - val_loss: 0.8165
# Epoch 9/250
# 39/39 [==============================] - 2s 61ms/step - loss: 0.4027 - val_loss: 0.8126
# Epoch 10/250
# 39/39 [==============================] - 2s 48ms/step - loss: 0.3905 - val_loss: 0.8116
# Epoch 11/250
# 39/39 [==============================] - 2s 50ms/step - loss: 0
250
# 39/39 [==============================] - 0s 4ms/step - loss: 1.3872 - accuracy: 0.4922 - val_loss: 1.1971 - val_accuracy: 0.5792
# Epoch 18/250
# 39/39 [==============================] - 0s 4ms/step - loss: 1.3753 - accuracy: 0.5135 - val_loss: 1.1882 - val_accuracy: 0.5743
# Epoch 19/250
# 39/39 [==============================] - 0s 4ms/step - loss: 1.3577 - accuracy: 0.4988 - val_loss: 1.1734 - val_accuracy: 0.5693
# Epoch 20/250
# 39/39 [==============================] - 0s 4ms/step - loss: 1.3319 - accuracy: 0.5127 - val_loss: 1.1665 - val_accuracy: 0.5644
# Epoch 21/250
# 39/39 [==============================] - 0s 5ms/step - loss: 1.2445 - accuracy: 0.5437 - val_loss: 1.1373 - val_accuracy: 0.5644
# Epoch 22/250
# 39/39 [==============================] - 0s 4ms/step - loss: 1.3356 - accuracy: 0.5257 - val_loss: 1.1431 - val_accuracy: 0.5644
# Epoch 23/250
# 39/39 [==============================] - 0s 4ms/step - loss: 1.2819 - accuracy: 0.5176 - val_loss: 1.1428 - val_accuracy: 0.5594
# Epoch 24/250
# 39/39 [==============================] - 0s 3ms/step - loss: 1.1678 - accuracy: 0.5649 - val_loss: 1.1344 - val_accuracy: 0.5743
# Epoch 25/250
# 39/39 [==============================] - 0s 3ms/step - loss: 1.1927 - accuracy: 0.5429 - val_loss: 1.1011 - val_accuracy: 0.5990
# Epoch 26/250
# 39/39 [==============================] - 0s 3ms/step - loss: 1.1656 - accuracy: 0.5600 - val_loss: 1.0829 - val_accuracy: 0.6089
# Epoch 27/250
# 39/39 [==============================] - 0s 5ms/step - loss: 1.1613 - accuracy: 0.5739 - val_loss: 1.0979 - val_accuracy: 0.5891
# Epoch 28/250
# 39/39 [==============================] - 0s 4ms/step - loss: 1.1445 - accuracy: 0.5641 - val_loss: 1.1053 - val_accuracy: 0.5891
# Epoch 29/250
# 39/39 [==============================] - 0s 3ms/step - loss: 1.0824 - accuracy: 0.5927 - val_loss: 1.0967 - val_accuracy: 0.5941
# Epoch 30/250
# 39/39 [==============================] - 0s 4ms/step - loss: 1.0436 - accuracy: 0.6000 - val_loss: 1.0944 - val_accuracy: 0.5644
# Epoch 31/250
# 39/39 [==============================] - 0s 3ms/step - loss: 1.0599 - accuracy: 0.5796 - val_loss: 1.0833 - val_accuracy: 0.6040
# Epoch 32/250
# 39/39 [==============================] - 0s 4ms/step - loss: 1.1211 - accuracy: 0.5747 - val_loss: 1.0759 - val_accuracy: 0.5941
# Epoch 33/250
# 39/39 [==============================] - 0s 6ms/step - loss: 1.0360 - accuracy: 0.6033 - val_loss: 1.0696 - val_accuracy: 0.5990
# Epoch 34/250
# 39/39 [==============================] - 0s 4ms/step - loss: 1.0456 - accuracy: 0.6098 - val_loss: 1.0888 - val_accuracy: 0.5495
# Epoch 35/250
# 39/39 [==============================] - 0s 4ms/step - loss: 0.9886 - accuracy: 0.6294 - val_loss: 1.0591 - val_accuracy: 0.5941
# Epoch 36/250
# 39/39 [==============================] - 0s 4ms/step - loss: 0.9614 - accuracy: 0.6147 - val_loss: 1.0665 - val_accuracy: 0.6188
# Epoch 37/250
# 39/39 [==============================] - 0s 4ms/step - loss: 0.9839 - accuracy: 0.6343 - val_loss: 1.0655 - val_accuracy: 0.6040
# Epoch 38/250
# 39/39 [==============================] - 0s 4ms/step - loss: 1.0133 - accuracy: 0.6090 - val_loss: 1.0652 - val_accuracy: 0.6287
# Epoch 39/250
# 39/39 [==============================] - 0s 5ms/step - loss: 0.9667 - accuracy: 0.6359 - val_loss: 1.0629 - val_accuracy: 0.6040
# Epoch 40/250
# 39/39 [==============================] - 0s 5ms/step - loss: 0.9530 - accuracy: 0.6433 - val_loss: 1.1025 - val_accuracy: 0.5396
# Epoch 41/250
# 39/39 [==============================] - 0s 5ms/step - loss: 0.9687 - accuracy: 0.6335 - val_loss: 1.0706 - val_accuracy: 0.5792
# Epoch 42/250
# 39/39 [==============================] - 0s 5ms/step - loss: 0.9370 - accuracy: 0.6433 - val_loss: 1.0661 - val_accuracy: 0.6040
# Epoch 43/250
# 39/39 [==============================] - 0s 8ms/step - loss: 0.9545 - accuracy: 0.6416 - val_loss: 1.0714 - val_accuracy: 0.6040
# Epoch 44/250
# 39/39 [==============================] - 0s 10ms/step - loss: 0.9544 - accuracy: 0.6457 - val_loss: 1.0899 - val_accuracy: 0.5594
# Epoch 45/250
# 39/39 [==============================] - 0s 9ms/step - loss: 0.8718 - accuracy: 0.6498 - val_loss: 1.0705 - val_accuracy: 0.6238
# 7/7 [==============================] - 0s 5ms/step
# Accuracy: 0.6237623762376238

# %% [markdown]
# ## BRCA_miRNA

# %%
X_train_rfe_miRNA.shape
# Out:
# (469, 300)

# %%
miRNA_y_test

# %%
print(miRNA_y_train.value_counts())
# Out:
# Label
# 1    245
# 2     96
# 3     82
# 4     25
# 0     21
# Name: count, dtype: int64

# %%
oversample = SMOTE()
X_resampled_miRNA, y_resampled_miRNA = oversample.fit_resample(X_train_rfe_miRNA, miRNA_y_train)
y_resampled_miRNA = pd.DataFrame(y_resampled_miRNA, columns=['Label'])

# %%
print(y_resampled_miRNA["Label"].value_counts()[0])
print(y_resampled_miRNA["Label"].value_counts()[1])
print(y_resampled_miRNA["Label"].value_counts()[2])
print(y_resampled_miRNA["Label"].value_counts()[3])
print(y_resampled_miRNA["Label"].value_counts()[4])
# Out:
# 245
# 245
# 245
# 245
# 245

# %%
y_resampled_miRNA.shape
# Out:
# (1225, 1)

# %%
from keras.callbacks import EarlyStopping

# %%
# Define the architecture parameters
input_dim = X_resampled_miRNA.shape[1]   # Number of features
hidden1_dim = 64
hidden2_dim = 32
encoding_dim = 16  # Size of the encoded representations

# Define early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10)

# Build the SDAE model
input_layer = Input(shape=(input_dim,))
hidden1 = Dense(hidden1_dim, activation='relu')(input_layer)
encoded1 = Dense(hidden2_dim, activation='relu')(hidden1)
encoded2 = Dense(encoding_dim, activation='relu')(encoded1)
decoded1 = Dense(hidden2_dim, activation='relu')(encoded2)
decoded2 = Dense(hidden1_dim, activation='relu')(decoded1)
output_layer = Dense(input_dim, activation='linear')(decoded2)

sdae = Model(inputs=input_layer, outputs=output_layer)

# Compile the SDAE model
sdae.compile(optimizer='adam', loss='mean_squared_error')

# Train the SDAE
sdae.fit(X_resampled_miRNA, X_resampled_miRNA, epochs=250, batch_size=32, shuffle=True, validation_data=(X_test_rfe_miRNA, X_test_rfe_miRNA), callbacks=[early_stopping])

# Extract the encoder part for feature extraction
encoder = Model(inputs=input_layer, outputs=encoded2)

# Extract features using the encoder
X_train_encoded = encoder.predict(X_resampled_miRNA)
X_test_encoded = encoder.predict(X_test_rfe_miRNA)

# Define a classifier (example: simple MLP classifier)
num_classes = len(np.unique(y_resampled_miRNA))  # Number of classes in the target

classifier = Sequential([
    Dense(64, activation='relu', input_dim=encoding_dim),
    Dropout(0.5),
    Dense(32, activation='relu'),
    Dropout(0.5),
    Dense(num_classes, activation='softmax')  # Softmax for multiclass classification
])


# Compile and train the classifier
classifier.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
classifier.fit(X_train_encoded, y_resampled_miRNA, epochs=250, batch_size=32, validation_data=(X_test_encoded, miRNA_y_test), callbacks=[early_stopping])

# Predict probabilities
y_pred_prob = classifier.predict(X_test_encoded)

# Convert probabilities to class labels
y_pred = np.argmax(y_pred_prob, axis=1)

# Evaluate the classifier
accuracy = accuracy_score(miRNA_y_test, y_pred)
print(f"Accuracy: {accuracy}")
# Out:
# Epoch 1/250
# 39/39 [==============================] - 2s 10ms/step - loss: 0.7882 - val_loss: 0.8901
# Epoch 2/250
# 39/39 [==============================] - 0s 5ms/step - loss: 0.6275 - val_loss: 0.7735
# Epoch 3/250
# 39/39 [==============================] - 0s 6ms/step - loss: 0.5641 - val_loss: 0.7435
# Epoch 4/250
# 39/39 [==============================] - 0s 5ms/step - loss: 0.5227 - val_loss: 0.7210
# Epoch 5/250
# 39/39 [==============================] - 0s 5ms/step - loss: 0.4894 - val_loss: 0.6979
# Epoch 6/250
# 39/39 [==============================] - 0s 5ms/step - loss: 0.4638 - val_loss: 0.6818
# Epoch 7/250
# 39/39 [==============================] - 0s 9ms/step - loss: 0.4465 - val_loss: 0.6695
# Epoch 8/250
# 39/39 [==============================] - 0s 8ms/step - loss: 0.4322 - val_loss: 0.6635
# Epoch 9/250
# 39/39 [==============================] - 0s 7ms/step - loss: 0.4215 - val_loss: 0.6577
# Epoch 10/250
# 39/39 [==============================] - 0s 8ms/step - loss: 0.4122 - val_loss: 0.6532
# Epoch 11/250
# 39/39 [==============================] - 0s 10ms/step - loss: 0.4040 - val_loss: 0.6527
# Epoch 12/250
# 39/39 [==============================] - 0s 8ms/step - loss: 0.3957 - val_loss: 0.6495
# Epoch 13/250
# 39/39 [==============================] - 0s 9ms/step - loss: 0.3887 - val_loss: 0.6465
# Epoch 14/250
# 39/39 [==============================] - 0s 9ms/step - loss: 0.3814 - val_loss: 0.6435
# Epoch 15/250
# 39/39 [==============================] - 0s 8ms/step - loss: 0.3758 - val_loss: 0.6429
# Epoch 16/250
# 39/39 [==============================] - 0s 10ms/step - loss: 0.3703 - val_loss: 0.6410
# Epoch 17/250
# 39/39 [==============================] - 0s 12ms/step - loss: 0.3655 - val_loss: 0.6381
# Epoch 18/250
# 39/39 [==============================] - 0s 9ms/step - loss: 0.3597 - val_loss: 0.6388
# Epoch 19/250
# 39/39 [==============================] - 0s 10ms/step - loss: 0.3558 - val_loss: 0.6365
# Epoch 20/250
# 39/39 [==============================] - 0s 8ms/step - loss: 0.3518 - val_loss: 0.6366
# Epoch 21/250
# 39/39 [==============================] - 0s 8ms/step - loss: 0.3471 - val_loss: 0.6369
# Epoch 22/250
# 39/39 [==============================] - 0s 10ms/step - loss: 0.3427 - val_loss: 0.6375
# Epoch 23/250
# 39/39 [==============================] - 0s 9ms/step - loss: 0.3391 - val_loss: 0.6347
# Epoch 24/250
# 39/39 [==============================] - 0s 9ms/step - loss: 0.3347 - val_loss: 0.6365
# Epoch 25/250
# 39/39 [==============================] - 0s 9ms/step - loss: 0.3317 - val_loss: 0.6377
# Epoch 26/250
# 39/39 [==============================] - 0s 7ms/step - loss: 0.3288 - val_loss: 0.6371
# Epoch 27/250
# 39/39 [==============================] - 0s 8ms/step - loss: 0.3259 - val_loss: 0.6355
# Epoch 28/250
# 39/39 [==============================] - 0s 9ms/step - loss: 0.3234 - val_loss: 0.6384
# Epoch 29/250
# 39/39 [==============================] - 0s 6ms/step - loss: 0.3203 - val_loss: 0.6378
# Epoch 30/250
# 39/39 [==============================] - 0s 5ms/step - loss: 0.3181 - val_loss: 0.6369
# Epoch 31/250
# 39/39 [==============================] - 0s 6ms/step - loss: 0.3154 - val_loss: 0.6390
# Epoch 32/250
# 39/39 [==============================] - 0s 5ms/step - loss: 0.3133 - val_loss: 0.6391
# Epoch 33/250
# 39/39 [==============================] - 0s 5ms/step - loss: 0.3100 - val_loss: 0.6381
# 39/39 [==============================] - 0s 2ms/step
# 7/7 [==============================] - 0s 2ms/step
# Epoch 1/250
# 39/39 [==============================] - 1s 9ms/step - loss: 4.3005 - accuracy: 0.2057 - val_loss: 1.6135 - val_accuracy: 0.1238
# Epoch 2/250
# 39/39 [==============================] - 0s 4ms/step - loss: 2.1847 - accuracy: 0.2653 - val_loss: 1.5697 - val_accuracy: 0.2376
# Epoch 3/250
# 39/39 [==============================] - 0s 4ms/step - loss: 1.7841 - accuracy: 0.2963 - val_loss: 1.5673 - val_accuracy: 0.1931
# Epoch 4/250
# 39/39 [==============================] - 0s 3ms/step - loss: 1.5986 - accuracy: 0.3478 - val_loss: 1.5387 - val_accuracy: 0.2327
# Epoch 5/250
# 39/39 [==============================] - 0s 4ms/step - loss: 1.4722 - accuracy: 0.3918 - val_loss: 1.4817 - val_accuracy: 0.2376
# Epoch 6/250
# 39/39 [==============================] - 0s 5ms/step - loss: 1.3406 - accuracy: 0.4335 - val_loss: 1.4028 - val_accuracy: 0.3416
# Epoch 7/250
# 39/39 [==============================] - 0s 4ms/step - loss: 1.2569 - accuracy: 0.4792 - val_loss: 1.3131 - val_accuracy: 0.4109
# Epoch 8/250
# 39/39 [==============================] - 0s 4ms/step - loss: 1.2208 - accuracy: 0.4971 - val_loss: 1.1951 - val_accuracy: 0.5297
# Epoch 9/250
# 39/39 [==============================] - 0s 5ms/step - loss: 1.1787 - accuracy: 0.5176 - val_loss: 1.1607 - val_accuracy: 0.5347
# Epoch 10/250
# 39/39 [==============================] - 0s 4ms/step - loss: 1.0570 - accuracy: 0.5722 - val_loss: 1.0644 - val_accuracy: 0.5792
# Epoch 11/250
# 39/39 [==============================] - 0s 5ms/step - loss: 0.9710 - accuracy: 0.5959 - val_loss: 1.0556 - val_accuracy: 0.5842
# Epoch 12/250
# 39/39 [==============================] - 0s 7ms/step - loss: 0.9451 - accuracy: 0.6392 - val_loss: 0.9891 - val_accuracy: 0.5842
# Epoch 13/250
# 39/39 [==============================] - 0s 5ms/step - loss: 0.8571 - accuracy: 0.6653 - val_loss: 0.9597 - val_accuracy: 0.6287
# Epoch 14/250
# 39/39 [==============================] - 0s 4ms/step - loss: 0.8624 - accuracy: 0.6449 - val_loss: 0.9657 - val_accuracy: 0.5941
# Epoch 15/250
# 39/39 [==============================] - 0s 4ms/step - loss: 0.8113 - accuracy: 0.6776 - val_loss: 0.9377 - val_accuracy: 0.6287
# Epoch 16/250
# 39/39 [==============================] - 0s 5ms/step - loss: 0.7878 - accuracy: 0.6776 - val_loss: 0.9476 - val_accuracy: 0.6238
# Epoch 17/250
# 39/39 [==============================] - 0s 5ms/step - loss: 0.7671 - accuracy: 0.6857 - val_loss: 0.9431 - val_accuracy: 0.6188
# Epoch 18/250
# 39/39 [==============================] - 0s 5ms/step - loss: 0.7398 - accuracy: 0.7037 - val_loss: 0.9482 - val_accuracy: 0.6287
# Epoch 19/250
# 39/39 [==============================] - 0s 5ms/step - loss: 0.7008 - accuracy: 0.7404 - val_loss: 0.9880 - val_accuracy: 0.6337
# Epoch 20/250
# 39/39 [==============================] - 0s 4ms/step - loss: 0.7109 - accuracy: 0.7404 - val_loss: 0.9004 - val_accuracy: 0.6584
# Epoch 21/250
# 39/39 [==============================] - 0s 4ms/step - loss: 0.7003 - accuracy: 0.7200 - val_loss: 0.9519 - val_accuracy: 0.6089
# Epoch 22/250
# 39/39 [==============================] - 0s 5ms/step - loss: 0.6867 - accuracy: 0.7233 - val_loss: 0.9148 - val_accuracy: 0.6535
# Epoch 23/250
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6561 - accuracy: 0.7535 - val_loss: 0.9051 - val_accuracy: 0.6337
# Epoch 24/250
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6351 - accuracy: 0.7453 - val_loss: 0.9284 - val_accuracy: 0.6238
# Epoch 25/250
# 39/39 [==============================] - 0s 4ms/step - loss: 0.5919 - accuracy: 0.7682 - val_loss: 0.8767 - val_accuracy: 0.6436
# Epoch 26/250
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6000 - accuracy: 0.7624 - val_loss: 0.9208 - val_accuracy: 0.6535
# Epoch 27/250
# 39/39 [==============================] - 0s 4ms/step - loss: 0.5711 - accuracy: 0.7820 - val_loss: 0.8972 - val_accuracy: 0.6436
# Epoch 28/250
# 39/39 [==============================] - 0s 5ms/step - loss: 0.5944 - accuracy: 0.7731 - val_loss: 0.9074 - val_accuracy: 0.6485
# Epoch 29/250
# 39/39 [==============================] - 0s 4ms/step - loss: 0.5666 - accuracy: 0.7902 - val_loss: 0.8946 - val_accuracy: 0.6287
# Epoch 30/250
# 39/39 [==============================] - 0s 4ms/step - loss: 0.5739 - accuracy: 0.7853 - val_loss: 0.9215 - val_accuracy: 0.6386
# Epoch 31/250
# 39/39 [==============================] - 0s 4ms/step - loss: 0.5291 - accuracy: 0.7869 - val_loss: 0.9025 - val_accuracy: 0.6634
# Epoch 32/250
# 39/39 [==============================] - 0s 4ms/step - loss: 0.5681 - accuracy: 0.7755 - val_loss: 0.8885 - val_accuracy: 0.6733
# Epoch 33/250
# 39/39 [==============================] - 0s 4ms/step - loss: 0.5303 - accuracy: 0.7943 - val_loss: 0.9540 - val_accuracy: 0.6485
# Epoch 34/250
# 39/39 [==============================] - 0s 5ms/step - loss: 0.5112 - accuracy: 0.7959 - val_loss: 0.8981 - val_accuracy: 0.6386
# Epoch 35/250
# 39/39 [==============================] - 0s 5ms/step - loss: 0.5436 - accuracy: 0.7869 - val_loss: 0.8832 - val_accuracy: 0.6634
# 7/7 [==============================] - 0s 3ms/step
# Accuracy: 0.6633663366336634

# %% [markdown]
# ## BRCA_DNA_Methylation

# %%
X_train_rfe_dna.shape
# Out:
# (469, 19000)

# %%
print(dna_y_train.value_counts())
# Out:
# Label
# 1    245
# 2     96
# 3     82
# 4     25
# 0     21
# Name: count, dtype: int64

# %%
oversample = SMOTE()
X_resampled_dna, y_resampled_dna = oversample.fit_resample(X_train_rfe_dna, dna_y_train)
y_resampled_dna = pd.DataFrame(y_resampled_dna, columns=['Label'])

# %%
print(y_resampled_dna["Label"].value_counts()[0])
print(y_resampled_dna["Label"].value_counts()[1])
print(y_resampled_dna["Label"].value_counts()[2])
print(y_resampled_dna["Label"].value_counts()[3])
print(y_resampled_dna["Label"].value_counts()[4])
# Out:
# 245
# 245
# 245
# 245
# 245

# %%
y_resampled_dna.shape
# Out:
# (1225, 1)

# %%
from keras.callbacks import EarlyStopping

# %%
# Define the architecture parameters
input_dim = X_resampled_dna.shape[1]   # Number of features
hidden1_dim = 64
hidden2_dim = 32
encoding_dim = 16  # Size of the encoded representations

# Define early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10)

# Build the SDAE model
input_layer = Input(shape=(input_dim,))
hidden1 = Dense(hidden1_dim, activation='relu')(input_layer)
encoded1 = Dense(hidden2_dim, activation='relu')(hidden1)
encoded2 = Dense(encoding_dim, activation='relu')(encoded1)
decoded1 = Dense(hidden2_dim, activation='relu')(encoded2)
decoded2 = Dense(hidden1_dim, activation='relu')(decoded1)
output_layer = Dense(input_dim, activation='linear')(decoded2)

sdae = Model(inputs=input_layer, outputs=output_layer)

# Compile the SDAE model
sdae.compile(optimizer='adam', loss='mean_squared_error')

# Train the SDAE
sdae.fit(X_resampled_dna, X_resampled_dna, epochs=250, batch_size=32, shuffle=True, validation_data=(X_test_rfe_dna, X_test_rfe_dna), callbacks=[early_stopping])

# Extract the encoder part for feature extraction
encoder = Model(inputs=input_layer, outputs=encoded2)

# Extract features using the encoder
X_train_encoded = encoder.predict(X_resampled_dna)
X_test_encoded = encoder.predict(X_test_rfe_dna)

# Define a classifier (example: simple MLP classifier)
num_classes = len(np.unique(y_resampled_dna))  # Number of classes in the target

classifier = Sequential([
    Dense(64, activation='relu', input_dim=encoding_dim),
    Dropout(0.5),
    Dense(32, activation='relu'),
    Dropout(0.5),
    Dense(num_classes, activation='softmax')  # Softmax for multiclass classification
])


# Compile and train the classifier
classifier.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
classifier.fit(X_train_encoded, y_resampled_dna, epochs=250, batch_size=32, validation_data=(X_test_encoded, dna_y_test), callbacks=[early_stopping])

# Predict probabilities
y_pred_prob = classifier.predict(X_test_encoded)

# Convert probabilities to class labels
y_pred = np.argmax(y_pred_prob, axis=1)

# Evaluate the classifier
accuracy = accuracy_score(dna_y_test, y_pred)
print(f"Accuracy: {accuracy}")
# Out:
# Epoch 1/250
# 39/39 [==============================] - 4s 74ms/step - loss: 0.6355 - val_loss: 0.6746
# Epoch 2/250
# 39/39 [==============================] - 2s 59ms/step - loss: 0.4767 - val_loss: 0.6267
# Epoch 3/250
# 39/39 [==============================] - 2s 59ms/step - loss: 0.4305 - val_loss: 0.6055
# Epoch 4/250
# 39/39 [==============================] - 2s 55ms/step - loss: 0.4062 - val_loss: 0.5953
# Epoch 5/250
# 39/39 [==============================] - 3s 81ms/step - loss: 0.3762 - val_loss: 0.5911
# Epoch 6/250
# 39/39 [==============================] - 3s 83ms/step - loss: 0.3611 - val_loss: 0.5884
# Epoch 7/250
# 39/39 [==============================] - 3s 82ms/step - loss: 0.3454 - val_loss: 0.5890
# Epoch 8/250
# 39/39 [==============================] - 2s 53ms/step - loss: 0.3344 - val_loss: 0.5840
# Epoch 9/250
# 39/39 [==============================] - 2s 60ms/step - loss: 0.3239 - val_loss: 0.5895
# Epoch 10/250
# 39/39 [==============================] - 2s 61ms/step - loss: 0.3175 - val_loss: 0.5862
# Epoch 11/250
# 39/39 [==============================] - 2s 55ms/step - loss: 0.3095 - val_loss: 0.5843
# Epoch 12/250
# 39/39 [==============================] - 3s 68ms/step - loss: 0.3059 - val_loss: 0.5883
# Epoch 13/250
# 39/39 [==============================] - 3s 85ms/step - loss: 0.2996 - val_loss: 0.5848
# Epoch 14/250
# 39/39 [==============================] - 3s 84ms/step - loss: 0.2966 - val_loss: 0.5895
# Epoch 15/250
# 39/39 [==============================] - 3s 64ms/step - loss: 0.2942 - val_loss: 0.5832
# Epoch 16/250
# 39/39 [==============================] - 2s 53ms/step - loss: 0.2876 - val_loss: 0.5851
# Epoch 17/250
# 39/39 [==============================] - 2s 60ms/step - loss: 0.2864 - val_loss: 0.5902
# Epoch 18/250
# 39/39 [==============================] - 2s 58ms/step - loss: 0.2811 - val_loss: 0.5866
# Epoch 19/250
# 39/39 [==============================] - 3s 68ms/step - loss: 0.2791 - val_loss: 0.5889
# Epoch 20/250
# 39/39 [==============================] - 3s 83ms/step - loss: 0.2793 - val_loss: 0.5946
# Epoch 21/250
# 39/39 [==============================] - 3s 84ms/step - loss: 0.2842 - val_loss: 0.6025
# Epoch 22/250
# 39/39 [==============================] - 3s 75ms/step - loss: 0.2866 - val_loss: 0.5933
# Epoch 23/250
# 39/39 [==============================] - 2s 60ms/step - loss: 0.2745 - val_loss: 0.5884
# Epoch 24/250
250
# 39/39 [==============================] - 0s 4ms/step - loss: 1.3835 - accuracy: 0.4147 - val_loss: 1.2338 - val_accuracy: 0.6089
# Epoch 23/250
# 39/39 [==============================] - 0s 4ms/step - loss: 1.4385 - accuracy: 0.4033 - val_loss: 1.2138 - val_accuracy: 0.6139
# Epoch 24/250
# 39/39 [==============================] - 0s 5ms/step - loss: 1.4056 - accuracy: 0.3951 - val_loss: 1.2083 - val_accuracy: 0.6040
# Epoch 25/250
# 39/39 [==============================] - 0s 6ms/step - loss: 1.3894 - accuracy: 0.4188 - val_loss: 1.2107 - val_accuracy: 0.5941
# Epoch 26/250
# 39/39 [==============================] - 0s 4ms/step - loss: 1.3295 - accuracy: 0.4376 - val_loss: 1.1814 - val_accuracy: 0.5941
# Epoch 27/250
# 39/39 [==============================] - 0s 4ms/step - loss: 1.3030 - accuracy: 0.4490 - val_loss: 1.1616 - val_accuracy: 0.6139
# Epoch 28/250
# 39/39 [==============================] - 0s 4ms/step - loss: 1.3393 - accuracy: 0.4180 - val_loss: 1.1648 - val_accuracy: 0.6238
# Epoch 29/250
# 39/39 [==============================] - 0s 4ms/step - loss: 1.3459 - accuracy: 0.4424 - val_loss: 1.1486 - val_accuracy: 0.5693
# Epoch 30/250
# 39/39 [==============================] - 0s 6ms/step - loss: 1.2707 - accuracy: 0.4620 - val_loss: 1.1326 - val_accuracy: 0.5941
# Epoch 31/250
# 39/39 [==============================] - 0s 5ms/step - loss: 1.2787 - accuracy: 0.4678 - val_loss: 1.1305 - val_accuracy: 0.5941
# Epoch 32/250
# 39/39 [==============================] - 0s 4ms/step - loss: 1.2608 - accuracy: 0.4498 - val_loss: 1.1239 - val_accuracy: 0.5990
# Epoch 33/250
# 39/39 [==============================] - 0s 4ms/step - loss: 1.2561 - accuracy: 0.4767 - val_loss: 1.1326 - val_accuracy: 0.5594
# Epoch 34/250
# 39/39 [==============================] - 0s 4ms/step - loss: 1.2198 - accuracy: 0.4816 - val_loss: 1.1030 - val_accuracy: 0.5594
# Epoch 35/250
# 39/39 [==============================] - 0s 7ms/step - loss: 1.1730 - accuracy: 0.4939 - val_loss: 1.0964 - val_accuracy: 0.5495
# Epoch 36/250
# 39/39 [==============================] - 0s 4ms/step - loss: 1.2017 - accuracy: 0.5020 - val_loss: 1.0769 - val_accuracy: 0.5693
# Epoch 37/250
# 39/39 [==============================] - 0s 4ms/step - loss: 1.2122 - accuracy: 0.4841 - val_loss: 1.0708 - val_accuracy: 0.5644
# Epoch 38/250
# 39/39 [==============================] - 0s 4ms/step - loss: 1.1869 - accuracy: 0.5078 - val_loss: 1.0576 - val_accuracy: 0.5693
# Epoch 39/250
# 39/39 [==============================] - 0s 4ms/step - loss: 1.1401 - accuracy: 0.5257 - val_loss: 1.0427 - val_accuracy: 0.5644
# Epoch 40/250
# 39/39 [==============================] - 0s 4ms/step - loss: 1.1719 - accuracy: 0.4922 - val_loss: 1.0072 - val_accuracy: 0.5990
# Epoch 41/250
# 39/39 [==============================] - 0s 5ms/step - loss: 1.1271 - accuracy: 0.4890 - val_loss: 1.0492 - val_accuracy: 0.5198
# Epoch 42/250
# 39/39 [==============================] - 0s 4ms/step - loss: 1.1060 - accuracy: 0.5249 - val_loss: 1.0332 - val_accuracy: 0.5644
# Epoch 43/250
# 39/39 [==============================] - 0s 4ms/step - loss: 1.0837 - accuracy: 0.5461 - val_loss: 1.0170 - val_accuracy: 0.5743
# Epoch 44/250
# 39/39 [==============================] - 0s 4ms/step - loss: 1.0934 - accuracy: 0.5314 - val_loss: 1.0129 - val_accuracy: 0.5594
# Epoch 45/250
# 39/39 [==============================] - 0s 4ms/step - loss: 1.1240 - accuracy: 0.5249 - val_loss: 1.0157 - val_accuracy: 0.5644
# Epoch 46/250
# 39/39 [==============================] - 0s 4ms/step - loss: 1.1087 - accuracy: 0.5322 - val_loss: 1.0214 - val_accuracy: 0.5644
# Epoch 47/250
# 39/39 [==============================] - 0s 5ms/step - loss: 1.0661 - accuracy: 0.5576 - val_loss: 0.9996 - val_accuracy: 0.5396
# Epoch 48/250
# 39/39 [==============================] - 0s 4ms/step - loss: 1.0709 - accuracy: 0.5657 - val_loss: 0.9930 - val_accuracy: 0.5743
# Epoch 49/250
# 39/39 [==============================] - 0s 4ms/step - loss: 1.0249 - accuracy: 0.5739 - val_loss: 0.9889 - val_accuracy: 0.5396
# Epoch 50/250
# 39/39 [==============================] - 0s 4ms/step - loss: 0.9533 - accuracy: 0.5976 - val_loss: 0.9922 - val_accuracy: 0.5248
# Epoch 51/250
# 39/39 [==============================] - 0s 4ms/step - loss: 0.
250
# 39/39 [==============================] - 0s 6ms/step - loss: 0.7906 - accuracy: 0.6776 - val_loss: 0.9492 - val_accuracy: 0.5248
# Epoch 81/250
# 39/39 [==============================] - 0s 7ms/step - loss: 0.8162 - accuracy: 0.6645 - val_loss: 0.9345 - val_accuracy: 0.5198
# Epoch 82/250
# 39/39 [==============================] - 0s 8ms/step - loss: 0.7544 - accuracy: 0.6669 - val_loss: 0.9540 - val_accuracy: 0.5000
# Epoch 83/250
# 39/39 [==============================] - 0s 7ms/step - loss: 0.7477 - accuracy: 0.6873 - val_loss: 0.9294 - val_accuracy: 0.5248
# Epoch 84/250
# 39/39 [==============================] - 0s 7ms/step - loss: 0.7190 - accuracy: 0.6841 - val_loss: 0.9346 - val_accuracy: 0.5149
# Epoch 85/250
# 39/39 [==============================] - 0s 8ms/step - loss: 0.7453 - accuracy: 0.6629 - val_loss: 0.9330 - val_accuracy: 0.5297
# Epoch 86/250
# 39/39 [==============================] - 0s 8ms/step - loss: 0.7679 - accuracy: 0.6857 - val_loss: 0.9431 - val_accuracy: 0.5347
# Epoch 87/250
# 39/39 [==============================] - 0s 8ms/step - loss: 0.7683 - accuracy: 0.6890 - val_loss: 0.9357 - val_accuracy: 0.5248
# Epoch 88/250
# 39/39 [==============================] - 0s 8ms/step - loss: 0.7801 - accuracy: 0.6727 - val_loss: 0.9729 - val_accuracy: 0.5050
# 7/7 [==============================] - 0s 7ms/step
# Accuracy: 0.504950495049505

# %% [markdown]
# ## BRCA_mRNA

# %%
X_train_rfe_mrna.shape
# Out:
# (469, 18000)

# %%
mrna_y_train.shape
# Out:
# (469,)

# %%
oversample = SMOTE()
X_resampled_mrna, y_resampled_mrna = oversample.fit_resample(X_train_rfe_mrna, mrna_y_train)
y_resampled_mrna = pd.DataFrame(y_resampled_mrna, columns=['Label'])

# %%
print(y_resampled_mrna["Label"].value_counts()[0])
print(y_resampled_mrna["Label"].value_counts()[1])
print(y_resampled_mrna["Label"].value_counts()[2])
print(y_resampled_mrna["Label"].value_counts()[3])
print(y_resampled_mrna["Label"].value_counts()[4])
# Out:
# 245
# 245
# 245
# 245
# 245

# %%
y_resampled_mrna.shape
# Out:
# (1225, 1)

# %%
from keras.callbacks import EarlyStopping

# %%
# Define the architecture parameters
input_dim = X_resampled_mrna.shape[1]   # Number of features
hidden1_dim = 64
hidden2_dim = 32
encoding_dim = 16  # Size of the encoded representations

# Define early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10)

# Build the SDAE model
input_layer = Input(shape=(input_dim,))
hidden1 = Dense(hidden1_dim, activation='relu')(input_layer)
encoded1 = Dense(hidden2_dim, activation='relu')(hidden1)
encoded2 = Dense(encoding_dim, activation='relu')(encoded1)
decoded1 = Dense(hidden2_dim, activation='relu')(encoded2)
decoded2 = Dense(hidden1_dim, activation='relu')(decoded1)
output_layer = Dense(input_dim, activation='linear')(decoded2)

sdae = Model(inputs=input_layer, outputs=output_layer)

# Compile the SDAE model
sdae.compile(optimizer='adam', loss='mean_squared_error')

# Train the SDAE
sdae.fit(X_resampled_mrna, X_resampled_mrna, epochs=250, batch_size=32, shuffle=True, validation_data=(X_test_rfe_mrna, X_test_rfe_mrna), callbacks=[early_stopping])

# Extract the encoder part for feature extraction
encoder = Model(inputs=input_layer, outputs=encoded2)

# Extract features using the encoder
X_train_encoded = encoder.predict(X_resampled_mrna)
X_test_encoded = encoder.predict(X_test_rfe_mrna)

# Define a classifier (example: simple MLP classifier)
num_classes = len(np.unique(y_resampled_mrna))  # Number of classes in the target

classifier = Sequential([
    Dense(64, activation='relu', input_dim=encoding_dim),
    Dropout(0.5),
    Dense(32, activation='relu'),
    Dropout(0.5),
    Dense(num_classes, activation='softmax')  # Softmax for multiclass classification
])


# Compile and train the classifier
classifier.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
classifier.fit(X_train_encoded, y_resampled_mrna, epochs=250, batch_size=32, validation_data=(X_test_encoded, mrna_y_test), callbacks=[early_stopping])

# Predict probabilities
y_pred_prob = classifier.predict(X_test_encoded)

# Convert probabilities to class labels
y_pred = np.argmax(y_pred_prob, axis=1)

# Evaluate the classifier
accuracy = accuracy_score(mrna_y_test, y_pred)
print(f"Accuracy: {accuracy}")
# Out:
# Epoch 1/250
# 39/39 [==============================] - 4s 62ms/step - loss: 0.7180 - val_loss: 0.8321
# Epoch 2/250
# 39/39 [==============================] - 3s 78ms/step - loss: 0.5952 - val_loss: 0.7721
# Epoch 3/250
# 39/39 [==============================] - 3s 84ms/step - loss: 0.5441 - val_loss: 0.7443
# Epoch 4/250
# 39/39 [==============================] - 3s 84ms/step - loss: 0.5065 - val_loss: 0.7318
# Epoch 5/250
# 39/39 [==============================] - 2s 54ms/step - loss: 0.4777 - val_loss: 0.7267
# Epoch 6/250
# 39/39 [==============================] - 2s 54ms/step - loss: 0.4580 - val_loss: 0.7236
# Epoch 7/250
# 39/39 [==============================] - 2s 55ms/step - loss: 0.4414 - val_loss: 0.7308
# Epoch 8/250
# 39/39 [==============================] - 2s 56ms/step - loss: 0.4296 - val_loss: 0.7212
# Epoch 9/250
# 39/39 [==============================] - 3s 66ms/step - loss: 0.4132 - val_loss: 0.7219
# Epoch 10/250
# 39/39 [==============================] - 3s 77ms/step - loss: 0.4020 - val_loss: 0.7233
# Epoch 11/250
# 39/39 [==============================] - 3s 73ms/step - loss: 0.3947 - val_loss: 0.7256
# Epoch 12/250
# 39/39 [==============================] - 3s 81ms/step - loss: 0.3875 - val_loss: 0.7270
# Epoch 13/250
# 39/39 [==============================] - 2s 55ms/step - loss: 0.3820 - val_loss: 0.7291
# Epoch 14/250
# 39/39 [==============================] - 2s 56ms/step - loss: 0.3745 - val_loss: 0.7268
# Epoch 15/250
# 39/39 [==============================] - 2s 54ms/step - loss: 0.3693 - val_loss: 0.7322
# Epoch 16/250
# 39/39 [==============================] - 2s 63ms/step - loss: 0.3659 - val_loss: 0.7311
# Epoch 17/250
# 39/39 [==============================] - 2s 55ms/step - loss: 0.3628 - val_loss: 0.7308
# Epoch 18/250
# 39/39 [==============================] - 3s 76ms/step - loss: 0.3591 - val_loss: 0.7327
# 39/39 [==============================] - 1s 13ms/step
# 7/7 [==============================] - 0s 13ms/step
# Epoch 1/250
# 39/39 [==============================] - 2s 9ms/step - loss: 20.9129 - accuracy: 0.2620 - val_loss: 2.6930 - val_accuracy: 0.4901
# Epoch 2/250
# 39/39 [==============================] - 0s 4ms/step - loss: 9.8010 - accuracy: 0.3167 - val_loss: 1.4295 - val_accuracy: 0.5495
# Epoch 3/250
# 39/39 [==============================] - 0s 5ms/step - loss: 6.2885 - accuracy: 0.3967 - val_loss: 1.2839 - val_accuracy: 0.5149
# Epoch 4/250
# 39/39 [==============================] - 0s 4ms/step - loss: 4.1232 - accuracy: 0.4302 - val_loss: 1.1755 - val_accuracy: 0.5693
# Epoch 5/250
# 39/39 [==============================] - 0s 5ms/step - loss: 3.0552 - accuracy: 0.4253 - val_loss: 1.1467 - val_accuracy: 0.5594
# Epoch 6/250
# 39/39 [==============================] - 0s 4ms/step - loss: 2.5220 - accuracy: 0.4539 - val_loss: 1.1366 - val_accuracy: 0.5693
# Epoch 7/250
# 39/39 [==============================] - 0s 3ms/step - loss: 2.2254 - accuracy: 0.4588 - val_loss: 1.1400 - val_accuracy: 0.5545
# Epoch 8/250
# 39/39 [==============================] - 0s 5ms/step - loss: 2.0065 - accuracy: 0.4571 - val_loss: 1.1274 - val_accuracy: 0.5396
# Epoch 9/250
# 39/39 [==============================] - 0s 5ms/step - loss: 1.7828 - accuracy: 0.4702 - val_loss: 1.1171 - val_accuracy: 0.5396
# Epoch 10/250
# 39/39 [==============================] - 0s 4ms/step - loss: 1.5850 - accuracy: 0.4988 - val_loss: 1.1348 - val_accuracy: 0.5198
# Epoch 11/250
# 39/39 [==============================] - 0s 5ms/step - loss: 1
250
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6216 - accuracy: 0.7576 - val_loss: 0.7852 - val_accuracy: 0.6832
# Epoch 43/250
# 39/39 [==============================] - 0s 5ms/step - loss: 0.6843 - accuracy: 0.7592 - val_loss: 0.7552 - val_accuracy: 0.6931
# Epoch 44/250
# 39/39 [==============================] - 0s 6ms/step - loss: 0.5869 - accuracy: 0.7739 - val_loss: 0.7373 - val_accuracy: 0.6931
# Epoch 45/250
# 39/39 [==============================] - 0s 4ms/step - loss: 0.6020 - accuracy: 0.7829 - val_loss: 0.7585 - val_accuracy: 0.6881
# Epoch 46/250
# 39/39 [==============================] - 0s 4ms/step - loss: 0.5931 - accuracy: 0.7894 - val_loss: 0.7569 - val_accuracy: 0.7079
# Epoch 47/250
# 39/39 [==============================] - 0s 4ms/step - loss: 0.5787 - accuracy: 0.7788 - val_loss: 0.7299 - val_accuracy: 0.7030
# Epoch 48/250
# 39/39 [==============================] - 0s 3ms/step - loss: 0.5766 - accuracy: 0.7780 - val_loss: 0.7455 - val_accuracy: 0.7079
# Epoch 49/250
# 39/39 [==============================] - 0s 4ms/step - loss: 0.5384 - accuracy: 0.8139 - val_loss: 0.7673 - val_accuracy: 0.7129
# Epoch 50/250
# 39/39 [==============================] - 0s 5ms/step - loss: 0.6069 - accuracy: 0.7845 - val_loss: 0.7441 - val_accuracy: 0.7327
# Epoch 51/250
# 39/39 [==============================] - 0s 4ms/step - loss: 0.5146 - accuracy: 0.8033 - val_loss: 0.7555 - val_accuracy: 0.6980
# Epoch 52/250
# 39/39 [==============================] - 0s 4ms/step - loss: 0.5662 - accuracy: 0.7959 - val_loss: 0.7218 - val_accuracy: 0.7426
# Epoch 53/250
# 39/39 [==============================] - 0s 4ms/step - loss: 0.5603 - accuracy: 0.7853 - val_loss: 0.7618 - val_accuracy: 0.7079
# Epoch 54/250
# 39/39 [==============================] - 0s 4ms/step - loss: 0.5324 - accuracy: 0.8000 - val_loss: 0.7296 - val_accuracy: 0.7426
# Epoch 55/250
# 39/39 [==============================] - 0s 4ms/step - loss: 0.5205 - accuracy: 0.8065 - val_loss: 0.7901 - val_accuracy: 0.6980
# Epoch 56/250
# 39/39 [==============================] - 0s 5ms/step - loss: 0.4624 - accuracy: 0.8114 - val_loss: 0.7298 - val_accuracy: 0.7327
# Epoch 57/250
# 39/39 [==============================] - 0s 6ms/step - loss: 0.4971 - accuracy: 0.8163 - val_loss: 0.7708 - val_accuracy: 0.6980
# Epoch 58/250
# 39/39 [==============================] - 0s 6ms/step - loss: 0.4815 - accuracy: 0.8204 - val_loss: 0.7916 - val_accuracy: 0.7079
# Epoch 59/250
# 39/39 [==============================] - 0s 7ms/step - loss: 0.4936 - accuracy: 0.8082 - val_loss: 0.7878 - val_accuracy: 0.7079
# Epoch 60/250
# 39/39 [==============================] - 0s 7ms/step - loss: 0.4320 - accuracy: 0.8433 - val_loss: 0.7852 - val_accuracy: 0.7129
# Epoch 61/250
# 39/39 [==============================] - 0s 6ms/step - loss: 0.4687 - accuracy: 0.8286 - val_loss: 0.7683 - val_accuracy: 0.7228
# Epoch 62/250
# 39/39 [==============================] - 1s 36ms/step - loss: 0.4334 - accuracy: 0.8408 - val_loss: 0.7791 - val_accuracy: 0.7228
# 7/7 [==============================] - 0s 3ms/step
# Accuracy: 0.7227722772277227

# %% [markdown]
# ## Multi-Omics

# %%
X_train_rfe_multiOmics = pd.read_pickle('/content/gdrive/My Drive/BIOINFORMATICSII/Project/X_train_rfe_multi_omics.pkl')
X_test_rfe_multiOmics = pd.read_pickle('/content/gdrive/My Drive/BIOINFORMATICSII/Project/X_test_rfe_multi_omics.pkl')

# %%
X_test_rfe_multiOmics.shape
# Out:
# (202, 57000)

# %%
X_train_rfe_multiOmics.shape
# Out:
# (469, 57000)

# %%
#before SMOTE
multiOmics_y_train.value_counts()
# Out:
# Label
# 1    245
# 2     96
# 3     82
# 4     25
# 0     21
# Name: count, dtype: int64

# %%
oversample = SMOTE()
X_resampled_multiOmics, y_resampled_multiOmics = oversample.fit_resample(X_train_rfe_multiOmics, multiOmics_y_train)
y_resampled_multiOmics = pd.DataFrame(y_resampled_multiOmics, columns=['Label'])

# %%
# after SMOTE
print(y_resampled_multiOmics["Label"].value_counts()[0])
print(y_resampled_multiOmics["Label"].value_counts()[1])
print(y_resampled_multiOmics["Label"].value_counts()[2])
print(y_resampled_multiOmics["Label"].value_counts()[3])
print(y_resampled_multiOmics["Label"].value_counts()[4])
# Out:
# 245
# 245
# 245
# 245
# 245

# %%
y_resampled_multiOmics.shape
# Out:
# (1225, 1)

# %%
X_resampled_multiOmics.shape
# Out:
# (1225, 57000)

# %%
from keras.callbacks import EarlyStopping

# %%
# Define the architecture parameters
input_dim = X_resampled_multiOmics.shape[1]   # Number of features
hidden1_dim = 64
hidden2_dim = 32
encoding_dim = 16  # Size of the encoded representations

# Define early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10)

# Build the SDAE model
input_layer = Input(shape=(input_dim,))
hidden1 = Dense(hidden1_dim, activation='relu')(input_layer)
encoded1 = Dense(hidden2_dim, activation='relu')(hidden1)
encoded2 = Dense(encoding_dim, activation='relu')(encoded1)
decoded1 = Dense(hidden2_dim, activation='relu')(encoded2)
decoded2 = Dense(hidden1_dim, activation='relu')(decoded1)
output_layer = Dense(input_dim, activation='linear')(decoded2)

sdae = Model(inputs=input_layer, outputs=output_layer)

# Compile the SDAE model
sdae.compile(optimizer='adam', loss='mean_squared_error')

# Train the SDAE
sdae.fit(X_resampled_multiOmics, X_resampled_multiOmics, epochs=250, batch_size=32, shuffle=True, validation_data=(X_test_rfe_multiOmics, X_test_rfe_multiOmics), callbacks=[early_stopping])

# Extract the encoder part for feature extraction
encoder = Model(inputs=input_layer, outputs=encoded2)

# Extract features using the encoder
X_train_encoded = encoder.predict(X_resampled_multiOmics)
X_test_encoded = encoder.predict(X_test_rfe_multiOmics)

# Define a classifier (example: simple MLP classifier)
num_classes = len(np.unique(y_resampled_multiOmics))  # Number of classes in the target

classifier = Sequential([
    Dense(64, activation='relu', input_dim=encoding_dim),
    Dropout(0.5),
    Dense(32, activation='relu'),
    Dropout(0.5),
    Dense(num_classes, activation='softmax')  # Softmax for multiclass classification
])


# Compile and train the classifier
classifier.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
classifier.fit(X_train_encoded, y_resampled_multiOmics, epochs=250, batch_size=32, validation_data=(X_test_encoded, multiOmics_y_test), callbacks=[early_stopping])

# Predict probabilities
y_pred_prob = classifier.predict(X_test_encoded)

# Convert probabilities to class labels
y_pred = np.argmax(y_pred_prob, axis=1)

# Evaluate the classifier
accuracy = accuracy_score(multiOmics_y_test, y_pred)
print(f"Accuracy: {accuracy}")
# Out:
# Epoch 1/250
# 39/39 [==============================] - 10s 207ms/step - loss: 0.6977 - val_loss: 0.8346
# Epoch 2/250
# 39/39 [==============================] - 4s 114ms/step - loss: 0.6021 - val_loss: 0.8137
# Epoch 3/250
# 39/39 [==============================] - 5s 119ms/step - loss: 0.5545 - val_loss: 0.8083
# Epoch 4/250
# 39/39 [==============================] - 6s 154ms/step - loss: 0.5213 - val_loss: 0.8040
# Epoch 5/250
# 39/39 [==============================] - 4s 111ms/step - loss: 0.4977 - val_loss: 0.8074
# Epoch 6/250
# 39/39 [==============================] - 4s 107ms/step - loss: 0.4790 - val_loss: 0.8061
# Epoch 7/250
# 39/39 [==============================] - 6s 154ms/step - loss: 0.4665 - val_loss: 0.8073
# Epoch 8/250
# 39/39 [==============================] - 4s 108ms/step - loss: 0.4597 - val_loss: 0.8104
# Epoch 9/250
# 39/39 [==============================] - 4s 115ms/step - loss: 0.4439 - val_loss: 0.8055
# Epoch 10/250
# 39/39 [==============================] - 6s 161ms/step - loss: 0.4312 - val_loss: 0.8100
# Epoch 11/250
# 39/39 [==============================] - 4s 113ms/step - loss: 0.4233 - val_loss: 0.8106
# Epoch 12/250
# 39/39 [==============================] - 4s 109ms/step - loss: 0.4196 - val_loss: 0.8129
# Epoch 13/250
# 39/39 [==============================] - 6s 150ms/step - loss: 0.4135 - val_loss: 0.8139
# Epoch 14/250
# 39/39 [==============================] - 4s 112ms/step - loss: 0.4034 - val_loss: 0.8151
# 39/39 [==============================] - 1s 14ms/step
# 7/7 [==============================] - 0s